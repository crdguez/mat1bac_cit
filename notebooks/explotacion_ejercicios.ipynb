# %%
import pandas as pd
import numpy as np
from docparts import escribir_ejercicios, escribir_fin, escribir_preambulo, generar_tex
from IPython.display import Markdown as md
from IPython.display import display

# %%
fichero = 'ejercicios'
n_ficheros = 4

n_ejercicios = 15

df = pd.concat([pd.read_csv(fichero + str(n + 1)+ '.csv', index_col=False) for n in range(n_ficheros)],sort=True)

df = df.reset_index()

# %%
df
# Out:
#      index curso  dificultad  \
# 0        0   1BC           1
# 1        1   1BC           1
# 2        2   1BC           1
# 3        3   1BC           1
# 4        4   1BC           1
# 5        5   1BC           1
# 6        6   1BC           1
# 7        7   1BC           1
# 8        0   1BC           1
# 9        1   1BC           1
# 10       2   1BC           1
# 11       3   1BC           1
# 12       4   1BC           1
# 13       5   1BC           1
# 14       6   1BC           1
# 15       7   1BC           1
# 16       8   1BC           1
# 17       9   1BC           1
# 18      10   1BC           1
# 19      11   1BC           1
# 20      12   1BC           1
# 21      13   1BC           1
# 22      14   1BC           1
# 23      15   1BC           1
# 24      16   1BC           1
# 25      17   1BC           1
# 26      18   1BC           1
# 27      19   1BC           1
# 28      20   1BC           1
# 29      21   1BC           1
# ..     ...   ...         ...
# 140     24   1BC           1
# 141     25   1BC           1
# 142     26   1BC           1
# 143     27   1BC           1
# 144     28   1BC           1
# 145     29   1BC           1
# 146     30   1BC           1
# 147     31   1BC           1
# 148     32   1BC           1
# 149     33   1BC           1
# 150     34   1BC           1
# 151     35   1BC           1
# 152     36   1BC           1
# 153     37   1BC           1
# 154     38   1BC           1
# 155     39   1BC           1
# 156     40   1BC           1
# 157     41   1BC           1
# 158     42   1BC           1
# 159     43   1BC           1
# 160     44   1BC           1
# 161     45   1BC           1
# 162     46   1BC           1
# 163     47   1BC           1
# 164     48   1BC           1
# 165     49   1BC           1
# 166     50   1BC           1
# 167     51   1BC           1
# 168     52   1BC           1
# 169     53   1BC           1
#
#                                              enunciado  \
# 0                                (Abs(x - 2) - 1, '<')
# 1                              (Abs(2*x + 3) - 4, '<')
# 2                               (Abs(x + 5) - 2, '<=')
# 3                           (Abs(3*x - 2) - 0.5, '<=')
# 4                                (Abs(x - 1) - 2, '>')
# 5                                (Abs(x + 2) - 5, '>')
# 6                             (Abs(2*x - 3) - 1, '>=')
# 7                           (Abs(2*x + 1) - 0.5, '>=')
# 8                       (2**3*(3**5*3**(-2)))/(2*3)**4
# 9                             81*(3**(-5)*(1/3)**(-2))
# 10                                (5/4)**5*(2**6/5**2)
# 11                         (2**(-2)*(2**2)**3)/2**(-3)
# 12                    (5**2*(5**(-3)/5))/(5**0 + 5**6)
# 13                                (2/3)**(-2)*(3/2)**4
# 14   ((sqrt(2)*(sqrt(2))**3)*(sqrt(5))**3)/(5*sqrt(...
# 15                     (2**(3/2)*(9**(1/2)/3))/sqrt(2)
# 16                                                   4
# 17                                       2*(-1)**(1/4)
# 18                                                   3
# 19                                         (-1)**(1/5)
# 20                                                  35
# 21                                                   1
# 22                                        Eq(x**4, 81)
# 23                                       Eq(x**3, 125)
# 24                                        Eq(x**2, -6)
# 25                                        Eq(x**5, -1)
# 26                         9*((3*sqrt(3))*(9*sqrt(3)))
# 27                               (5*5**(1/3))/5**(1/3)
# 28                                       (5**(1/3))**7
# 29                                   2**(1/6)*2**(1/3)
# ..                                                 ...
# 140                         (7*x**3 - 4*x - 3)/(x - 1)
# 141                                 (x**2 - 1)/(x + 1)
# 142                         (7*x**3 - 4*x + 9)/(x + 1)
# 143                         (7*x**3 - 4*x - 3)/(x - 1)
# 144                                 (x**2 - 1)/(x + 1)
# 145                                          x**2 - 81
# 146                                           x**2 - 2
# 147                                         4*x**2 - 9
# 148                                           x**3 - x
# 149                                         x**2 - 3*x
# 150                                     x**2 - 2*x + 1
# 151                             2*x**3 + x**5 - 3*x**4
# 152                                      x**2 - x - 30
# 153                                     x**2 + 2*x + 1
# 154                               -x + x**3 - x**2 + 1
# 155                           -5*x + x**3 - 2*x**2 + 6
# 156          -4*x - 10*x**2 + x**3 + x**5 + 4*x**4 + 8
# 157                           -2*x + x**3 + 3*x**2 - 6
# 158                         -13*x + x**3 - 3*x**2 + 15
# 159                                 -6*x + x**3 + x**2
# 160                          -12*x + 3*x**3 + x**2 - 4
# 161                        -2*x - x**2 + x**4 + 2*x**3
# 162                  -2*x + 2*x**2 + x**4 - 2*x**3 + 1
# 163                  -4*x - 3*x**2 + x**4 + 2*x**3 + 4
# 164                              x + x**3 + 4*x**2 - 6
# 165                          -x**2 + x**5 - 4*x**3 + 4
# 166                                                x=0
# 167                                                x=1
# 168                                                x=2
# 169                                      x=\frac{2}{3}
#
#                                        enunciado_latex  n_columnas  \
# 0                          \left|{x - 2}\right| - 1< 0           3
# 1                        \left|{2 x + 3}\right| - 4< 0           3
# 2                       \left|{x + 5}\right| - 2\leq 0           3
# 3                   \left|{3 x - 2}\right| - 0.5\leq 0           3
# 4                          \left|{x - 1}\right| - 2> 0           3
# 5                          \left|{x + 2}\right| - 5> 0           3
# 6                     \left|{2 x - 3}\right| - 1\geq 0           3
# 7                   \left|{2 x + 1}\right| - 0.5\geq 0           3
# 8    \frac{{{3^{ - 2}} \cdot {3^5} \cdot {2^3}}}{{{...           3
# 9    {3^{ - 5}} \cdot {( {\frac{1}{3}} )^{ - 2}} \c...           3
# 10   {( {\frac{5}{4}} )^5} \cdot \frac{{{2^6}}}{{{5...           3
# 11   \frac{{{2^{ - 2}} \cdot {{( {{2^2}} )}^3}}}{{{...           3
# 12   \frac{{{5^{ - 3}} \cdot {5^{ - 1}} \cdot {5^2}...           3
# 13   {( {\frac{2}{3}} )^{ - 2}} \cdot {( {\frac{3}{...           3
# 14   \frac{{\sqrt {2}  \cdot {{( {\sqrt {2} } )}^3}...           3
# 15   \frac{{{9^{\frac{1}{2}}} \cdot {3^{ - 1}} \cdo...           3
# 16                                          \sqrt {16}           3
# 17                                     \sqrt[4]{ - 16}           3
# 18                                        \sqrt[3]{27}           3
# 19                                        \sqrt[5]{-1}           3
# 20                                        \sqrt {1225}           3
# 21                                         \sqrt[7]{1}           3
# 22                                            x^4 = 81           3
# 23                                           x^3 = 125           3
# 24                                            x^2 = -6           3
# 25                                            x^5 = -1           3
# 26     \sqrt {27}  \cdot \sqrt {243}  \cdot \sqrt {81}           3
# 27          \frac{{\sqrt[3] {625} }}{{\sqrt[3] {5}  }}           3
# 28                                   ({\sqrt[3]{5}})^7           3
# 29                                  \sqrt[3]{\sqrt{8}}           3
# ..                                                 ...         ...
# 140                 ( {7{x^3} - 4x - 3} ):( {{x} - 1})           1
# 141                          ( {x^2 - 1 } ):( {x} + 1)           1
# 142                    ( {7{x^3} - 4x + 9} ):( {x+1} )           3
# 143                    ( {7{x^3} - 4x - 3} ):( {x-1} )           3
# 144                           ( {x^2 - 1} ):( {x + 1})           3
# 145                                             x^2-81           2
# 146                                              x^2-2           2
# 147                                             4x^2-9           2
# 148                                              x^3-x           2
# 149                                             x^2-3x           2
# 150                                           x^2-2x+1           2
# 151                                      x^5-3x^4+2x^3           2
# 152                                           x^2-x-30           2
# 153                                           x^2+2x+1           2
# 154                                        x^3-x^2-x+1           2
# 155                                      x^3-2x^2-5x+6           2
# 156                            x^5+4x^4+x^3-10x^2-4x+8           2
# 157                                      x^3+3x^2-2x-6           2
# 158                                    x^3-3x^2-13x+15           2
# 159                                         x^3+x^2-6x           2
# 160                                     3x^3+x^2-12x-4           2
# 161                                    x^4+2x^3-x^2-2x           2
# 162                                 x^4-2x^3+2x^2-2x+1           2
# 163                                 x^4+2x^3-3x^2-4x+4           2
# 164                                       x^3+4x^2+x-6           2
# 165                                    x^5- 4x^3-x^2+4           2
# 166                                                x=0           3
# 167                                                x=1           3
# 168                                                x=2           3
# 169                                      x=\frac{2}{3}           3
#
#     n_ejercicio  puntos                                           solucion  \
# 0          p9e3       1                                 1 < x \wedge x < 3
# 1          p9e3       1           - \frac{7}{2} < x \wedge x < \frac{1}{2}
# 2          p9e3       1                         -7 \leq x \wedge x \leq -3
# 3          p9e3       1         0.5 \leq x \wedge x \leq 0.833333333333333
# 4          p9e3       1  \left(-\infty < x \wedge x < -1\right) \vee \l...
# 5          p9e3       1  \left(-\infty < x \wedge x < -7\right) \vee \l...
# 6          p9e3       1  \left(2 \leq x \wedge x < \infty\right) \vee \...
# 7          p9e3       1  \left(-0.25 \leq x \wedge x < \infty\right) \v...
# 8        p4e1-2       1                                        \frac{1}{6}
# 9        p4e1-2       1                                                  3
# 10       p4e1-2       1                                     \frac{125}{16}
# 11       p4e1-2       1                                                128
# 12       p4e1-2       1                                   \frac{1}{390650}
# 13       p4e1-2       1                                     \frac{729}{64}
# 14       p4e1-2       1                               \frac{2 \sqrt{5}}{5}
# 15       p4e1-2       1                                                  2
# 16        p6e13       1                                                  4
# 17        p6e13       1                                     2 \sqrt[4]{-1}
# 18        p6e13       1                                                  3
# 19        p6e13       1                                       \sqrt[5]{-1}
# 20        p6e13       1                                                 35
# 21        p6e13       1                                                  1
# 22        p6e14       1                                         x^{4} = 81
# 23        p6e14       1                                        x^{3} = 125
# 24        p6e14       1                                         x^{2} = -6
# 25        p6e14       1                                         x^{5} = -1
# 26        p6e15       1                                                729
# 27        p6e15       1                                                  5
# 28        p6e15       1                                     25 \sqrt[3]{5}
# 29        p6e15       1                                           \sqrt{2}
# ..          ...     ...                                                ...
# 140     p013e11       1         \left ( 7 x^{2} + 7 x + 3, \quad 0\right )
# 141     p013e11       1                     \left ( x - 1, \quad 0\right )
# 142     p013e12       1                                                  6
# 143     p013e12       1                                                  0
# 144     p013e12       1                                                  0
# 145  p013e17-18       1              \left(x - 9\right) \left(x + 9\right)
# 146  p013e17-18       1  \left(x - \sqrt{2}\right) \left(x + \sqrt{2}\r...
# 147  p013e17-18       1  4 \left(x - \frac{3}{2}\right) \left(x + \frac...
# 148  p013e17-18       1            x \left(x - 1\right) \left(x + 1\right)
# 149  p013e17-18       1                               x \left(x - 3\right)
# 150  p013e17-18       1                             \left(x - 1\right)^{2}
# 151  p013e17-18       1        x^{3} \left(x - 2\right) \left(x - 1\right)
# 152  p013e17-18       1              \left(x - 6\right) \left(x + 5\right)
# 153  p013e17-18       1                             \left(x + 1\right)^{2}
# 154  p013e17-18       1          \left(x - 1\right)^{2} \left(x + 1\right)
# 155  p013e17-18       1  \left(x - 3\right) \left(x - 1\right) \left(x ...
# 156  p013e17-18       1      \left(x - 1\right)^{2} \left(x + 2\right)^{3}
# 157  p013e17-18       1  \left(x + 3\right) \left(x - \sqrt{2}\right) \...
# 158  p013e17-18       1  \left(x - 5\right) \left(x - 1\right) \left(x ...
# 159  p013e17-18       1            x \left(x - 2\right) \left(x + 3\right)
# 160  p013e17-18       1  3 \left(x - 2\right) \left(x + \frac{1}{3}\rig...
# 161  p013e17-18       1  x \left(x - 1\right) \left(x + 1\right) \left(...
# 162  p013e17-18       1      \left(x - 1\right)^{2} \left(x^{2} + 1\right)
# 163  p013e17-18       1      \left(x - 1\right)^{2} \left(x + 2\right)^{2}
# 164  p013e17-18       1  \left(x - 1\right) \left(x + 2\right) \left(x ...
# 165  p013e17-18       1  \left(x - 2\right) \left(x - 1\right) \left(x ...
# 166     p013e21       1                                                  3
# 167     p013e21       1                                                  1
# 168     p013e21       1                                                 -1
# 169     p013e21       1                                     \frac{175}{81}
#
#                                                  texto  \
# 0                Resolver las siguientes inecuaciones:
# 1                Resolver las siguientes inecuaciones:
# 2                Resolver las siguientes inecuaciones:
# 3                Resolver las siguientes inecuaciones:
# 4                Resolver las siguientes inecuaciones:
# 5                Resolver las siguientes inecuaciones:
# 6                Resolver las siguientes inecuaciones:
# 7                Resolver las siguientes inecuaciones:
# 8                                            Calcula :
# 9                                            Calcula :
# 10                                           Calcula :
# 11                                           Calcula :
# 12                                           Calcula :
# 13                                           Calcula :
# 14                                           Calcula :
# 15                                           Calcula :
# 16                   Calcula los siguientes radicales:
# 17                   Calcula los siguientes radicales:
# 18                   Calcula los siguientes radicales:
# 19                   Calcula los siguientes radicales:
# 20                   Calcula los siguientes radicales:
# 21                   Calcula los siguientes radicales:
# 22                 Resuelve las siguientes ecuaciones:
# 23                 Resuelve las siguientes ecuaciones:
# 24                 Resuelve las siguientes ecuaciones:
# 25                 Resuelve las siguientes ecuaciones:
# 26   Calcula y expresa el resultado de la forma más...
# 27   Calcula y expresa el resultado de la forma más...
# 28   Calcula y expresa el resultado de la forma más...
# 29   Calcula y expresa el resultado de la forma más...
# ..                                                 ...
# 140  Aplica la regla de Ruffini para hallar el coci...
# 141  Aplica la regla de Ruffini para hallar el coci...
# 142  Aplica el teorema del resto para calcular el r...
# 143  Aplica el teorema del resto para calcular el r...
# 144  Aplica el teorema del resto para calcular el r...
# 145                            Descomponer en factores
# 146                            Descomponer en factores
# 147                            Descomponer en factores
# 148                            Descomponer en factores
# 149                            Descomponer en factores
# 150                            Descomponer en factores
# 151                            Descomponer en factores
# 152                            Descomponer en factores
# 153                            Descomponer en factores
# 154                            Descomponer en factores
# 155                            Descomponer en factores
# 156                            Descomponer en factores
# 157                            Descomponer en factores
# 158                            Descomponer en factores
# 159                            Descomponer en factores
# 160                            Descomponer en factores
# 161                            Descomponer en factores
# 162                            Descomponer en factores
# 163                            Descomponer en factores
# 164                            Descomponer en factores
# 165                            Descomponer en factores
# 166  Halla el valor numérico del polinomio $x^4-2x^...
# 167  Halla el valor numérico del polinomio $x^4-2x^...
# 168  Halla el valor numérico del polinomio $x^4-2x^...
# 169  Halla el valor numérico del polinomio $x^4-2x^...
#
#                         titulo
# 0           1 - Números reales
# 1           1 - Números reales
# 2           1 - Números reales
# 3           1 - Números reales
# 4           1 - Números reales
# 5           1 - Números reales
# 6           1 - Números reales
# 7           1 - Números reales
# 8    2 - Potencias y radicales
# 9    2 - Potencias y radicales
# 10   2 - Potencias y radicales
# 11   2 - Potencias y radicales
# 12   2 - Potencias y radicales
# 13   2 - Potencias y radicales
# 14   2 - Potencias y radicales
# 15   2 - Potencias y radicales
# 16   2 - Potencias y radicales
# 17   2 - Potencias y radicales
# 18   2 - Potencias y radicales
# 19   2 - Potencias y radicales
# 20   2 - Potencias y radicales
# 21   2 - Potencias y radicales
# 22   2 - Potencias y radicales
# 23   2 - Potencias y radicales
# 24   2 - Potencias y radicales
# 25   2 - Potencias y radicales
# 26   2 - Potencias y radicales
# 27   2 - Potencias y radicales
# 28   2 - Potencias y radicales
# 29   2 - Potencias y radicales
# ..                         ...
# 140             4 - Polinomios
# 141             4 - Polinomios
# 142             4 - Polinomios
# 143             4 - Polinomios
# 144             4 - Polinomios
# 145             4 - Polinomios
# 146             4 - Polinomios
# 147             4 - Polinomios
# 148             4 - Polinomios
# 149             4 - Polinomios
# 150             4 - Polinomios
# 151             4 - Polinomios
# 152             4 - Polinomios
# 153             4 - Polinomios
# 154             4 - Polinomios
# 155             4 - Polinomios
# 156             4 - Polinomios
# 157             4 - Polinomios
# 158             4 - Polinomios
# 159             4 - Polinomios
# 160             4 - Polinomios
# 161             4 - Polinomios
# 162             4 - Polinomios
# 163             4 - Polinomios
# 164             4 - Polinomios
# 165             4 - Polinomios
# 166             4 - Polinomios
# 167             4 - Polinomios
# 168             4 - Polinomios
# 169             4 - Polinomios
#
# [170 rows x 11 columns]

# %%
df_ejercicios = df.loc[np.random.choice(df.index, n_ejercicios)].sort_values('n_ejercicio')

# %%
df_ejercicios
# Out:
#      index curso  dificultad                                  enunciado  \
# 133     17   1BC           1                                   x**2 - 1
# 144     28   1BC           1                         (x**2 - 1)/(x + 1)
# 142     26   1BC           1                 (7*x**3 - 4*x + 9)/(x + 1)
# 159     43   1BC           1                         -6*x + x**3 + x**2
# 155     39   1BC           1                   -5*x + x**3 - 2*x**2 + 6
# 20      12   1BC           1                                         35
# 25      17   1BC           1                               Eq(x**5, -1)
# 29      21   1BC           1                          2**(1/6)*2**(1/3)
# 50      42   1BC           1                                         15
# 71      63   1BC           1  ((x*y)**(1/5)/sqrt(x*y**3))*(x**2)**(1/3)
# 61      53   1BC           1            (x**2*y**3)**(1/3)/(x*y)**(1/3)
# 90       4   1BC           1          factorial(m + 1)/factorial(m - 1)
# 3        3   1BC           1                 (Abs(3*x - 2) - 0.5, '<=')
# 102     16   1BC           1                          (x/2 + 2/x**2)**5
# 107     21   1BC           1                             (2/5 + 3/x)**8
#
#                                        enunciado_latex  n_columnas  \
# 133                                            x^2 - 1           3
# 144                           ( {x^2 - 1} ):( {x + 1})           3
# 142                    ( {7{x^3} - 4x + 9} ):( {x+1} )           3
# 159                                         x^3+x^2-6x           2
# 155                                      x^3-2x^2-5x+6           2
# 20                                        \sqrt {1225}           3
# 25                                            x^5 = -1           3
# 29                                  \sqrt[3]{\sqrt{8}}           3
# 50                                     \sqrt[4]{50625}           3
# 71   \sqrt [3] {{x^2}}  \cdot \frac{{\sqrt [5] {xy}...           3
# 61     \frac{{\sqrt[3]{{x^2}{y^3}} }}{{\sqrt[3]{xy} }}           3
# 90               \frac{{( {m + 1} )!}}{{( {m - 1} )!}}           3
# 3                   \left|{3 x - 2}\right| - 0.5\leq 0           3
# 102            ( {\frac{x}{2} + \frac{2}{{{x^2}}}} )^5           3
# 107                  ( {\frac{2}{5} + \frac{3}{x}} )^8           3
#
#     n_ejercicio  puntos                                           solucion  \
# 133     p012e09       1                               \left\{-1, 1\right\}
# 144     p013e12       1                                                  0
# 142     p013e12       1                                                  6
# 159  p013e17-18       1            x \left(x - 2\right) \left(x + 3\right)
# 155  p013e17-18       1  \left(x - 3\right) \left(x - 1\right) \left(x ...
# 20        p6e13       1                                                 35
# 25        p6e14       1                                         x^{5} = -1
# 29        p6e15       1                                           \sqrt{2}
# 50        p6e23       1                                                 15
# 71        p6e27       1  \frac{\sqrt[5]{x y} \sqrt{x y^{3}} \sqrt[3]{x^...
# 61        p6e27       1        \frac{\sqrt[3]{x^{2} y^{3}}}{\sqrt[3]{x y}}
# 90         p9e2       1                               m \left(m + 1\right)
# 3          p9e3       1         0.5 \leq x \wedge x \leq 0.833333333333333
# 102        p9e6       1  \frac{x^{5}}{32} + \frac{5 x^{2}}{8} + \frac{5...
# 107     p9e7-13       1  \frac{256}{390625} + \frac{3072}{78125 x} + \f...
#
#                                                  texto  \
# 133  Halla, para cada uno  de los siguientes polino...
# 144  Aplica el teorema del resto para calcular el r...
# 142  Aplica el teorema del resto para calcular el r...
# 159                            Descomponer en factores
# 155                            Descomponer en factores
# 20                   Calcula los siguientes radicales:
# 25                 Resuelve las siguientes ecuaciones:
# 29   Calcula y expresa el resultado de la forma más...
# 50   Calcula, descomponiendo el radicando en factor...
# 71                                            Efectúa:
# 61                                            Efectúa:
# 90         Simplifica los cocientes entre factoriales:
# 3                Resolver las siguientes inecuaciones:
# 102  Realiza los desarrollos de los siguientes bino...
# 107  Realiza los desarrollos de los siguientes bino...
#
#                                            titulo
# 133                                4 - Polinomios
# 144                                4 - Polinomios
# 142                                4 - Polinomios
# 159                                4 - Polinomios
# 155                                4 - Polinomios
# 20                      2 - Potencias y radicales
# 25                      2 - Potencias y radicales
# 29                      2 - Potencias y radicales
# 50                      2 - Potencias y radicales
# 71                      2 - Potencias y radicales
# 61                      2 - Potencias y radicales
# 90   3 - Números combinatorios. Binomio de Newton
# 3                              1 - Números reales
# 102  3 - Números combinatorios. Binomio de Newton
# 107  3 - Números combinatorios. Binomio de Newton

# %%
fichero = 'autoevaluacion.tex'
titulo = 'Autoevaluación'
tipo = 'ejerc'

if tipo != 'ejercicios' : df_ejercicios.n_columnas = 1 

escribir_preambulo(fichero, titulo, tipo)
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **p012e09
#      index curso  dificultad enunciado enunciado_latex  n_columnas  \
# 133     17   1BC           1  x**2 - 1         x^2 - 1           1
#
#     n_ejercicio  puntos              solucion  \
# 133     p012e09       1  \left\{-1, 1\right\}
#
#                                                  texto          titulo
# 133  Halla, para cada uno  de los siguientes polino...  4 - Polinomios
# **Ejercicio: **p013e12
#      index curso  dificultad                   enunciado  \
# 144     28   1BC           1          (x**2 - 1)/(x + 1)
# 142     26   1BC           1  (7*x**3 - 4*x + 9)/(x + 1)
#
#                      enunciado_latex  n_columnas n_ejercicio  puntos solucion  \
# 144         ( {x^2 - 1} ):( {x + 1})           1     p013e12       1        0
# 142  ( {7{x^3} - 4x + 9} ):( {x+1} )           1     p013e12       1        6
#
#                                                  texto          titulo
# 144  Aplica el teorema del resto para calcular el r...  4 - Polinomios
# 142  Aplica el teorema del resto para calcular el r...  4 - Polinomios
# **Ejercicio: **p013e17-18
#      index curso  dificultad                 enunciado enunciado_latex  \
# 159     43   1BC           1        -6*x + x**3 + x**2      x^3+x^2-6x
# 155     39   1BC           1  -5*x + x**3 - 2*x**2 + 6   x^3-2x^2-5x+6
#
#      n_columnas n_ejercicio  puntos  \
# 159           1  p013e17-18       1
# 155           1  p013e17-18       1
#
#                                               solucion  \
# 159            x \left(x - 2\right) \left(x + 3\right)
# 155  \left(x - 3\right) \left(x - 1\right) \left(x ...
#
#                        texto          titulo
# 159  Descomponer en factores  4 - Polinomios
# 155  Descomponer en factores  4 - Polinomios
# **Ejercicio: **p6e13
#     index curso  dificultad enunciado enunciado_latex  n_columnas n_ejercicio  \
# 20     12   1BC           1        35    \sqrt {1225}           1       p6e13
#
#     puntos solucion                              texto  \
# 20       1       35  Calcula los siguientes radicales:
#
#                        titulo
# 20  2 - Potencias y radicales
# **Ejercicio: **p6e14
#     index curso  dificultad     enunciado enunciado_latex  n_columnas  \
# 25     17   1BC           1  Eq(x**5, -1)        x^5 = -1           1
#
#    n_ejercicio  puntos    solucion                                texto  \
# 25       p6e14       1  x^{5} = -1  Resuelve las siguientes ecuaciones:
#
#                        titulo
# 25  2 - Potencias y radicales
# **Ejercicio: **p6e15
#     index curso  dificultad          enunciado     enunciado_latex  \
# 29     21   1BC           1  2**(1/6)*2**(1/3)  \sqrt[3]{\sqrt{8}}
#
#     n_columnas n_ejercicio  puntos  solucion  \
# 29           1       p6e15       1  \sqrt{2}
#
#                                                 texto  \
# 29  Calcula y expresa el resultado de la forma más...
#
#                        titulo
# 29  2 - Potencias y radicales
# **Ejercicio: **p6e23
#     index curso  dificultad enunciado  enunciado_latex  n_columnas  \
# 50     42   1BC           1        15  \sqrt[4]{50625}           1
#
#    n_ejercicio  puntos solucion  \
# 50       p6e23       1       15
#
#                                                 texto  \
# 50  Calcula, descomponiendo el radicando en factor...
#
#                        titulo
# 50  2 - Potencias y radicales
# **Ejercicio: **p6e27
#     index curso  dificultad                                  enunciado  \
# 71     63   1BC           1  ((x*y)**(1/5)/sqrt(x*y**3))*(x**2)**(1/3)
# 61     53   1BC           1            (x**2*y**3)**(1/3)/(x*y)**(1/3)
#
#                                       enunciado_latex  n_columnas n_ejercicio  \
# 71  \sqrt [3] {{x^2}}  \cdot \frac{{\sqrt [5] {xy}...           1       p6e27
# 61    \frac{{\sqrt[3]{{x^2}{y^3}} }}{{\sqrt[3]{xy} }}           1       p6e27
#
#     puntos                                           solucion     texto  \
# 71       1  \frac{\sqrt[5]{x y} \sqrt{x y^{3}} \sqrt[3]{x^...  Efectúa:
# 61       1        \frac{\sqrt[3]{x^{2} y^{3}}}{\sqrt[3]{x y}}  Efectúa:
#
#                        titulo
# 71  2 - Potencias y radicales
# 61  2 - Potencias y radicales
# **Ejercicio: **p9e2
#     index curso  dificultad                          enunciado  \
# 90      4   1BC           1  factorial(m + 1)/factorial(m - 1)
#
#                           enunciado_latex  n_columnas n_ejercicio  puntos  \
# 90  \frac{{( {m + 1} )!}}{{( {m - 1} )!}}           1        p9e2       1
#
#                 solucion                                        texto  \
# 90  m \left(m + 1\right)  Simplifica los cocientes entre factoriales:
#
#                                           titulo
# 90  3 - Números combinatorios. Binomio de Newton
# **Ejercicio: **p9e3
#    index curso  dificultad                   enunciado  \
# 3      3   1BC           1  (Abs(3*x - 2) - 0.5, '<=')
#
#                       enunciado_latex  n_columnas n_ejercicio  puntos  \
# 3  \left|{3 x - 2}\right| - 0.5\leq 0           1        p9e3       1
#
#                                      solucion  \
# 3  0.5 \leq x \wedge x \leq 0.833333333333333
#
#                                    texto              titulo
# 3  Resolver las siguientes inecuaciones:  1 - Números reales
# **Ejercicio: **p9e6
#      index curso  dificultad          enunciado  \
# 102     16   1BC           1  (x/2 + 2/x**2)**5
#
#                              enunciado_latex  n_columnas n_ejercicio  puntos  \
# 102  ( {\frac{x}{2} + \frac{2}{{{x^2}}}} )^5           1        p9e6       1
#
#                                               solucion  \
# 102  \frac{x^{5}}{32} + \frac{5 x^{2}}{8} + \frac{5...
#
#                                                  texto  \
# 102  Realiza los desarrollos de los siguientes bino...
#
#                                            titulo
# 102  3 - Números combinatorios. Binomio de Newton
# **Ejercicio: **p9e7-13
#      index curso  dificultad       enunciado  \
# 107     21   1BC           1  (2/5 + 3/x)**8
#
#                        enunciado_latex  n_columnas n_ejercicio  puntos  \
# 107  ( {\frac{2}{5} + \frac{3}{x}} )^8           1     p9e7-13       1
#
#                                               solucion  \
# 107  \frac{256}{390625} + \frac{3072}{78125 x} + \f...
#
#                                                  texto  \
# 107  Realiza los desarrollos de los siguientes bino...
#
#                                            titulo
# 107  3 - Números combinatorios. Binomio de Newton

# %%
df_ejercicios.n_columnas = 1

# %%
df_ejercicios
# Out:
#      index curso  dificultad                                  enunciado  \
# 133     17   1BC           1                                   x**2 - 1
# 144     28   1BC           1                         (x**2 - 1)/(x + 1)
# 142     26   1BC           1                 (7*x**3 - 4*x + 9)/(x + 1)
# 159     43   1BC           1                         -6*x + x**3 + x**2
# 155     39   1BC           1                   -5*x + x**3 - 2*x**2 + 6
# 20      12   1BC           1                                         35
# 25      17   1BC           1                               Eq(x**5, -1)
# 29      21   1BC           1                          2**(1/6)*2**(1/3)
# 50      42   1BC           1                                         15
# 71      63   1BC           1  ((x*y)**(1/5)/sqrt(x*y**3))*(x**2)**(1/3)
# 61      53   1BC           1            (x**2*y**3)**(1/3)/(x*y)**(1/3)
# 90       4   1BC           1          factorial(m + 1)/factorial(m - 1)
# 3        3   1BC           1                 (Abs(3*x - 2) - 0.5, '<=')
# 102     16   1BC           1                          (x/2 + 2/x**2)**5
# 107     21   1BC           1                             (2/5 + 3/x)**8
#
#                                        enunciado_latex  n_columnas  \
# 133                                            x^2 - 1           1
# 144                           ( {x^2 - 1} ):( {x + 1})           1
# 142                    ( {7{x^3} - 4x + 9} ):( {x+1} )           1
# 159                                         x^3+x^2-6x           1
# 155                                      x^3-2x^2-5x+6           1
# 20                                        \sqrt {1225}           1
# 25                                            x^5 = -1           1
# 29                                  \sqrt[3]{\sqrt{8}}           1
# 50                                     \sqrt[4]{50625}           1
# 71   \sqrt [3] {{x^2}}  \cdot \frac{{\sqrt [5] {xy}...           1
# 61     \frac{{\sqrt[3]{{x^2}{y^3}} }}{{\sqrt[3]{xy} }}           1
# 90               \frac{{( {m + 1} )!}}{{( {m - 1} )!}}           1
# 3                   \left|{3 x - 2}\right| - 0.5\leq 0           1
# 102            ( {\frac{x}{2} + \frac{2}{{{x^2}}}} )^5           1
# 107                  ( {\frac{2}{5} + \frac{3}{x}} )^8           1
#
#     n_ejercicio  puntos                                           solucion  \
# 133     p012e09       1                               \left\{-1, 1\right\}
# 144     p013e12       1                                                  0
# 142     p013e12       1                                                  6
# 159  p013e17-18       1            x \left(x - 2\right) \left(x + 3\right)
# 155  p013e17-18       1  \left(x - 3\right) \left(x - 1\right) \left(x ...
# 20        p6e13       1                                                 35
# 25        p6e14       1                                         x^{5} = -1
# 29        p6e15       1                                           \sqrt{2}
# 50        p6e23       1                                                 15
# 71        p6e27       1  \frac{\sqrt[5]{x y} \sqrt{x y^{3}} \sqrt[3]{x^...
# 61        p6e27       1        \frac{\sqrt[3]{x^{2} y^{3}}}{\sqrt[3]{x y}}
# 90         p9e2       1                               m \left(m + 1\right)
# 3          p9e3       1         0.5 \leq x \wedge x \leq 0.833333333333333
# 102        p9e6       1  \frac{x^{5}}{32} + \frac{5 x^{2}}{8} + \frac{5...
# 107     p9e7-13       1  \frac{256}{390625} + \frac{3072}{78125 x} + \f...
#
#                                                  texto  \
# 133  Halla, para cada uno  de los siguientes polino...
# 144  Aplica el teorema del resto para calcular el r...
# 142  Aplica el teorema del resto para calcular el r...
# 159                            Descomponer en factores
# 155                            Descomponer en factores
# 20                   Calcula los siguientes radicales:
# 25                 Resuelve las siguientes ecuaciones:
# 29   Calcula y expresa el resultado de la forma más...
# 50   Calcula, descomponiendo el radicando en factor...
# 71                                            Efectúa:
# 61                                            Efectúa:
# 90         Simplifica los cocientes entre factoriales:
# 3                Resolver las siguientes inecuaciones:
# 102  Realiza los desarrollos de los siguientes bino...
# 107  Realiza los desarrollos de los siguientes bino...
#
#                                            titulo
# 133                                4 - Polinomios
# 144                                4 - Polinomios
# 142                                4 - Polinomios
# 159                                4 - Polinomios
# 155                                4 - Polinomios
# 20                      2 - Potencias y radicales
# 25                      2 - Potencias y radicales
# 29                      2 - Potencias y radicales
# 50                      2 - Potencias y radicales
# 71                      2 - Potencias y radicales
# 61                      2 - Potencias y radicales
# 90   3 - Números combinatorios. Binomio de Newton
# 3                              1 - Números reales
# 102  3 - Números combinatorios. Binomio de Newton
# 107  3 - Números combinatorios. Binomio de Newton
