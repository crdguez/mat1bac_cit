# %%
from sympy import init_session
from sympy import div, QQ
from sympy.parsing.latex import parse_latex
from sympy.parsing.sympy_parser import parse_expr
from IPython.display import Markdown as md
from IPython.display import display
import pandas as pd

import numpy as np




init_session()

a, b, c, d = symbols('a b c d', real = True)
from docparts import añadir_ejercicios, doc_ejer, escribir_preambulo, escribir_ejercicios, escribir_fin

df_ejercicios = pd.DataFrame()

fichero = 'autoev1305'
titulo = 'Ejercicios 13/05'
curso = '1BC'


x,y = symbols('x, y', real=True)

import matplotlib.pyplot as plt
from matplotlib import style
#style.use('ggplot')
style.use('seaborn-whitegrid')


# %matplotlib inline
# Out:
# IPython console for SymPy 1.4 (Python 3.6.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.4/

# %%
puntuacion = '1'                          
                      
datos = [[r'0x+3',r'x^3-5x^2+2',r'\frac{{x - 3}}{{x + 2}}', r'2x-3', r'2-\frac{2}{x-1}'],]


for i, s in enumerate(datos) : 
    n_ejercicio = 'e1-'+str(i)
    enunciado_latex, enunciado, solucion = [],[],[]
    
    texto_ejercicio = r"""Halla analíticamente el dominio de las siguientes funciones y comprueba el resultado con la gráfica que aparece en la solución:"""
    
    display(md("**"+texto_ejercicio+"**"))
    
    for j, t in enumerate(s):
        enunciado_latex.append("$f(x)="+t+"$")
        enunciado.append(parse_latex(t))
        # voy por aquí

        sol = r"$Dom\left(f \right)="
        sol+=latex(S.Reals - singularities(eval(str(parse_latex(t))),x))+r"$"
        
        plt.rcParams['figure.figsize'] = 10,10
        p1 = plot(parse_latex(t),show=True, xlim=(-10,10), ylim=(-10,10))
        p1.save(n_ejercicio+"-"+str(j)+".png")
        sol+=r"\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{%s}}" % (n_ejercicio+"-"+str(j))

        solucion.append(sol)
        display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))
        

        
    df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Halla analíticamente el dominio de las siguientes funciones y comprueba el resultado con la gráfica que aparece en la solución:**
# $f(x)=0x+3$ $ \rightarrow $$Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{e1-0-0}}
# $f(x)=x^3-5x^2+2$ $ \rightarrow $$Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{e1-0-1}}
# $f(x)=\frac{{x - 3}}{{x + 2}}$ $ \rightarrow $$Dom\left(f \right)=\left(-\infty, -2\right) \cup \left(-2, \infty\right)$\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{e1-0-2}}
# $f(x)=2x-3$ $ \rightarrow $$Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{e1-0-3}}
# $f(x)=2-\frac{2}{x-1}$ $ \rightarrow $$Dom\left(f \right)=\left(-\infty, 1\right) \cup \left(1, \infty\right)$\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{e1-0-4}}

# %%
puntuacion = '1'                          
                      
#datos = [[r'0x-3',r'x^3-5x^2+2',r'\frac{{x - 1}}{{x + 5}}', r'7x-1', r'\frac{2}{x}'],]


for i, s in enumerate(datos) : 
    n_ejercicio = 'e1b-'+str(i)
    enunciado_latex, enunciado, solucion = [],[],[]
    
    texto_ejercicio = r"""Halla analíticamente el dominio de las siguientes funciones:"""
    
    display(md("**"+texto_ejercicio+"**"))
    
    
    dato = r'\sqrt[3]{\frac{x + 2}{x - 3}}'
    enunciado_latex.append("$f(x)="+dato+"$")
    enunciado.append(parse_latex(dato))
    sol = r"$Dom\left(f \right)="
    sol+=latex(S.Reals - singularities((x+2)/(x-3),x))+r"$"
    solucion.append(sol)
    display(md(r"$f(x)="+dato+"$"+" $ \\rightarrow $" + sol))
    
    dato = r'\sqrt {\frac{x}{2 x^{2} + 2 x - 12}}'
    enunciado_latex.append("$f(x)="+dato+"$")
    enunciado.append(parse_latex(dato))
    sol = r"$Dom\left(f \right)="
    sol+=latex(S.Reals - solve_univariate_inequality(2*x**2 + 2*x - 12<=0,x, relational=False))+r"$"
    solucion.append(sol)
    display(md(r"$f(x)="+dato+"$"+" $ \\rightarrow $" + sol))
    
    dato = r'\sqrt {x^2-9}'
    enunciado_latex.append("$f(x)="+dato+"$")
    enunciado.append(parse_latex(dato))
    sol = r"$Dom\left(f \right)="
    sol+=latex(S.Reals - solve_univariate_inequality(x**2-9<0,x, relational=False))+r"$"
    solucion.append(sol)
    display(md(r"$f(x)="+dato+"$"+" $ \\rightarrow $" + sol))

        
    df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '3', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Halla analíticamente el dominio de las siguientes funciones:**
# $f(x)=\sqrt[3]{\frac{x + 2}{x - 3}}$ $ \rightarrow $$Dom\left(f \right)=\left(-\infty, 3\right) \cup \left(3, \infty\right)$
# $f(x)=\sqrt {\frac{x}{2 x^{2} + 2 x - 12}}$ $ \rightarrow $$Dom\left(f \right)=\left(-\infty, -3\right) \cup \left(2, \infty\right)$
# $f(x)=\sqrt {x^2-9}$ $ \rightarrow $$Dom\left(f \right)=\left(-\infty, -3\right] \cup \left[3, \infty\right)$

# %%
puntuacion = '1'                          
                      
datos = [[r'x^2+4',r'\frac{{x - 1}}{{x + 2}}',r'\sqrt{2x}'],]

# vectores iniciales correspondientes al texto del enunciado

for i, s in enumerate(datos) : 
    n_ejercicio = 'e3-'+str(i)
    enunciado_latex, enunciado, solucion = [],[],[]
    
    texto_ejercicio = r"""Dadas las funciones $f(x)= {}$, $g(x)= {}$ y $h(x)= {}$. Calcula: 
    """.format(datos[i][0],datos[i][1],datos[i][2])
    
    display(md("**"+texto_ejercicio+"**"))
    
    f = Lambda(x,eval(str(parse_latex(s[0]))))
    g = Lambda(x,eval(str(parse_latex(s[1]))))
    h = Lambda(x,eval(str(parse_latex(s[2]))))
    
    apartados = [[r'g \circ f','g(f(x))'],[r'f \circ g','f(g(x))'],[r'h \circ g \circ f','h(g(f(x)))']]
    
    for j, t in enumerate(apartados):
        enunciado_latex.append("$"+t[0]+"$")
        enunciado.append(t[1])


        sol = r"$"+latex(S(t[1]))+"="
        sol+=latex(eval(t[1]))+r"$"
        solucion.append(sol)
        display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))
        

        
    df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '3', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Dadas las funciones $f(x)= x^2+4$, $g(x)= \frac{{x - 1}}{{x + 2}}$ y $h(x)= \sqrt{2x}$. Calcula:
#     **
# $g \circ f$ $ \rightarrow $$g{\left(f{\left(x \right)} \right)}=\frac{x^{2} + 3}{x^{2} + 6}$
# $f \circ g$ $ \rightarrow $$f{\left(g{\left(x \right)} \right)}=\frac{\left(x - 1\right)^{2}}{\left(x + 2\right)^{2}} + 4$
# $h \circ g \circ f$ $ \rightarrow $$h{\left(g{\left(f{\left(x \right)} \right)} \right)}=\frac{\sqrt{2} \sqrt{x^{2} + 3}}{\sqrt{x^{2} + 6}}$

# %%
puntuacion = '1'                          
                      
datos = [r'5x-1',r'\frac{{1 + x}}{{2 - x}}']

# vectores iniciales correspondientes al texto del enunciado
n_ejercicio = 'e4'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Halla la función inversa de $f(x)$, y comprueba el resultado, siendo:"""
display(md("**"+texto_ejercicio+"**"))

for i, s in enumerate(datos) : 
    
    enunciado_latex.append("$f(x)="+latex(parse_latex(s))+"$")
    enunciado.append(s)
    
    inv = solve(S('x')-eval(str(parse_latex(s))).subs([(x,y)]),y)[0]
    f = Lambda(x,eval(str(parse_latex(s))))
    g = Lambda(x,eval(str(inv)))
    
    #display(f(x),g(x), f(g(x)), g(f(x)))
    sol = r"$f^{-1}(x)="
    sol+=latex(inv)+r"$ \\ $f^{-1} \circ f(x)="+ latex(g(f(x)))+ "=" + latex(simplify(g(f(x)))) + r"$ \\"
    
    plt.rcParams['figure.figsize'] = 10,10
    p1 = plot(f(x),g(x),show=True, xlim=(-10,10), ylim=(-10,10))
    p1.save(n_ejercicio+"-"+str(i)+".png")
    sol+=r"\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{%s}}" % (n_ejercicio+"-"+str(i))
    
       
    
    solucion.append(sol)
    display(md(enunciado_latex[i] +" $ \\rightarrow $" + solucion[i] ))
        
df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Halla la función inversa de $f(x)$, y comprueba el resultado, siendo:**
# $f(x)=5 x - 1$ $ \rightarrow $$f^{-1}(x)=\frac{x}{5} + \frac{1}{5}$ \\ $f^{-1} \circ f(x)=x=x$ \\\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{e4-0}}
# $f(x)=\frac{x + 1}{2 - x}$ $ \rightarrow $$f^{-1}(x)=\frac{2 x - 1}{x + 1}$ \\ $f^{-1} \circ f(x)=\frac{-1 + \frac{2 \left(x + 1\right)}{2 - x}}{1 + \frac{x + 1}{2 - x}}=x$ \\\\ \resizebox{0.4\textwidth}{!}{\includegraphics[width=1\columnwidth]{e4-1}}

# %%
puntuacion = '1'                          
                      
datos =  [  [r'x^2-3x-1',3],[r'\frac{x^2 -10x+4}{x}',2],[r'\frac{2x-1}{\sqrt{x}}',4],
            [r'\frac{1-x}{(3-x)^2}',3],[r'\frac{7}{x^2-6x+9}',3],[r'\frac{x-1}{x^2}',0],
            [r'\frac{x^2-x-2}{3x^2+12x+12}',2], 
            #[r'\frac{3x^2}{2-x}',oo],
            [r'\frac{x-1}{\sqrt{x}-1}',1]
         ]
        

# vectores iniciales correspondientes al texto del enunciado

n_ejercicio = 'e5'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula los siguientes límites:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$'+latex(Limit((parse_latex(t[0])),x,t[1],dir='+-'))+r'$')
    enunciado.append(Limit(parse_latex(t[0]),x,t[1],dir='+-'))
    # voy por aquí

    sol=r"$"+latex(limit(eval(str(parse_latex(t[0]))),x,t[1],dir='+-'))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '3', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula los siguientes límites:
# **
# $\lim_{x \to 3}\left(\left(x^{2} - 3 x\right) - 1\right)$ $ \rightarrow $$-1$
# $\lim_{x \to 2}\left(\frac{\left(x^{2} - 10 x\right) + 4}{x}\right)$ $ \rightarrow $$-6$
# $\lim_{x \to 4}\left(\frac{2 x - 1}{\sqrt{x}}\right)$ $ \rightarrow $$\frac{7}{2}$
# $\lim_{x \to 3}\left(\frac{1 - x}{\left(3 - x\right)^{2}}\right)$ $ \rightarrow $$-\infty$
# $\lim_{x \to 3}\left(\frac{7}{\left(x^{2} - 6 x\right) + 9}\right)$ $ \rightarrow $$\infty$
# $\lim_{x \to 0}\left(\frac{x - 1}{x^{2}}\right)$ $ \rightarrow $$-\infty$
# $\lim_{x \to 2}\left(\frac{\left(x^{2} - x\right) - 2}{\left(3 x^{2} + 12 x\right) + 12}\right)$ $ \rightarrow $$0$
# $\lim_{x \to 1}\left(\frac{x - 1}{\sqrt{x} - 1}\right)$ $ \rightarrow $$2$

# %%
df_ejercicios
# Out:
#                                       enunciado_latex  \
# 0                                         $f(x)=0x+3$
# 1                                   $f(x)=x^3-5x^2+2$
# 2                      $f(x)=\frac{{x - 3}}{{x + 2}}$
# 3                                         $f(x)=2x-3$
# 4                              $f(x)=2-\frac{2}{x-1}$
# 5                $f(x)=\sqrt[3]{\frac{x + 2}{x - 3}}$
# 6         $f(x)=\sqrt {\frac{x}{2 x^{2} + 2 x - 12}}$
# 7                                $f(x)=\sqrt {x^2-9}$
# 8                                         $g \circ f$
# 9                                         $f \circ g$
# 10                                $h \circ g \circ f$
# 11                                     $f(x)=5 x - 1$
# 12                         $f(x)=\frac{x + 1}{2 - x}$
# 13  $\lim_{x \to 3}\left(\left(x^{2} - 3 x\right) ...
# 14  $\lim_{x \to 2}\left(\frac{\left(x^{2} - 10 x\...
# 15  $\lim_{x \to 4}\left(\frac{2 x - 1}{\sqrt{x}}\...
# 16  $\lim_{x \to 3}\left(\frac{1 - x}{\left(3 - x\...
# 17  $\lim_{x \to 3}\left(\frac{7}{\left(x^{2} - 6 ...
# 18   $\lim_{x \to 0}\left(\frac{x - 1}{x^{2}}\right)$
# 19  $\lim_{x \to 2}\left(\frac{\left(x^{2} - x\rig...
# 20  $\lim_{x \to 1}\left(\frac{x - 1}{\sqrt{x} - 1...
#
#                                             enunciado  \
# 0                                             0*x + 3
# 1                                   x**3 - 5*x**2 + 2
# 2                                     (x - 3)/(x + 2)
# 3                                             2*x - 3
# 4                                       2 - 2/(x - 1)
# 5                            ((x + 2)/(x - 3))**(1/3)
# 6                         sqrt(x/(2*x**2 + 2*x - 12))
# 7                                      sqrt(x**2 - 9)
# 8                                             g(f(x))
# 9                                             f(g(x))
# 10                                         h(g(f(x)))
# 11                                               5x-1
# 12                            \frac{{1 + x}}{{2 - x}}
# 13              Limit(x**2 - 3*x - 1, x, 3, dir='+-')
# 14         Limit((x**2 - 10*x + 4)/x, x, 2, dir='+-')
# 15           Limit((2*x - 1)/sqrt(x), x, 4, dir='+-')
# 16          Limit((1 - x)/(3 - x)**2, x, 3, dir='+-')
# 17          Limit(7/(x**2 - 6*x + 9), x, 3, dir='+-')
# 18                Limit((x - 1)/x**2, x, 0, dir='+-')
# 19  Limit((x**2 - x - 2)/(3*x**2 + 12*x + 12), x, ...
# 20       Limit((x - 1)/(sqrt(x) - 1), x, 1, dir='+-')
#
#                                              solucion  \
# 0   $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 1   $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 2   $Dom\left(f \right)=\left(-\infty, -2\right) \...
# 3   $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 4   $Dom\left(f \right)=\left(-\infty, 1\right) \c...
# 5   $Dom\left(f \right)=\left(-\infty, 3\right) \c...
# 6   $Dom\left(f \right)=\left(-\infty, -3\right) \...
# 7   $Dom\left(f \right)=\left(-\infty, -3\right] \...
# 8   $g{\left(f{\left(x \right)} \right)}=\frac{x^{...
# 9   $f{\left(g{\left(x \right)} \right)}=\frac{\le...
# 10  $h{\left(g{\left(f{\left(x \right)} \right)} \...
# 11  $f^{-1}(x)=\frac{x}{5} + \frac{1}{5}$ \\ $f^{-...
# 12  $f^{-1}(x)=\frac{2 x - 1}{x + 1}$ \\ $f^{-1} \...
# 13                                               $-1$
# 14                                               $-6$
# 15                                      $\frac{7}{2}$
# 16                                          $-\infty$
# 17                                           $\infty$
# 18                                          $-\infty$
# 19                                                $0$
# 20                                                $2$
#
#                                                 texto curso            titulo  \
# 0   Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 1   Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 2   Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 3   Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 4   Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 5   Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 6   Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 7   Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 8   Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
# 9   Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
# 10  Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
# 11  Halla la función inversa de $f(x)$, y comprueb...   1BC  Ejercicios 13/05
# 12  Halla la función inversa de $f(x)$, y comprueb...   1BC  Ejercicios 13/05
# 13                  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05
# 14                  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05
# 15                  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05
# 16                  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05
# 17                  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05
# 18                  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05
# 19                  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05
# 20                  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05
#
#    n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 0         e1-0          5          2      1     False    False
# 1         e1-0          5          2      1     False    False
# 2         e1-0          5          2      1     False    False
# 3         e1-0          5          2      1     False    False
# 4         e1-0          5          2      1     False    False
# 5        e1b-0          5          3      1     False    False
# 6        e1b-0          5          3      1     False    False
# 7        e1b-0          5          3      1     False    False
# 8         e3-0          5          3      1     False    False
# 9         e3-0          5          3      1     False    False
# 10        e3-0          5          3      1     False    False
# 11          e4          5          2      1     False    False
# 12          e4          5          2      1     False    False
# 13          e5          5          3      1     False    False
# 14          e5          5          3      1     False    False
# 15          e5          5          3      1     False    False
# 16          e5          5          3      1     False    False
# 17          e5          5          3      1     False    False
# 18          e5          5          3      1     False    False
# 19          e5          5          3      1     False    False
# 20          e5          5          3      1     False    False

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **e1-0
#                   enunciado_latex          enunciado  \
# 0                     $f(x)=0x+3$            0*x + 3
# 1               $f(x)=x^3-5x^2+2$  x**3 - 5*x**2 + 2
# 2  $f(x)=\frac{{x - 3}}{{x + 2}}$    (x - 3)/(x + 2)
# 3                     $f(x)=2x-3$            2*x - 3
# 4          $f(x)=2-\frac{2}{x-1}$      2 - 2/(x - 1)
#
#                                             solucion  \
# 0  $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 1  $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 2  $Dom\left(f \right)=\left(-\infty, -2\right) \...
# 3  $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 4  $Dom\left(f \right)=\left(-\infty, 1\right) \c...
#
#                                                texto curso            titulo  \
# 0  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 1  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 2  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 3  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 4  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
#
#   n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 0        e1-0          5          2      1     False    False
# 1        e1-0          5          2      1     False    False
# 2        e1-0          5          2      1     False    False
# 3        e1-0          5          2      1     False    False
# 4        e1-0          5          2      1     False    False
# **Ejercicio: **e1b-0
#                                enunciado_latex                    enunciado  \
# 5         $f(x)=\sqrt[3]{\frac{x + 2}{x - 3}}$     ((x + 2)/(x - 3))**(1/3)
# 6  $f(x)=\sqrt {\frac{x}{2 x^{2} + 2 x - 12}}$  sqrt(x/(2*x**2 + 2*x - 12))
# 7                         $f(x)=\sqrt {x^2-9}$               sqrt(x**2 - 9)
#
#                                             solucion  \
# 5  $Dom\left(f \right)=\left(-\infty, 3\right) \c...
# 6  $Dom\left(f \right)=\left(-\infty, -3\right) \...
# 7  $Dom\left(f \right)=\left(-\infty, -3\right] \...
#
#                                                texto curso            titulo  \
# 5  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 6  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 7  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
#
#   n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 5       e1b-0          5          3      1     False    False
# 6       e1b-0          5          3      1     False    False
# 7       e1b-0          5          3      1     False    False
# **Ejercicio: **e3-0
#         enunciado_latex   enunciado  \
# 8           $g \circ f$     g(f(x))
# 9           $f \circ g$     f(g(x))
# 10  $h \circ g \circ f$  h(g(f(x)))
#
#                                              solucion  \
# 8   $g{\left(f{\left(x \right)} \right)}=\frac{x^{...
# 9   $f{\left(g{\left(x \right)} \right)}=\frac{\le...
# 10  $h{\left(g{\left(f{\left(x \right)} \right)} \...
#
#                                                 texto curso            titulo  \
# 8   Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
# 9   Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
# 10  Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
#
#    n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 8         e3-0          5          3      1     False    False
# 9         e3-0          5          3      1     False    False
# 10        e3-0          5          3      1     False    False
# **Ejercicio: **e4
#                enunciado_latex                enunciado  \
# 11              $f(x)=5 x - 1$                     5x-1
# 12  $f(x)=\frac{x + 1}{2 - x}$  \frac{{1 + x}}{{2 - x}}
#
#                                              solucion  \
# 11  $f^{-1}(x)=\frac{x}{5} + \frac{1}{5}$ \\ $f^{-...
# 12  $f^{-1}(x)=\frac{2 x - 1}{x + 1}$ \\ $f^{-1} \...
#
#                                                 texto curso            titulo  \
# 11  Halla la función inversa de $f(x)$, y comprueb...   1BC  Ejercicios 13/05
# 12  Halla la función inversa de $f(x)$, y comprueb...   1BC  Ejercicios 13/05
#
#    n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 11          e4          5          2      1     False    False
# 12          e4          5          2      1     False    False
# **Ejercicio: **e5
#                                       enunciado_latex  \
# 13  $\lim_{x \to 3}\left(\left(x^{2} - 3 x\right) ...
# 14  $\lim_{x \to 2}\left(\frac{\left(x^{2} - 10 x\...
# 15  $\lim_{x \to 4}\left(\frac{2 x - 1}{\sqrt{x}}\...
# 16  $\lim_{x \to 3}\left(\frac{1 - x}{\left(3 - x\...
# 17  $\lim_{x \to 3}\left(\frac{7}{\left(x^{2} - 6 ...
# 18   $\lim_{x \to 0}\left(\frac{x - 1}{x^{2}}\right)$
# 19  $\lim_{x \to 2}\left(\frac{\left(x^{2} - x\rig...
# 20  $\lim_{x \to 1}\left(\frac{x - 1}{\sqrt{x} - 1...
#
#                                             enunciado       solucion  \
# 13              Limit(x**2 - 3*x - 1, x, 3, dir='+-')           $-1$
# 14         Limit((x**2 - 10*x + 4)/x, x, 2, dir='+-')           $-6$
# 15           Limit((2*x - 1)/sqrt(x), x, 4, dir='+-')  $\frac{7}{2}$
# 16          Limit((1 - x)/(3 - x)**2, x, 3, dir='+-')      $-\infty$
# 17          Limit(7/(x**2 - 6*x + 9), x, 3, dir='+-')       $\infty$
# 18                Limit((x - 1)/x**2, x, 0, dir='+-')      $-\infty$
# 19  Limit((x**2 - x - 2)/(3*x**2 + 12*x + 12), x, ...            $0$
# 20       Limit((x - 1)/(sqrt(x) - 1), x, 1, dir='+-')            $2$
#
#                                 texto curso            titulo n_ejercicio  \
# 13  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 14  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 15  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 16  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 17  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 18  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 19  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 20  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 13          5          3      1     False    False
# 14          5          3      1     False    False
# 15          5          3      1     False    False
# 16          5          3      1     False    False
# 17          5          3      1     False    False
# 18          5          3      1     False    False
# 19          5          3      1     False    False
# 20          5          3      1     False    False

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **e1-0
#                   enunciado_latex          enunciado  \
# 0                     $f(x)=0x+3$            0*x + 3
# 1               $f(x)=x^3-5x^2+2$  x**3 - 5*x**2 + 2
# 2  $f(x)=\frac{{x - 3}}{{x + 2}}$    (x - 3)/(x + 2)
# 3                     $f(x)=2x-3$            2*x - 3
# 4          $f(x)=2-\frac{2}{x-1}$      2 - 2/(x - 1)
#
#                                             solucion  \
# 0  $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 1  $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 2  $Dom\left(f \right)=\left(-\infty, -2\right) \...
# 3  $Dom\left(f \right)=\mathbb{R}$\\ \resizebox{0...
# 4  $Dom\left(f \right)=\left(-\infty, 1\right) \c...
#
#                                                texto curso            titulo  \
# 0  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 1  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 2  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 3  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 4  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
#
#   n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 0        e1-0          5          2      1     False    False
# 1        e1-0          5          2      1     False    False
# 2        e1-0          5          2      1     False    False
# 3        e1-0          5          2      1     False    False
# 4        e1-0          5          2      1     False    False
# **Ejercicio: **e1b-0
#                                enunciado_latex                    enunciado  \
# 5         $f(x)=\sqrt[3]{\frac{x + 2}{x - 3}}$     ((x + 2)/(x - 3))**(1/3)
# 6  $f(x)=\sqrt {\frac{x}{2 x^{2} + 2 x - 12}}$  sqrt(x/(2*x**2 + 2*x - 12))
# 7                         $f(x)=\sqrt {x^2-9}$               sqrt(x**2 - 9)
#
#                                             solucion  \
# 5  $Dom\left(f \right)=\left(-\infty, 3\right) \c...
# 6  $Dom\left(f \right)=\left(-\infty, -3\right) \...
# 7  $Dom\left(f \right)=\left(-\infty, -3\right] \...
#
#                                                texto curso            titulo  \
# 5  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 6  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
# 7  Halla analíticamente el dominio de las siguien...   1BC  Ejercicios 13/05
#
#   n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 5       e1b-0          5          3      1     False    False
# 6       e1b-0          5          3      1     False    False
# 7       e1b-0          5          3      1     False    False
# **Ejercicio: **e3-0
#         enunciado_latex   enunciado  \
# 8           $g \circ f$     g(f(x))
# 9           $f \circ g$     f(g(x))
# 10  $h \circ g \circ f$  h(g(f(x)))
#
#                                              solucion  \
# 8   $g{\left(f{\left(x \right)} \right)}=\frac{x^{...
# 9   $f{\left(g{\left(x \right)} \right)}=\frac{\le...
# 10  $h{\left(g{\left(f{\left(x \right)} \right)} \...
#
#                                                 texto curso            titulo  \
# 8   Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
# 9   Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
# 10  Dadas las funciones $f(x)= x^2+4$, $g(x)= \fra...   1BC  Ejercicios 13/05
#
#    n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 8         e3-0          5          3      1     False    False
# 9         e3-0          5          3      1     False    False
# 10        e3-0          5          3      1     False    False
# **Ejercicio: **e4
#                enunciado_latex                enunciado  \
# 11              $f(x)=5 x - 1$                     5x-1
# 12  $f(x)=\frac{x + 1}{2 - x}$  \frac{{1 + x}}{{2 - x}}
#
#                                              solucion  \
# 11  $f^{-1}(x)=\frac{x}{5} + \frac{1}{5}$ \\ $f^{-...
# 12  $f^{-1}(x)=\frac{2 x - 1}{x + 1}$ \\ $f^{-1} \...
#
#                                                 texto curso            titulo  \
# 11  Halla la función inversa de $f(x)$, y comprueb...   1BC  Ejercicios 13/05
# 12  Halla la función inversa de $f(x)$, y comprueb...   1BC  Ejercicios 13/05
#
#    n_ejercicio dificultad n_columnas puntos  enun_tex  sol_tex
# 11          e4          5          2      1     False    False
# 12          e4          5          2      1     False    False
# **Ejercicio: **e5
#                                       enunciado_latex  \
# 13  $\lim_{x \to 3}\left(\left(x^{2} - 3 x\right) ...
# 14  $\lim_{x \to 2}\left(\frac{\left(x^{2} - 10 x\...
# 15  $\lim_{x \to 4}\left(\frac{2 x - 1}{\sqrt{x}}\...
# 16  $\lim_{x \to 3}\left(\frac{1 - x}{\left(3 - x\...
# 17  $\lim_{x \to 3}\left(\frac{7}{\left(x^{2} - 6 ...
# 18   $\lim_{x \to 0}\left(\frac{x - 1}{x^{2}}\right)$
# 19  $\lim_{x \to 2}\left(\frac{\left(x^{2} - x\rig...
# 20  $\lim_{x \to 1}\left(\frac{x - 1}{\sqrt{x} - 1...
#
#                                             enunciado       solucion  \
# 13              Limit(x**2 - 3*x - 1, x, 3, dir='+-')           $-1$
# 14         Limit((x**2 - 10*x + 4)/x, x, 2, dir='+-')           $-6$
# 15           Limit((2*x - 1)/sqrt(x), x, 4, dir='+-')  $\frac{7}{2}$
# 16          Limit((1 - x)/(3 - x)**2, x, 3, dir='+-')      $-\infty$
# 17          Limit(7/(x**2 - 6*x + 9), x, 3, dir='+-')       $\infty$
# 18                Limit((x - 1)/x**2, x, 0, dir='+-')      $-\infty$
# 19  Limit((x**2 - x - 2)/(3*x**2 + 12*x + 12), x, ...            $0$
# 20       Limit((x - 1)/(sqrt(x) - 1), x, 1, dir='+-')            $2$
#
#                                 texto curso            titulo n_ejercicio  \
# 13  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 14  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 15  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 16  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 17  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 18  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 19  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
# 20  Calcula los siguientes límites:\n   1BC  Ejercicios 13/05          e5
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 13          5          3      1     False    False
# 14          5          3      1     False    False
# 15          5          3      1     False    False
# 16          5          3      1     False    False
# 17          5          3      1     False    False
# 18          5          3      1     False    False
# 19          5          3      1     False    False
# 20          5          3      1     False    False
