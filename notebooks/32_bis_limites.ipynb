# %%
from sympy import init_session
from sympy import div, QQ
from sympy.parsing.latex import parse_latex
from sympy.parsing.sympy_parser import parse_expr
from IPython.display import Markdown as md
from IPython.display import display
import pandas as pd

import numpy as np




init_session()

a, b, c, d = symbols('a b c d', real = True)
from docparts import añadir_ejercicios, doc_ejer, escribir_preambulo, escribir_ejercicios, escribir_fin

df_ejercicios = pd.DataFrame()

fichero = 'rep_lim'
titulo = 'Repaso de límites'
curso = '1BC'


x,y = symbols('x, y', real=True)

import matplotlib.pyplot as plt
from matplotlib import style
#style.use('ggplot')
style.use('seaborn-whitegrid')


# %matplotlib inline
# Out:
# IPython console for SymPy 1.4 (Python 3.6.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.4/

# %%
puntuacion = '1'                          
                      
datos =  [  
            [(3*x**2 - 7*x + 12)/(x**2-10*x+4),oo],
            [((2*x**2 -3)*(2*x-1))/(4*x**3-2*x*2+1),oo],
            [(x**3+1)/(x**2+2*x+1),-1],
            [(x**2-1)/(x**2+3*x+2),-1],
            [(1/(1-x)-3/(1-x**2)),1],
            [(2*x**3+6*x**2-3*x)/(2*x**2+5*x),0],
            [(2*x**3+6*x**2-3*x)/(2*x**2+5*x),oo],
            [(2*x**3+6*x**2-3*x)/(2*x**2+5*x),-oo],
            [((4*x**2-x)/(3*x**2+x))**(x/(1-x)),-oo],
            [sqrt(x**3+1)-x,oo],
            [sqrt(x**2+x+4)-x,oo],
            [((x**2+3)/(3*x**2-5))**(x**2/(2-x)),oo],
            [((x**3+1)/(x**2+1))**(3/(x-1)),1],
            [(x-1)**(1/(x-2)),2],
    
         ]
        

# vectores iniciales correspondientes al texto del enunciado

n_ejercicio = 'Ejercicios: '
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula los siguientes límites:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$$'+latex(Limit(t[0],x,t[1],dir='+-'))+r'$$')
    enunciado.append(Limit(t[0],x,t[1],dir='+-'))
   
    
    if  limit(t[0],x,t[1],dir='-') == limit(t[0],x,t[1],dir='+'):      
        sol=r"$"+latex(limit(t[0],x,t[1],dir='+-'))+r"$"
    else:
        sol = r"No existe el límite"
    
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '3', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula los siguientes límites:
# **
# $$\lim_{x \to \infty}\left(\frac{3 x^{2} - 7 x + 12}{x^{2} - 10 x + 4}\right)$$ $ \rightarrow $$3$
# $$\lim_{x \to \infty}\left(\frac{\left(2 x - 1\right) \left(2 x^{2} - 3\right)}{4 x^{3} - 4 x + 1}\right)$$ $ \rightarrow $$1$
# $$\lim_{x \to -1}\left(\frac{x^{3} + 1}{x^{2} + 2 x + 1}\right)$$ $ \rightarrow $No existe el límite
# $$\lim_{x \to -1}\left(\frac{x^{2} - 1}{x^{2} + 3 x + 2}\right)$$ $ \rightarrow $$-2$
# $$\lim_{x \to 1}\left(- \frac{3}{1 - x^{2}} + \frac{1}{1 - x}\right)$$ $ \rightarrow $No existe el límite
# $$\lim_{x \to 0}\left(\frac{2 x^{3} + 6 x^{2} - 3 x}{2 x^{2} + 5 x}\right)$$ $ \rightarrow $$- \frac{3}{5}$
# $$\lim_{x \to \infty}\left(\frac{2 x^{3} + 6 x^{2} - 3 x}{2 x^{2} + 5 x}\right)$$ $ \rightarrow $$\infty$
# $$\lim_{x \to -\infty}\left(\frac{2 x^{3} + 6 x^{2} - 3 x}{2 x^{2} + 5 x}\right)$$ $ \rightarrow $$-\infty$
# $$\lim_{x \to -\infty} \left(\frac{4 x^{2} - x}{3 x^{2} + x}\right)^{\frac{x}{1 - x}}$$ $ \rightarrow $$\frac{3}{4}$
# $$\lim_{x \to \infty}\left(- x + \sqrt{x^{3} + 1}\right)$$ $ \rightarrow $$\infty$
# $$\lim_{x \to \infty}\left(- x + \sqrt{x^{2} + x + 4}\right)$$ $ \rightarrow $$\frac{1}{2}$
# $$\lim_{x \to \infty} \left(\frac{x^{2} + 3}{3 x^{2} - 5}\right)^{\frac{x^{2}}{2 - x}}$$ $ \rightarrow $$\infty$
# $$\lim_{x \to 1} \left(\frac{x^{3} + 1}{x^{2} + 1}\right)^{\frac{3}{x - 1}}$$ $ \rightarrow $$e^{\frac{3}{2}}$
# $$\lim_{x \to 2} \left(x - 1\right)^{\frac{1}{x - 2}}$$ $ \rightarrow $$e$

# %%
puntuacion = '1'                          
                      
datos =  [  
            [(2*x**2+7*x+6)/(x**3+3*x**2+3*x+2),-2],
            [(x**3+1)/(x**2+2*x+1),-1],
            [((3*x-1)/(3*x-2))**(2*x),oo],
    
         ]
        

# vectores iniciales correspondientes al texto del enunciado

n_ejercicio = 'Ejercicios2: '
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula los siguientes límites:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$$'+latex(Limit(t[0],x,t[1],dir='+-'))+r'$$')
    enunciado.append(Limit(t[0],x,t[1],dir='+-'))
   
    
    if  limit(t[0],x,t[1],dir='-') == limit(t[0],x,t[1],dir='+'):      
        sol=r"$"+latex(limit(t[0],x,t[1],dir='+-'))+r"$"
    else:
        sol = r"No existe el límite"
    
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '3', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula los siguientes límites:
# **
# $$\lim_{x \to -2}\left(\frac{2 x^{2} + 7 x + 6}{x^{3} + 3 x^{2} + 3 x + 2}\right)$$ $ \rightarrow $$- \frac{1}{3}$
# $$\lim_{x \to \infty} \left(\frac{3 x - 1}{3 x - 2}\right)^{2 x}$$ $ \rightarrow $$e^{\frac{2}{3}}$

# %%
df_ejercicios
# Out:
#                                       enunciado_latex  \
# 0   $$\lim_{x \to \infty}\left(\frac{2 x^{2} - 14 ...
# 1   $$\lim_{x \to \infty}\left(\frac{\left(5 x - 4...
# 2   $$\lim_{x \to -1}\left(\frac{x^{3} + 1}{x^{2} ...
# 3   $$\lim_{x \to -1}\left(\frac{x^{2} - 1}{x^{2} ...
# 4   $$\lim_{x \to a}\left(\frac{- a^{2} - 2 a x + ...
# 5   $$\lim_{x \to 1}\left(- \frac{3}{1 - x^{2}} + ...
# 6   $$\lim_{x \to 0}\left(\frac{2 x^{3} + 6 x^{2} ...
# 7   $$\lim_{x \to \infty}\left(\frac{2 x^{3} + 6 x...
# 8   $$\lim_{x \to -\infty}\left(\frac{2 x^{3} + 6 ...
# 9   $$\lim_{x \to -\infty} \left(\frac{4 x^{2} - x...
# 10  $$\lim_{x \to \infty}\left(- x + \sqrt{x^{3} +...
# 11  $$\lim_{x \to \infty}\left(- x + \sqrt{x^{2} +...
# 12  $$\lim_{x \to \infty} \left(\frac{x^{2} + 3}{3...
# 13  $$\lim_{x \to 1} \left(\frac{x^{3} + 1}{x^{2} ...
# 14  $$\lim_{x \to 2} \left(x - 1\right)^{\frac{1}{...
#
#                                             enunciado             solucion  \
# 0   Limit((2*x**2 - 14*x + 12)/(x**2 - 10*x + 4), ...                  $2$
# 1   Limit((5*x - 4)*(2*x**2 - 3)/(2*x**3 - 4*x + 1...                  $5$
# 2   Limit((x**3 + 1)/(x**2 + 2*x + 1), x, -1, dir=...  No existe el límite
# 3   Limit((x**2 - 1)/(x**2 + 3*x + 2), x, -1, dir=...                 $-2$
# 4   Limit((-a**2 - 2*a*x + 3*x**2)/(a**2 - 3*a*x +...                  $4$
# 5    Limit(-3/(1 - x**2) + 1/(1 - x), x, 1, dir='+-')  No existe el límite
# 6   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...      $- \frac{3}{5}$
# 7   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...             $\infty$
# 8   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...            $-\infty$
# 9   Limit(((4*x**2 - x + 3)/(3*x**2 + x - 3))**(x/...        $\frac{3}{4}$
# 10     Limit(-x + sqrt(x**3 + x + 1), x, oo, dir='-')             $\infty$
# 11     Limit(-x + sqrt(x**2 + x + 1), x, oo, dir='-')        $\frac{1}{2}$
# 12  Limit(((x**2 + 3)/(3*x**2 - 5))**(x**2/(2 - x)...             $\infty$
# 13  Limit(((x**3 + 1)/(x**2 + 1))**(3/(x - 1)), x,...    $e^{\frac{3}{2}}$
# 14        Limit((x - 1)**(1/(x - 2)), x, 2, dir='+-')                  $e$
#
#                                 texto curso             titulo   n_ejercicio  \
# 0   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 1   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 2   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 3   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 4   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 5   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 6   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 7   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 8   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 9   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 10  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 11  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 12  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 13  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 14  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 0           5          3      1     False    False
# 1           5          3      1     False    False
# 2           5          3      1     False    False
# 3           5          3      1     False    False
# 4           5          3      1     False    False
# 5           5          3      1     False    False
# 6           5          3      1     False    False
# 7           5          3      1     False    False
# 8           5          3      1     False    False
# 9           5          3      1     False    False
# 10          5          3      1     False    False
# 11          5          3      1     False    False
# 12          5          3      1     False    False
# 13          5          3      1     False    False
# 14          5          3      1     False    False

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **Ejercicios:
#                                       enunciado_latex  \
# 0   $$\lim_{x \to \infty}\left(\frac{2 x^{2} - 14 ...
# 1   $$\lim_{x \to \infty}\left(\frac{\left(5 x - 4...
# 2   $$\lim_{x \to -1}\left(\frac{x^{3} + 1}{x^{2} ...
# 3   $$\lim_{x \to -1}\left(\frac{x^{2} - 1}{x^{2} ...
# 4   $$\lim_{x \to a}\left(\frac{- a^{2} - 2 a x + ...
# 5   $$\lim_{x \to 1}\left(- \frac{3}{1 - x^{2}} + ...
# 6   $$\lim_{x \to 0}\left(\frac{2 x^{3} + 6 x^{2} ...
# 7   $$\lim_{x \to \infty}\left(\frac{2 x^{3} + 6 x...
# 8   $$\lim_{x \to -\infty}\left(\frac{2 x^{3} + 6 ...
# 9   $$\lim_{x \to -\infty} \left(\frac{4 x^{2} - x...
# 10  $$\lim_{x \to \infty}\left(- x + \sqrt{x^{3} +...
# 11  $$\lim_{x \to \infty}\left(- x + \sqrt{x^{2} +...
# 12  $$\lim_{x \to \infty} \left(\frac{x^{2} + 3}{3...
# 13  $$\lim_{x \to 1} \left(\frac{x^{3} + 1}{x^{2} ...
# 14  $$\lim_{x \to 2} \left(x - 1\right)^{\frac{1}{...
#
#                                             enunciado             solucion  \
# 0   Limit((2*x**2 - 14*x + 12)/(x**2 - 10*x + 4), ...                  $2$
# 1   Limit((5*x - 4)*(2*x**2 - 3)/(2*x**3 - 4*x + 1...                  $5$
# 2   Limit((x**3 + 1)/(x**2 + 2*x + 1), x, -1, dir=...  No existe el límite
# 3   Limit((x**2 - 1)/(x**2 + 3*x + 2), x, -1, dir=...                 $-2$
# 4   Limit((-a**2 - 2*a*x + 3*x**2)/(a**2 - 3*a*x +...                  $4$
# 5    Limit(-3/(1 - x**2) + 1/(1 - x), x, 1, dir='+-')  No existe el límite
# 6   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...      $- \frac{3}{5}$
# 7   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...             $\infty$
# 8   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...            $-\infty$
# 9   Limit(((4*x**2 - x + 3)/(3*x**2 + x - 3))**(x/...        $\frac{3}{4}$
# 10     Limit(-x + sqrt(x**3 + x + 1), x, oo, dir='-')             $\infty$
# 11     Limit(-x + sqrt(x**2 + x + 1), x, oo, dir='-')        $\frac{1}{2}$
# 12  Limit(((x**2 + 3)/(3*x**2 - 5))**(x**2/(2 - x)...             $\infty$
# 13  Limit(((x**3 + 1)/(x**2 + 1))**(3/(x - 1)), x,...    $e^{\frac{3}{2}}$
# 14        Limit((x - 1)**(1/(x - 2)), x, 2, dir='+-')                  $e$
#
#                                 texto curso             titulo   n_ejercicio  \
# 0   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 1   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 2   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 3   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 4   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 5   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 6   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 7   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 8   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 9   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 10  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 11  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 12  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 13  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 14  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 0           5          3      1     False    False
# 1           5          3      1     False    False
# 2           5          3      1     False    False
# 3           5          3      1     False    False
# 4           5          3      1     False    False
# 5           5          3      1     False    False
# 6           5          3      1     False    False
# 7           5          3      1     False    False
# 8           5          3      1     False    False
# 9           5          3      1     False    False
# 10          5          3      1     False    False
# 11          5          3      1     False    False
# 12          5          3      1     False    False
# 13          5          3      1     False    False
# 14          5          3      1     False    False

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **Ejercicios:
#                                       enunciado_latex  \
# 0   $$\lim_{x \to \infty}\left(\frac{2 x^{2} - 14 ...
# 1   $$\lim_{x \to \infty}\left(\frac{\left(5 x - 4...
# 2   $$\lim_{x \to -1}\left(\frac{x^{3} + 1}{x^{2} ...
# 3   $$\lim_{x \to -1}\left(\frac{x^{2} - 1}{x^{2} ...
# 4   $$\lim_{x \to a}\left(\frac{- a^{2} - 2 a x + ...
# 5   $$\lim_{x \to 1}\left(- \frac{3}{1 - x^{2}} + ...
# 6   $$\lim_{x \to 0}\left(\frac{2 x^{3} + 6 x^{2} ...
# 7   $$\lim_{x \to \infty}\left(\frac{2 x^{3} + 6 x...
# 8   $$\lim_{x \to -\infty}\left(\frac{2 x^{3} + 6 ...
# 9   $$\lim_{x \to -\infty} \left(\frac{4 x^{2} - x...
# 10  $$\lim_{x \to \infty}\left(- x + \sqrt{x^{3} +...
# 11  $$\lim_{x \to \infty}\left(- x + \sqrt{x^{2} +...
# 12  $$\lim_{x \to \infty} \left(\frac{x^{2} + 3}{3...
# 13  $$\lim_{x \to 1} \left(\frac{x^{3} + 1}{x^{2} ...
# 14  $$\lim_{x \to 2} \left(x - 1\right)^{\frac{1}{...
#
#                                             enunciado             solucion  \
# 0   Limit((2*x**2 - 14*x + 12)/(x**2 - 10*x + 4), ...                  $2$
# 1   Limit((5*x - 4)*(2*x**2 - 3)/(2*x**3 - 4*x + 1...                  $5$
# 2   Limit((x**3 + 1)/(x**2 + 2*x + 1), x, -1, dir=...  No existe el límite
# 3   Limit((x**2 - 1)/(x**2 + 3*x + 2), x, -1, dir=...                 $-2$
# 4   Limit((-a**2 - 2*a*x + 3*x**2)/(a**2 - 3*a*x +...                  $4$
# 5    Limit(-3/(1 - x**2) + 1/(1 - x), x, 1, dir='+-')  No existe el límite
# 6   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...      $- \frac{3}{5}$
# 7   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...             $\infty$
# 8   Limit((2*x**3 + 6*x**2 - 3*x)/(2*x**2 + 5*x), ...            $-\infty$
# 9   Limit(((4*x**2 - x + 3)/(3*x**2 + x - 3))**(x/...        $\frac{3}{4}$
# 10     Limit(-x + sqrt(x**3 + x + 1), x, oo, dir='-')             $\infty$
# 11     Limit(-x + sqrt(x**2 + x + 1), x, oo, dir='-')        $\frac{1}{2}$
# 12  Limit(((x**2 + 3)/(3*x**2 - 5))**(x**2/(2 - x)...             $\infty$
# 13  Limit(((x**3 + 1)/(x**2 + 1))**(3/(x - 1)), x,...    $e^{\frac{3}{2}}$
# 14        Limit((x - 1)**(1/(x - 2)), x, 2, dir='+-')                  $e$
#
#                                 texto curso             titulo   n_ejercicio  \
# 0   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 1   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 2   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 3   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 4   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 5   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 6   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 7   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 8   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 9   Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 10  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 11  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 12  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 13  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
# 14  Calcula los siguientes límites:\n   1BC  Repaso de límites  Ejercicios:
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 0           5          3      1     False    False
# 1           5          3      1     False    False
# 2           5          3      1     False    False
# 3           5          3      1     False    False
# 4           5          3      1     False    False
# 5           5          3      1     False    False
# 6           5          3      1     False    False
# 7           5          3      1     False    False
# 8           5          3      1     False    False
# 9           5          3      1     False    False
# 10          5          3      1     False    False
# 11          5          3      1     False    False
# 12          5          3      1     False    False
# 13          5          3      1     False    False
# 14          5          3      1     False    False
