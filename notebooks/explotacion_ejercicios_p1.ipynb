# %%
import pandas as pd
import numpy as np
from docparts import escribir_ejercicios, escribir_fin, escribir_preambulo, generar_tex, exportar_pdf
from IPython.display import Markdown as md
from IPython.display import display
import string
import random

# %%
df = pd.read_csv('ejercicios_parcial1.csv', index_col=False)

# %%
df
# Out:
#                                       enunciado_latex  \
# 0   A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
# 1   A=\left\{ x \in \mathbb{R}| 3 \leq x \wedge x ...
# 2                  {\binom{23}{x}} = \binom{23}{3x-1}
# 3               {\binom{39}{5+2x}} = \binom{39}{2x-2}
# 4                   {\binom{15}{x}} = \binom{15}{x+1}
# 5                                 {\binom{x}{2}} = 21
# 6                                 {\binom{x}{2}} = 28
# 7                             {\binom{x}{x - 2}} = 10
# 8                             {\binom{x}{x - 2}} = 28
# 9   {\binom{11}{3}} = {\binom{12}{3}}-{\binom{11}{x}}
# 10  {\binom{33}{x}} = {\binom{33}{x+y}}-{\binom{34...
# 11  {\binom{20}{7}} - {\binom{19}{x}}-{\binom{19}{...
# 12  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
# 13  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
# 14  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
# 15  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
# 16   P(x)=\left(3 x^{2} - \frac{3}{x}\right)^{10} \,
# 17  P(x)=\left(3 x^{2} - \frac{1}{3 x}\right)^{10}...
# 18                P(x)=\left(x^{2} + x\right)^{4} \,
# 19  \frac{{\sqrt [6]{27} \sqrt {\sqrt [3]{3} } }}{...
# 20  3\sqrt [3] {16} - 2\sqrt [3] {250} + 5\sqrt [3...
# 21  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
# 22  \frac{\sqrt{7}-\sqrt{5}}{\sqrt{7}+\sqrt{5}}-\f...
# 23  \frac{\sqrt{3}}{\sqrt{3}-\sqrt{2}}-\frac{\sqrt...
# 24  El \ resto \ de \ dividir \ P(x)=x^{27}-kx+3k-...
# 25  El \ resto \ de \ dividir \ P(x)=x^{27}-kx+3k-...
# 26  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
# 27  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
# 28  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
# 29  P(x)=x^2+mx-16 \ tenga\ dos \ ra\acute \imath ...
# 30  P(x)=\frac{x^2}{9}+mx+\frac{9}{25} \ tenga\ do...
# 31  P(x)=\frac{x^2}{25}-mx+\frac{4}{9} \ tenga\ do...
# 32  P(x)=4x^2-mx+9 \ tenga\ una \ ra \acute \imath...
# 33  P(x)=\frac{x^2}{16}-mx+\frac{9}{4} \ tenga\ un...
# 34  P(x)=\frac{x^2}{4}-mx+\frac{1}{16} \ tenga\ un...
# 35  P(x)=4x^2+mx+9 \ no \ tenga\ ninguna \ ra \acu...
# 36  P(x)=9x^2-mx+\frac{1}{4} \ no \ tenga\ ninguna...
# 37  P(x)=16x^2-mx+\frac{9}{4} \ no \ tenga\ ningun...
# 38   A(x)= x^5+x^4-7x^3+x^2+10x-6\  y \\  B(x)= x^...
# 39   A(x)= x^{5} - 6 x^{3} + 2 x^{2} + 9 x - 6\  y...
# 40   A(x)= x^{5} - 2 x^{4} - 5 x^{3} + 10 x^{2} + ...
#
#                                             enunciado  \
# 0   [Interval(-2, 5), Union(Interval.open(-oo, -1)...
# 1   [Interval.Ropen(3, 8), Union(Interval.open(-oo...
# 2          Eq(binomial(23, x), binomial(23, 3*x - 1))
# 3    Eq(binomial(39, 2*x + 5), binomial(39, 2*x - 2))
# 4            Eq(binomial(15, x), binomial(15, x + 1))
# 5                              Eq(binomial(x, 2), 21)
# 6                              Eq(binomial(x, 2), 28)
# 7                          Eq(binomial(x, x - 2), 10)
# 8                          Eq(binomial(x, x - 2), 28)
# 9                                       Eq(-x + 3, 1)
# 10                           [Eq(y, 1), Eq(x + y, 5)]
# 11                                       Eq(x + 1, 7)
# 12                          ((2*x - 3/x)**8, x**(-8))
# 13                       ((3*x**2 + 1/x)**7, x**(-4))
# 14                          ((2*x - 3/x)**8, x**(-2))
# 15                          ((3*x**2 + 1/x)**7, x**5)
# 16              ((3*x**2 - 3/x)**10, -14880348*x**10)
# 17             ((3*x**2 - 1/(3*x))**10, -61236*x**10)
# 18                            ((x**2 + x)**4, 6*x**6)
# 19                        (3**(1/6)*sqrt(3))/3**(2/5)
# 20  -4*2**(1/3) - 10*2**(1/3) + 3*(2*2**(1/3)) + 5...
# 21  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
# 22  -(sqrt(5) + sqrt(7))/(-sqrt(5) + sqrt(7)) + (-...
# 23  -sqrt(3)/(sqrt(2) + sqrt(3)) + sqrt(3)/(-sqrt(...
# 24  (Poly((3*k - k*x + x**27) - 4, 3*k - k*x + x**...
# 25  (Poly((3*k - k*x + x**27) - 4, 3*k - k*x + x**...
# 26  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...
# 27  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...
# 28  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...
# 29                                    m*x + x**2 - 16
# 30                                m*x + x**2/9 + 9/25
# 31                               -m*x + x**2/25 + 4/9
# 32                                  -m*x + 4*x**2 + 9
# 33                               -m*x + x**2/16 + 9/4
# 34                               -m*x + x**2/4 + 1/16
# 35                                   m*x + 4*x**2 + 9
# 36                                -m*x + 9*x**2 + 1/4
# 37                               -m*x + 16*x**2 + 9/4
# 38  (x**5 + x**4 - 7*x**3 + x**2 + 10*x - 6, x**5 ...
# 39  (x**5 - 6*x**3 + 2*x**2 + 9*x - 6, x**5 + 3*x*...
# 40  (x**5 - 2*x**4 - 5*x**3 + 10*x**2 + 4*x - 8, x...
#
#                                              solucion  \
# 0   A \cup  B = \left(-\infty, \infty\right)  \\  ...
# 1   A \cup  B = \left(-\infty, 1\right) \cup \left...
# 2                                    \left\{6\right\}
# 3                                    \left\{9\right\}
# 4                                    \left\{7\right\}
# 5                                    \left\{7\right\}
# 6                                    \left\{8\right\}
# 7                                    \left\{5\right\}
# 8                                    \left\{8\right\}
# 9                                   \left [ 2\right ]
# 10               \left \{ x : 4, \quad y : 1\right \}
# 11                                  \left [ 6\right ]
# 12                                               6561
# 13                                                 21
# 14                                            -108864
# 15                                               2835
# 16                                  - 14880348 x^{10}
# 17                                     - 61236 x^{10}
# 18                                            6 x^{6}
# 19                3^{\frac{4}{15}}\to3^{\frac{4}{15}}
# 20                    17 \sqrt[3]{2}\to17 \sqrt[3]{2}
# 21  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...
# 22  \frac{-12 - 2 \sqrt{35} + \left(- \sqrt{7} + \...
# 23                            2 \sqrt{6}\to2 \sqrt{6}
# 24                                                  4
# 25                                                  4
# 26                                                  4
# 27                                                  3
# 28                                                  3
# 29  \left [ 1, \quad m, \quad -16\right ]\to \left...
# 30  \left [ \frac{1}{9}, \quad m, \quad \frac{9}{2...
# 31  \left [ \frac{1}{25}, \quad - m, \quad \frac{4...
# 32  \left [ 4, \quad - m, \quad 9\right ]\to \left...
# 33  \left [ \frac{1}{16}, \quad - m, \quad \frac{9...
# 34  \left [ \frac{1}{4}, \quad - m, \quad \frac{1}...
# 35  \left [ 4, \quad m, \quad 9\right ]\to -12 < m...
# 36  \left [ 9, \quad - m, \quad \frac{1}{4}\right ...
# 37  \left [ 16, \quad - m, \quad \frac{9}{4}\right...
# 38  Descomposici \acute on:(\left(x - 1\right)^{2}...
# 39  Descomposici \acute on:(\left(x - 1\right)^{2}...
# 40  Descomposici \acute on:(\left(x - 2\right)^{2}...
#
#                                                 texto curso     titulo  \
# 0   Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
# 1   Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
# 2   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 3   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 4   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 5   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 6   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 7   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 8   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 9   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 10  Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 11  Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 12  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
# 13  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
# 14  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
# 15  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
# 16  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
# 17  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
# 18  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
# 19                                           Efectúa:   1BC  Parcial 1
# 20                                           Efectúa:   1BC  Parcial 1
# 21                                           Efectúa:   1BC  Parcial 1
# 22                                           Efectúa:   1BC  Parcial 1
# 23                                           Efectúa:   1BC  Parcial 1
# 24                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 25                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 26                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 27                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 28                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 29                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 30                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 31                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 32                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 33                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 34                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 35                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 36                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 37                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 38    Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
# 39    Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
# 40    Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 0      ex01e01           1           3       2
# 1      ex01e01           1           3       2
# 2      ex01e02           1           3       1
# 3      ex01e02           1           3       1
# 4      ex01e02           1           3       1
# 5      ex01e02           1           3       1
# 6      ex01e02           1           3       1
# 7      ex01e02           1           3       1
# 8      ex01e02           1           3       1
# 9      ex01e02           1           3       1
# 10     ex01e02           1           3       1
# 11     ex01e02           1           3       1
# 12     ex01e03           1           3       2
# 13     ex01e03           1           3       2
# 14     ex01e03           1           3       2
# 15     ex01e03           1           3       2
# 16     ex01e04           1           3       2
# 17     ex01e04           1           3       2
# 18     ex01e04           1           3       2
# 19     ex01e05           1           3       1
# 20     ex01e05           1           3       1
# 21     ex01e05           1           3       1
# 22     ex01e05           1           3       1
# 23     ex01e05           1           3       1
# 24     ex01e06           1           3       1
# 25     ex01e06           1           3       1
# 26     ex01e06           1           3       1
# 27     ex01e06           1           3       1
# 28     ex01e06           1           3       1
# 29     ex01e07           1           3       1
# 30     ex01e07           1           3       1
# 31     ex01e07           1           3       1
# 32     ex01e07           1           3       1
# 33     ex01e07           1           3       1
# 34     ex01e07           1           3       1
# 35     ex01e07           1           3       1
# 36     ex01e07           1           3       1
# 37     ex01e07           1           3       1
# 38     ex01e08           1           3       3
# 39     ex01e08           1           3       3
# 40     ex01e08           1           3       3

# %%
df.pivot_table(index = ['n_ejercicio','texto'])
# Out:
#                                                                 dificultad  \
# n_ejercicio texto
# ex01e01     Dados los siguientes conjuntos A, B y C, repres...           1
# ex01e02     Usando la definición y las propiedades de los n...           1
# ex01e03     Calcula, sin hacer todo el desarrollo, el coefi...           1
# ex01e04     Encontrar, sin hacer todo el desarrollo, el tér...           1
# ex01e05     Efectúa:                                                     1
# ex01e06     Calcula el valor de $k$ para que:                            1
# ex01e07     Calcula el valor de $m$ para que:                            1
# ex01e08     Halla el m.c.d. y el m.c.m. de los polinomios:               1
#
#                                                                 n_columnas  \
# n_ejercicio texto
# ex01e01     Dados los siguientes conjuntos A, B y C, repres...           3
# ex01e02     Usando la definición y las propiedades de los n...           3
# ex01e03     Calcula, sin hacer todo el desarrollo, el coefi...           3
# ex01e04     Encontrar, sin hacer todo el desarrollo, el tér...           3
# ex01e05     Efectúa:                                                     3
# ex01e06     Calcula el valor de $k$ para que:                            3
# ex01e07     Calcula el valor de $m$ para que:                            3
# ex01e08     Halla el m.c.d. y el m.c.m. de los polinomios:               3
#
#                                                                 puntos
# n_ejercicio texto
# ex01e01     Dados los siguientes conjuntos A, B y C, repres...       2
# ex01e02     Usando la definición y las propiedades de los n...       1
# ex01e03     Calcula, sin hacer todo el desarrollo, el coefi...       2
# ex01e04     Encontrar, sin hacer todo el desarrollo, el tér...       2
# ex01e05     Efectúa:                                                 1
# ex01e06     Calcula el valor de $k$ para que:                        1
# ex01e07     Calcula el valor de $m$ para que:                        1
# ex01e08     Halla el m.c.d. y el m.c.m. de los polinomios:           3

# %%
# Generador de prueb: Cambia los parámetros 

fichero = 'parcial1'
titulo = 'Parcial 1ª evaluación'
tipo = 'ejerc'

n_pdf = list(string.ascii_uppercase)[:2]

if tipo != 'ejercicios' :
 
    #Construcción de lista de ejercicios
    numero = 2
    lista1 = np.unique(df.n_ejercicio.tolist())
    lista2 =[]
    for i in range(lista1.size) : lista2.append(numero)
    lista = list(zip(lista1,lista2))
    
    # Si queremos poner nuestra propia lista: lista =[('texto_nejercicio',nº de ejercicios)], si no comentar la linea siguiente
    lista = [('ex01e01', 1),('ex01e02', 1),('ex01e03', 1),('ex01e05', 2),('ex01e06', 1),('ex01e08', 1)]
    
    for s in n_pdf:
        random.shuffle(lista)
        df_ejercicios = pd.concat(df.loc[np.random.choice(df[df.n_ejercicio==s[0]].index, s[1], replace=False)] for s in lista)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = False)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = True)

else :
    exportar_pdf(df, fichero, titulo, tipo)
# Out:
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right)  \\  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       2
# **Ejercicio: **ex01e02
#            enunciado_latex                   enunciado          solucion  \
# 7  {\binom{x}{x - 2}} = 10  Eq(binomial(x, x - 2), 10)  \left\{5\right\}
#
#                                                texto curso     titulo  \
# 7  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 7     ex01e02           1           1       1
# **Ejercicio: **ex01e03
#                                       enunciado_latex  \
# 13  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
#
#                        enunciado solucion  \
# 13  ((3*x**2 + 1/x)**7, x**(-4))       21
#
#                                                 texto curso     titulo  \
# 13  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 13     ex01e03           1           1       2
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 23  \frac{\sqrt{3}}{\sqrt{3}-\sqrt{2}}-\frac{\sqrt...
# 22  \frac{\sqrt{7}-\sqrt{5}}{\sqrt{7}+\sqrt{5}}-\f...
#
#                                             enunciado  \
# 23  -sqrt(3)/(sqrt(2) + sqrt(3)) + sqrt(3)/(-sqrt(...
# 22  -(sqrt(5) + sqrt(7))/(-sqrt(5) + sqrt(7)) + (-...
#
#                                              solucion     texto curso  \
# 23                            2 \sqrt{6}\to2 \sqrt{6}  Efectúa:   1BC
# 22  \frac{-12 - 2 \sqrt{35} + \left(- \sqrt{7} + \...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos
# 23  Parcial 1     ex01e05           1           1       1
# 22  Parcial 1     ex01e05           1           1       1
# **Ejercicio: **ex01e06
#                                       enunciado_latex  \
# 26  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
#
#                                             enunciado solucion  \
# 26  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...        4
#
#                                 texto curso     titulo n_ejercicio  \
# 26  Calcula el valor de $k$ para que:   1BC  Parcial 1     ex01e06
#
#     dificultad  n_columnas  puntos
# 26           1           1       1
# **Ejercicio: **ex01e08
#                                       enunciado_latex  \
# 39   A(x)= x^{5} - 6 x^{3} + 2 x^{2} + 9 x - 6\  y...
#
#                                             enunciado  \
# 39  (x**5 - 6*x**3 + 2*x**2 + 9*x - 6, x**5 + 3*x*...
#
#                                              solucion  \
# 39  Descomposici \acute on:(\left(x - 1\right)^{2}...
#
#                                               texto curso     titulo  \
# 39  Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 39     ex01e08           1           1       3
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right)  \\  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       2
# **Ejercicio: **ex01e02
#            enunciado_latex                   enunciado          solucion  \
# 7  {\binom{x}{x - 2}} = 10  Eq(binomial(x, x - 2), 10)  \left\{5\right\}
#
#                                                texto curso     titulo  \
# 7  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 7     ex01e02           1           1       1
# **Ejercicio: **ex01e03
#                                       enunciado_latex  \
# 13  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
#
#                        enunciado solucion  \
# 13  ((3*x**2 + 1/x)**7, x**(-4))       21
#
#                                                 texto curso     titulo  \
# 13  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 13     ex01e03           1           1       2
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 23  \frac{\sqrt{3}}{\sqrt{3}-\sqrt{2}}-\frac{\sqrt...
# 22  \frac{\sqrt{7}-\sqrt{5}}{\sqrt{7}+\sqrt{5}}-\f...
#
#                                             enunciado  \
# 23  -sqrt(3)/(sqrt(2) + sqrt(3)) + sqrt(3)/(-sqrt(...
# 22  -(sqrt(5) + sqrt(7))/(-sqrt(5) + sqrt(7)) + (-...
#
#                                              solucion     texto curso  \
# 23                            2 \sqrt{6}\to2 \sqrt{6}  Efectúa:   1BC
# 22  \frac{-12 - 2 \sqrt{35} + \left(- \sqrt{7} + \...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos
# 23  Parcial 1     ex01e05           1           1       1
# 22  Parcial 1     ex01e05           1           1       1
# **Ejercicio: **ex01e06
#                                       enunciado_latex  \
# 26  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
#
#                                             enunciado solucion  \
# 26  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...        4
#
#                                 texto curso     titulo n_ejercicio  \
# 26  Calcula el valor de $k$ para que:   1BC  Parcial 1     ex01e06
#
#     dificultad  n_columnas  puntos
# 26           1           1       1
# **Ejercicio: **ex01e08
#                                       enunciado_latex  \
# 39   A(x)= x^{5} - 6 x^{3} + 2 x^{2} + 9 x - 6\  y...
#
#                                             enunciado  \
# 39  (x**5 - 6*x**3 + 2*x**2 + 9*x - 6, x**5 + 3*x*...
#
#                                              solucion  \
# 39  Descomposici \acute on:(\left(x - 1\right)^{2}...
#
#                                               texto curso     titulo  \
# 39  Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 39     ex01e08           1           1       3
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right)  \\  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       2
# **Ejercicio: **ex01e02
#                                       enunciado_latex  \
# 10  {\binom{33}{x}} = {\binom{33}{x+y}}-{\binom{34...
#
#                    enunciado                              solucion  \
# 10  [Eq(y, 1), Eq(x + y, 5)]  \left \{ x : 4, \quad y : 1\right \}
#
#                                                 texto curso     titulo  \
# 10  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 10     ex01e02           1           1       1
# **Ejercicio: **ex01e03
#                                       enunciado_latex  \
# 12  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
#
#                     enunciado solucion  \
# 12  ((2*x - 3/x)**8, x**(-8))     6561
#
#                                                 texto curso     titulo  \
# 12  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 12     ex01e03           1           1       2
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 21  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
# 19  \frac{{\sqrt [6]{27} \sqrt {\sqrt [3]{3} } }}{...
#
#                                             enunciado  \
# 21  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
# 19                        (3**(1/6)*sqrt(3))/3**(2/5)
#
#                                              solucion     texto curso  \
# 21  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
# 19                3^{\frac{4}{15}}\to3^{\frac{4}{15}}  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos
# 21  Parcial 1     ex01e05           1           1       1
# 19  Parcial 1     ex01e05           1           1       1
# **Ejercicio: **ex01e06
#                                       enunciado_latex  \
# 27  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
#
#                                             enunciado solucion  \
# 27  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...        3
#
#                                 texto curso     titulo n_ejercicio  \
# 27  Calcula el valor de $k$ para que:   1BC  Parcial 1     ex01e06
#
#     dificultad  n_columnas  puntos
# 27           1           1       1
# **Ejercicio: **ex01e08
#                                       enunciado_latex  \
# 38   A(x)= x^5+x^4-7x^3+x^2+10x-6\  y \\  B(x)= x^...
#
#                                             enunciado  \
# 38  (x**5 + x**4 - 7*x**3 + x**2 + 10*x - 6, x**5 ...
#
#                                              solucion  \
# 38  Descomposici \acute on:(\left(x - 1\right)^{2}...
#
#                                               texto curso     titulo  \
# 38  Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 38     ex01e08           1           1       3
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right)  \\  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       2
# **Ejercicio: **ex01e02
#                                       enunciado_latex  \
# 10  {\binom{33}{x}} = {\binom{33}{x+y}}-{\binom{34...
#
#                    enunciado                              solucion  \
# 10  [Eq(y, 1), Eq(x + y, 5)]  \left \{ x : 4, \quad y : 1\right \}
#
#                                                 texto curso     titulo  \
# 10  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 10     ex01e02           1           1       1
# **Ejercicio: **ex01e03
#                                       enunciado_latex  \
# 12  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
#
#                     enunciado solucion  \
# 12  ((2*x - 3/x)**8, x**(-8))     6561
#
#                                                 texto curso     titulo  \
# 12  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 12     ex01e03           1           1       2
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 21  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
# 19  \frac{{\sqrt [6]{27} \sqrt {\sqrt [3]{3} } }}{...
#
#                                             enunciado  \
# 21  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
# 19                        (3**(1/6)*sqrt(3))/3**(2/5)
#
#                                              solucion     texto curso  \
# 21  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
# 19                3^{\frac{4}{15}}\to3^{\frac{4}{15}}  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos
# 21  Parcial 1     ex01e05           1           1       1
# 19  Parcial 1     ex01e05           1           1       1
# **Ejercicio: **ex01e06
#                                       enunciado_latex  \
# 27  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
#
#                                             enunciado solucion  \
# 27  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...        3
#
#                                 texto curso     titulo n_ejercicio  \
# 27  Calcula el valor de $k$ para que:   1BC  Parcial 1     ex01e06
#
#     dificultad  n_columnas  puntos
# 27           1           1       1
# **Ejercicio: **ex01e08
#                                       enunciado_latex  \
# 38   A(x)= x^5+x^4-7x^3+x^2+10x-6\  y \\  B(x)= x^...
#
#                                             enunciado  \
# 38  (x**5 + x**4 - 7*x**3 + x**2 + 10*x - 6, x**5 ...
#
#                                              solucion  \
# 38  Descomposici \acute on:(\left(x - 1\right)^{2}...
#
#                                               texto curso     titulo  \
# 38  Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 38     ex01e08           1           1       3
