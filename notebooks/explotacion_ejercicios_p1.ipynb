# %%
import pandas as pd
import numpy as np
from docparts import escribir_ejercicios, escribir_fin, escribir_preambulo, generar_tex, exportar_pdf
from IPython.display import Markdown as md
from IPython.display import display
import string

# %%
fichero = 'ejercicios'
n_ficheros = 7


df = pd.concat([pd.read_csv(fichero + str(n + 1)+ '.csv', index_col=False) for n in range(n_ficheros)],sort=True)

df = df.reset_index()

# %%
df = pd.read_csv('ejercicios.csv', index_col=False)

# %%
df
# Out:
#      index curso  dificultad  \
# 0        0   1BC           1
# 1        1   1BC           1
# 2        2   1BC           1
# 3        3   1BC           1
# 4        4   1BC           1
# 5        5   1BC           1
# 6        6   1BC           1
# 7        7   1BC           1
# 8        0   1BC           1
# 9        1   1BC           1
# 10       2   1BC           1
# 11       3   1BC           1
# 12       4   1BC           1
# 13       5   1BC           1
# 14       6   1BC           1
# 15       7   1BC           1
# 16       8   1BC           1
# 17       9   1BC           1
# 18      10   1BC           1
# 19      11   1BC           1
# 20      12   1BC           1
# 21      13   1BC           1
# 22      14   1BC           1
# 23      15   1BC           1
# 24      16   1BC           1
# 25      17   1BC           1
# 26      18   1BC           1
# 27      19   1BC           1
# 28      20   1BC           1
# 29      21   1BC           1
# ..     ...   ...         ...
# 232      2   1BC           1
# 233      3   1BC           1
# 234      4   1BC           1
# 235      5   1BC           1
# 236      6   1BC           1
# 237      7   1BC           1
# 238      8   1BC           1
# 239      9   1BC           1
# 240     10   1BC           1
# 241     11   1BC           1
# 242     12   1BC           1
# 243     13   1BC           1
# 244     14   1BC           1
# 245     15   1BC           1
# 246     16   1BC           1
# 247     17   1BC           1
# 248     18   1BC           1
# 249     19   1BC           1
# 250     20   1BC           1
# 251     21   1BC           1
# 252     22   1BC           1
# 253     23   1BC           1
# 254     24   1BC           1
# 255     25   1BC           1
# 256     26   1BC           1
# 257     27   1BC           1
# 258     28   1BC           1
# 259     29   1BC           1
# 260     30   1BC           1
# 261     31   1BC           1
#
#                                              enunciado  \
# 0                                (Abs(x - 2) - 1, '<')
# 1                              (Abs(2*x + 3) - 4, '<')
# 2                               (Abs(x + 5) - 2, '<=')
# 3                           (Abs(3*x - 2) - 0.5, '<=')
# 4                                (Abs(x - 1) - 2, '>')
# 5                                (Abs(x + 2) - 5, '>')
# 6                             (Abs(2*x - 3) - 1, '>=')
# 7                           (Abs(2*x + 1) - 0.5, '>=')
# 8                       (2**3*(3**5*3**(-2)))/(2*3)**4
# 9                             81*(3**(-5)*(1/3)**(-2))
# 10                                (5/4)**5*(2**6/5**2)
# 11                         (2**(-2)*(2**2)**3)/2**(-3)
# 12                    (5**2*(5**(-3)/5))/(5**0 + 5**6)
# 13                                (2/3)**(-2)*(3/2)**4
# 14   ((sqrt(2)*(sqrt(2))**3)*(sqrt(5))**3)/(5*sqrt(...
# 15                     (2**(3/2)*(9**(1/2)/3))/sqrt(2)
# 16                                                   4
# 17                                       2*(-1)**(1/4)
# 18                                                   3
# 19                                         (-1)**(1/5)
# 20                                                  35
# 21                                                   1
# 22                                        Eq(x**4, 81)
# 23                                       Eq(x**3, 125)
# 24                                        Eq(x**2, -6)
# 25                                        Eq(x**5, -1)
# 26                         9*((3*sqrt(3))*(9*sqrt(3)))
# 27                               (5*5**(1/3))/5**(1/3)
# 28                                       (5**(1/3))**7
# 29                                   2**(1/6)*2**(1/3)
# ..                                                 ...
# 232                           (Abs(2*x + 5) - 2, '<=')
# 233                        (Abs(3*x - 2) - 0.25, '<=')
# 234                            (Abs(2*x - 4) - 2, '>')
# 235                            (Abs(3*x + 4) - 5, '>')
# 236                           (Abs(2*x - 8) - 1, '>=')
# 237                         (Abs(2*x + 6) - 0.5, '>=')
# 238                     (2**3*(3**6*3**(-3)))/(2*3)**5
# 239                         2**7*(2**(-5)*(1/2)**(-2))
# 240                               (7/4)**5*(2**6/7**2)
# 241                        (2**(-2)*(2**2)**3)/2**(-3)
# 242                   (5**2*(5**(-3)/5))/(5**0 + 5**6)
# 243                               (2/5)**(-2)*(5/2)**4
# 244  ((sqrt(2)*(sqrt(2))**3)*(sqrt(5))**3)/(5*sqrt(...
# 245                    (2**(9/2)*(4**(1/2)/2))/sqrt(2)
# 246       -36*sqrt(5) + 3*(2*sqrt(5)) + 2*(25*sqrt(5))
# 247          -9*sqrt(5)/4 - 8*sqrt(5) + (25*sqrt(5))/4
# 248                                         (x + 3)**4
# 249                                 (1 + 3*sqrt(2))**3
# 250                                (-3*sqrt(2) + 2)**3
# 251                                  (x/3 + 3/x**2)**5
# 252                           (2/sqrt(2) + sqrt(2))**3
# 253                        (-2*sqrt(3) + 5*sqrt(2))**3
# 254                                  (2*x**2 - 3/x)**4
# 255                                          A(x)*B(x)
# 256                             A(x) - 3*B(x) + 5*C(x)
# 257                             x**2*A(x) + (3*x)*B(x)
# 258                       -26*x + 2*x**3 - 6*x**2 + 30
# 259                            -12*x + 2*x**3 + 2*x**2
# 260                        -24*x + 6*x**3 + 2*x**2 - 8
# 261                      -2*x**2 + 2*x**5 - 8*x**3 + 8
#
#                                        enunciado_latex  n_columnas  \
# 0                          \left|{x - 2}\right| - 1< 0           3
# 1                        \left|{2 x + 3}\right| - 4< 0           3
# 2                       \left|{x + 5}\right| - 2\leq 0           3
# 3                   \left|{3 x - 2}\right| - 0.5\leq 0           3
# 4                          \left|{x - 1}\right| - 2> 0           3
# 5                          \left|{x + 2}\right| - 5> 0           3
# 6                     \left|{2 x - 3}\right| - 1\geq 0           3
# 7                   \left|{2 x + 1}\right| - 0.5\geq 0           3
# 8    \frac{{{3^{ - 2}} \cdot {3^5} \cdot {2^3}}}{{{...           3
# 9    {3^{ - 5}} \cdot {( {\frac{1}{3}} )^{ - 2}} \c...           3
# 10   {( {\frac{5}{4}} )^5} \cdot \frac{{{2^6}}}{{{5...           3
# 11   \frac{{{2^{ - 2}} \cdot {{( {{2^2}} )}^3}}}{{{...           3
# 12   \frac{{{5^{ - 3}} \cdot {5^{ - 1}} \cdot {5^2}...           3
# 13   {( {\frac{2}{3}} )^{ - 2}} \cdot {( {\frac{3}{...           3
# 14   \frac{{\sqrt {2}  \cdot {{( {\sqrt {2} } )}^3}...           3
# 15   \frac{{{9^{\frac{1}{2}}} \cdot {3^{ - 1}} \cdo...           3
# 16                                          \sqrt {16}           3
# 17                                     \sqrt[4]{ - 16}           3
# 18                                        \sqrt[3]{27}           3
# 19                                        \sqrt[5]{-1}           3
# 20                                        \sqrt {1225}           3
# 21                                         \sqrt[7]{1}           3
# 22                                            x^4 = 81           3
# 23                                           x^3 = 125           3
# 24                                            x^2 = -6           3
# 25                                            x^5 = -1           3
# 26     \sqrt {27}  \cdot \sqrt {243}  \cdot \sqrt {81}           3
# 27          \frac{{\sqrt[3] {625} }}{{\sqrt[3] {5}  }}           3
# 28                                   ({\sqrt[3]{5}})^7           3
# 29                                  \sqrt[3]{\sqrt{8}}           3
# ..                                                 ...         ...
# 232                   \left|{2 x + 5}\right| - 2\leq 0           3
# 233                \left|{3 x - 2}\right| - 0.25\leq 0           3
# 234                      \left|{2 x - 4}\right| - 2> 0           3
# 235                      \left|{3 x + 4}\right| - 5> 0           3
# 236                   \left|{2 x - 8}\right| - 1\geq 0           3
# 237                 \left|{2 x + 6}\right| - 0.5\geq 0           3
# 238  \frac{{{3^{ - 3}} \cdot {3^6} \cdot {2^3}}}{{{...           3
# 239  {2^{ - 5}} \cdot {( {\frac{1}{2}} )^{ - 2}} \c...           3
# 240  {( {\frac{7}{4}} )^5} \cdot \frac{{{2^6}}}{{{7...           3
# 241  \frac{{{2^{ - 2}} \cdot {{( {{2^2}} )}^3}}}{{{...           3
# 242  \frac{{{5^{ - 3}} \cdot {5^{ - 1}} \cdot {5^2}...           3
# 243  {( {\frac{2}{5}} )^{ - 2}} \cdot {( {\frac{5}{...           3
# 244  \frac{{\sqrt {2}  \cdot {{( {\sqrt {2} } )}^3}...           3
# 245  \frac{{{4^{\frac{1}{2}}} \cdot {2^{ - 1}} \cdo...           3
# 246       2\sqrt {3125}  + 3\sqrt {20}  - 12\sqrt {45}           3
# 247  \frac{1}{4}\sqrt {3125}  - 4\sqrt {20}  - \fra...           3
# 248                                          (3 + x)^4           3
# 249                             ( {1 + 3\sqrt{ 2} })^3           3
# 250                             ( {2 - 3\sqrt{ 2} })^3           3
# 251            ( {\frac{x}{3} + \frac{3}{{{x^2}}}} )^5           3
# 252          ( {\frac{2}{\sqrt {2} } + \sqrt {2} } )^3           3
# 253                   ( {5\sqrt {2} - 2\sqrt {3} } )^3           3
# 254                       ( {2{x^2} - \frac{3}{x}} )^4           3
# 255                                    A(x) \cdot B(x)           3
# 256                               A(x) - 3B(x) + 5C(x)           3
# 257                       x^2\cdot A(x) + 3x\cdot B(x)           3
# 258                      2 x^{3} - 6 x^{2} - 26 x + 30           2
# 259                           2 x^{3} + 2 x^{2} - 12 x           2
# 260                       6 x^{3} + 2 x^{2} - 24 x - 8           2
# 261                    2 x^{5} - 8 x^{3} - 2 x^{2} + 8           2
#
#     n_ejercicio  puntos                                           solucion  \
# 0          p9e3       1                                 1 < x \wedge x < 3
# 1          p9e3       1           - \frac{7}{2} < x \wedge x < \frac{1}{2}
# 2          p9e3       1                         -7 \leq x \wedge x \leq -3
# 3          p9e3       1         0.5 \leq x \wedge x \leq 0.833333333333333
# 4          p9e3       1  \left(-\infty < x \wedge x < -1\right) \vee \l...
# 5          p9e3       1  \left(-\infty < x \wedge x < -7\right) \vee \l...
# 6          p9e3       1  \left(2 \leq x \wedge x < \infty\right) \vee \...
# 7          p9e3       1  \left(-0.25 \leq x \wedge x < \infty\right) \v...
# 8        p4e1-2       1                                        \frac{1}{6}
# 9        p4e1-2       1                                                  3
# 10       p4e1-2       1                                     \frac{125}{16}
# 11       p4e1-2       1                                                128
# 12       p4e1-2       1                                   \frac{1}{390650}
# 13       p4e1-2       1                                     \frac{729}{64}
# 14       p4e1-2       1                               \frac{2 \sqrt{5}}{5}
# 15       p4e1-2       1                                                  2
# 16        p6e13       1                                                  4
# 17        p6e13       1                                     2 \sqrt[4]{-1}
# 18        p6e13       1                                                  3
# 19        p6e13       1                                       \sqrt[5]{-1}
# 20        p6e13       1                                                 35
# 21        p6e13       1                                                  1
# 22        p6e14       1                                         x^{4} = 81
# 23        p6e14       1                                        x^{3} = 125
# 24        p6e14       1                                         x^{2} = -6
# 25        p6e14       1                                         x^{5} = -1
# 26        p6e15       1                                                729
# 27        p6e15       1                                                  5
# 28        p6e15       1                                     25 \sqrt[3]{5}
# 29        p6e15       1                                           \sqrt{2}
# ..          ...     ...                                                ...
# 232      a01e01       1   - \frac{7}{2} \leq x \wedge x \leq - \frac{3}{2}
# 233      a01e01       1        0.583333333333333 \leq x \wedge x \leq 0.75
# 234      a01e01       1  \left(-\infty < x \wedge x < 1\right) \vee \le...
# 235      a01e01       1  \left(-\infty < x \wedge x < -3\right) \vee \l...
# 236      a01e01       1  \left(\frac{9}{2} \leq x \wedge x < \infty\rig...
# 237      a01e01       1  \left(-2.75 \leq x \wedge x < \infty\right) \v...
# 238      a01e02       1                                       \frac{1}{36}
# 239      a01e02       1                                                 16
# 240      a01e02       1                                     \frac{343}{16}
# 241      a01e02       1                                                128
# 242      a01e02       1                                   \frac{1}{390650}
# 243      a01e02       1                                   \frac{15625}{64}
# 244      a01e02       1                               \frac{2 \sqrt{5}}{5}
# 245      a01e02       1                                                 16
# 246      a01e03       1                                        20 \sqrt{5}
# 247      a01e03       1                                       - 4 \sqrt{5}
# 248      a01e04       1           x^{4} + 12 x^{3} + 54 x^{2} + 108 x + 81
# 249      a01e04       1                                   55 + 63 \sqrt{2}
# 250      a01e04       1                                - 90 \sqrt{2} + 116
# 251      a01e04       1  \frac{x^{5}}{243} + \frac{5 x^{2}}{27} + \frac...
# 252      a01e04       1                \frac{12 \sqrt{2}}{2} + 10 \sqrt{2}
# 253      a01e04       1                      - 324 \sqrt{3} + 430 \sqrt{2}
# 254      a01e04       1  16 x^{8} - 96 x^{5} + 216 x^{2} - \frac{216}{x...
# 255      a01e05       1  - 2 x^{7} + 5 x^{6} - 5 x^{5} + 5 x^{4} - 6 x^...
# 256      a01e05       1     8 x^{4} - x^{3} - 8 x^{2} + 4 x + \frac{11}{3}
# 257      a01e05       1                  - x^{5} + 2 x^{3} + 2 x^{2} - 3 x
# 258      a01e06       1  2 \left(x - 5\right) \left(x - 1\right) \left(...
# 259      a01e06       1          2 x \left(x - 2\right) \left(x + 3\right)
# 260      a01e06       1  6 \left(x - 2\right) \left(x + \frac{1}{3}\rig...
# 261      a01e06       1  2 \left(x - 2\right) \left(x - 1\right) \left(...
#
#                                                  texto  \
# 0                Resolver las siguientes inecuaciones:
# 1                Resolver las siguientes inecuaciones:
# 2                Resolver las siguientes inecuaciones:
# 3                Resolver las siguientes inecuaciones:
# 4                Resolver las siguientes inecuaciones:
# 5                Resolver las siguientes inecuaciones:
# 6                Resolver las siguientes inecuaciones:
# 7                Resolver las siguientes inecuaciones:
# 8                                            Calcula :
# 9                                            Calcula :
# 10                                           Calcula :
# 11                                           Calcula :
# 12                                           Calcula :
# 13                                           Calcula :
# 14                                           Calcula :
# 15                                           Calcula :
# 16                   Calcula los siguientes radicales:
# 17                   Calcula los siguientes radicales:
# 18                   Calcula los siguientes radicales:
# 19                   Calcula los siguientes radicales:
# 20                   Calcula los siguientes radicales:
# 21                   Calcula los siguientes radicales:
# 22                 Resuelve las siguientes ecuaciones:
# 23                 Resuelve las siguientes ecuaciones:
# 24                 Resuelve las siguientes ecuaciones:
# 25                 Resuelve las siguientes ecuaciones:
# 26   Calcula y expresa el resultado de la forma más...
# 27   Calcula y expresa el resultado de la forma más...
# 28   Calcula y expresa el resultado de la forma más...
# 29   Calcula y expresa el resultado de la forma más...
# ..                                                 ...
# 232              Resolver las siguientes inecuaciones:
# 233              Resolver las siguientes inecuaciones:
# 234              Resolver las siguientes inecuaciones:
# 235              Resolver las siguientes inecuaciones:
# 236              Resolver las siguientes inecuaciones:
# 237              Resolver las siguientes inecuaciones:
# 238                                          Calcula :
# 239                                          Calcula :
# 240                                          Calcula :
# 241                                          Calcula :
# 242                                          Calcula :
# 243                                          Calcula :
# 244                                          Calcula :
# 245                                          Calcula :
# 246                                           Calcula:
# 247                                           Calcula:
# 248  Realiza los desarrollos de los siguientes bino...
# 249  Realiza los desarrollos de los siguientes bino...
# 250  Realiza los desarrollos de los siguientes bino...
# 251  Realiza los desarrollos de los siguientes bino...
# 252  Realiza los desarrollos de los siguientes bino...
# 253  Realiza los desarrollos de los siguientes bino...
# 254  Realiza los desarrollos de los siguientes bino...
# 255  Dados los polinomios $ A(x)=2{x^3} - 3{x^2} + ...
# 256  Dados los polinomios $ A(x)=2{x^3} - 3{x^2} + ...
# 257  Dados los polinomios $ A(x)=2{x^3} - 3{x^2} + ...
# 258                            Descomponer en factores
# 259                            Descomponer en factores
# 260                            Descomponer en factores
# 261                            Descomponer en factores
#
#                         titulo
# 0           1 - Números reales
# 1           1 - Números reales
# 2           1 - Números reales
# 3           1 - Números reales
# 4           1 - Números reales
# 5           1 - Números reales
# 6           1 - Números reales
# 7           1 - Números reales
# 8    2 - Potencias y radicales
# 9    2 - Potencias y radicales
# 10   2 - Potencias y radicales
# 11   2 - Potencias y radicales
# 12   2 - Potencias y radicales
# 13   2 - Potencias y radicales
# 14   2 - Potencias y radicales
# 15   2 - Potencias y radicales
# 16   2 - Potencias y radicales
# 17   2 - Potencias y radicales
# 18   2 - Potencias y radicales
# 19   2 - Potencias y radicales
# 20   2 - Potencias y radicales
# 21   2 - Potencias y radicales
# 22   2 - Potencias y radicales
# 23   2 - Potencias y radicales
# 24   2 - Potencias y radicales
# 25   2 - Potencias y radicales
# 26   2 - Potencias y radicales
# 27   2 - Potencias y radicales
# 28   2 - Potencias y radicales
# 29   2 - Potencias y radicales
# ..                         ...
# 232           Autoevaluación 1
# 233           Autoevaluación 1
# 234           Autoevaluación 1
# 235           Autoevaluación 1
# 236           Autoevaluación 1
# 237           Autoevaluación 1
# 238           Autoevaluación 1
# 239           Autoevaluación 1
# 240           Autoevaluación 1
# 241           Autoevaluación 1
# 242           Autoevaluación 1
# 243           Autoevaluación 1
# 244           Autoevaluación 1
# 245           Autoevaluación 1
# 246           Autoevaluación 1
# 247           Autoevaluación 1
# 248           Autoevaluación 1
# 249           Autoevaluación 1
# 250           Autoevaluación 1
# 251           Autoevaluación 1
# 252           Autoevaluación 1
# 253           Autoevaluación 1
# 254           Autoevaluación 1
# 255           Autoevaluación 1
# 256           Autoevaluación 1
# 257           Autoevaluación 1
# 258           Autoevaluación 1
# 259           Autoevaluación 1
# 260           Autoevaluación 1
# 261           Autoevaluación 1
#
# [262 rows x 11 columns]

# %%
fichero = 'autoevaluacion'
titulo = 'Autoevaluación'
tipo = 'ejerc'
n_pdf = ['A','B','C', 'D']
n_ejercicios = 10
   
for s in n_pdf: 
    df_ejercicios = df.loc[np.random.choice(df.index, n_ejercicios, replace=False)].sort_values('n_ejercicio')
    exportar_pdf(df_ejercicios,fichero, titulo, tipo, s)
# Out:
# **Ejercicio: **a01e01
#    index                      enunciado_latex                    enunciado  \
# 3      3  \left|{3 x - 2}\right| - 0.25\leq 0  (Abs(3*x - 2) - 0.25, '<=')
# 7      7   \left|{2 x + 6}\right| - 0.5\geq 0   (Abs(2*x + 6) - 0.5, '>=')
# 0      0          \left|{x - 4}\right| - 2< 0        (Abs(x - 4) - 2, '<')
#
#                                             solucion  \
# 3        0.583333333333333 \leq x \wedge x \leq 0.75
# 7  \left(-2.75 \leq x \wedge x < \infty\right) \v...
# 0                                 2 < x \wedge x < 6
#
#                                    texto curso            titulo n_ejercicio  \
# 3  Resolver las siguientes inecuaciones:   1BC  Autoevaluación 1      a01e01
# 7  Resolver las siguientes inecuaciones:   1BC  Autoevaluación 1      a01e01
# 0  Resolver las siguientes inecuaciones:   1BC  Autoevaluación 1      a01e01
#
#    dificultad  n_columnas  puntos
# 3           1           1       1
# 7           1           1       1
# 0           1           1       1
# **Ejercicio: **a01e03
#     index                               enunciado_latex  \
# 16     16  2\sqrt {3125}  + 3\sqrt {20}  - 12\sqrt {45}
#
#                                        enunciado     solucion     texto curso  \
# 16  -36*sqrt(5) + 3*(2*sqrt(5)) + 2*(25*sqrt(5))  20 \sqrt{5}  Calcula:   1BC
#
#               titulo n_ejercicio  dificultad  n_columnas  puntos
# 16  Autoevaluación 1      a01e03           1           1       1
# **Ejercicio: **a01e04
#     index                            enunciado_latex  \
# 22     22  ( {\frac{2}{\sqrt {2} } + \sqrt {2} } )^3
# 24     24               ( {2{x^2} - \frac{3}{x}} )^4
# 21     21    ( {\frac{x}{3} + \frac{3}{{{x^2}}}} )^5
#
#                    enunciado  \
# 22  (2/sqrt(2) + sqrt(2))**3
# 24         (2*x**2 - 3/x)**4
# 21         (x/3 + 3/x**2)**5
#
#                                              solucion  \
# 22                \frac{12 \sqrt{2}}{2} + 10 \sqrt{2}
# 24  16 x^{8} - 96 x^{5} + 216 x^{2} - \frac{216}{x...
# 21  \frac{x^{5}}{243} + \frac{5 x^{2}}{27} + \frac...
#
#                                                 texto curso            titulo  \
# 22  Realiza los desarrollos de los siguientes bino...   1BC  Autoevaluación 1
# 24  Realiza los desarrollos de los siguientes bino...   1BC  Autoevaluación 1
# 21  Realiza los desarrollos de los siguientes bino...   1BC  Autoevaluación 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 22      a01e04           1           1       1
# 24      a01e04           1           1       1
# 21      a01e04           1           1       1
# **Ejercicio: **a01e05
#     index               enunciado_latex               enunciado  \
# 27     27  x^2\cdot A(x) + 3x\cdot B(x)  x**2*A(x) + (3*x)*B(x)
# 26     26          A(x) - 3B(x) + 5C(x)  A(x) - 3*B(x) + 5*C(x)
#
#                                           solucion  \
# 27               - x^{5} + 2 x^{3} + 2 x^{2} - 3 x
# 26  8 x^{4} - x^{3} - 8 x^{2} + 4 x + \frac{11}{3}
#
#                                                 texto curso            titulo  \
# 27  Dados los polinomios $ A(x)=2{x^3} - 3{x^2} + ...   1BC  Autoevaluación 1
# 26  Dados los polinomios $ A(x)=2{x^3} - 3{x^2} + ...   1BC  Autoevaluación 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 27      a01e05           1           1       1
# 26      a01e05           1           1       1
# **Ejercicio: **a01e06
#     index           enunciado_latex                enunciado  \
# 29     29  2 x^{3} + 2 x^{2} - 12 x  -12*x + 2*x**3 + 2*x**2
#
#                                      solucion                    texto curso  \
# 29  2 x \left(x - 2\right) \left(x + 3\right)  Descomponer en factores   1BC
#
#               titulo n_ejercicio  dificultad  n_columnas  puntos
# 29  Autoevaluación 1      a01e06           1           1       1
# **Ejercicio: **a01e01
#    index              enunciado_latex              enunciado  \
# 0      0  \left|{x - 4}\right| - 2< 0  (Abs(x - 4) - 2, '<')
#
#              solucion                                  texto curso  \
# 0  2 < x \wedge x < 6  Resolver las siguientes inecuaciones:   1BC
#
#              titulo n_ejercicio  dificultad  n_columnas  puntos
# 0  Autoevaluación 1      a01e01           1           1       1
# **Ejercicio: **a01e02
#     index                                    enunciado_latex  \
# 12     12  \frac{{{5^{ - 3}} \cdot {5^{ - 1}} \cdot {5^2}...
# 10     10  {( {\frac{7}{4}} )^5} \cdot \frac{{{2^6}}}{{{7...
# 8       8  \frac{{{3^{ - 3}} \cdot {3^6} \cdot {2^3}}}{{{...
#
#                            enunciado          solucion      texto curso  \
# 12  (5**2*(5**(-3)/5))/(5**0 + 5**6)  \frac{1}{390650}  Calcula :   1BC
# 10              (7/4)**5*(2**6/7**2)    \frac{343}{16}  Calcula :   1BC
# 8     (2**3*(3**6*3**(-3)))/(2*3)**5      \frac{1}{36}  Calcula :   1BC
#
#               titulo n_ejercicio  dificultad  n_columnas  puntos
# 12  Autoevaluación 1      a01e02           1           1       1
# 10  Autoevaluación 1      a01e02           1           1       1
# 8   Autoevaluación 1      a01e02           1           1       1
# **Ejercicio: **a01e03
#     index                               enunciado_latex  \
# 16     16  2\sqrt {3125}  + 3\sqrt {20}  - 12\sqrt {45}
#
#                                        enunciado     solucion     texto curso  \
# 16  -36*sqrt(5) + 3*(2*sqrt(5)) + 2*(25*sqrt(5))  20 \sqrt{5}  Calcula:   1BC
#
#               titulo n_ejercicio  dificultad  n_columnas  puntos
# 16  Autoevaluación 1      a01e03           1           1       1
# **Ejercicio: **a01e04
#     index                            enunciado_latex  \
# 19     19                     ( {1 + 3\sqrt{ 2} })^3
# 23     23           ( {5\sqrt {2} - 2\sqrt {3} } )^3
# 22     22  ( {\frac{2}{\sqrt {2} } + \sqrt {2} } )^3
# 18     18                                  (3 + x)^4
#
#                       enunciado                                  solucion  \
# 19           (1 + 3*sqrt(2))**3                          55 + 63 \sqrt{2}
# 23  (-2*sqrt(3) + 5*sqrt(2))**3             - 324 \sqrt{3} + 430 \sqrt{2}
# 22     (2/sqrt(2) + sqrt(2))**3       \frac{12 \sqrt{2}}{2} + 10 \sqrt{2}
# 18                   (x + 3)**4  x^{4} + 12 x^{3} + 54 x^{2} + 108 x + 81
#
#                                                 texto curso            titulo  \
# 19  Realiza los desarrollos de los siguientes bino...   1BC  Autoevaluación 1
# 23  Realiza los desarrollos de los siguientes bino...   1BC  Autoevaluación 1
# 22  Realiza los desarrollos de los siguientes bino...   1BC  Autoevaluación 1
# 18  Realiza los desarrollos de los siguientes bino...   1BC  Autoevaluación 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 19      a01e04           1           1       1
# 23      a01e04           1           1       1
# 22      a01e04           1           1       1
# 18      a01e04           1           1       1
# **Ejercicio: **a01e06
#     index           enunciado_latex                enunciado  \
# 29     29  2 x^{3} + 2 x^{2} - 12 x  -12*x + 2*x**3 + 2*x**2
#
#                                      solucion                    texto curso  \
# 29  2 x \left(x - 2\right) \left(x + 3\right)  Descomponer en factores   1BC
#
#               titulo n_ejercicio  dificultad  n_columnas  puntos
# 29  Autoevaluación 1      a01e06           1           1       1
# **Ejercicio: **a01e01
#    index                enunciado_latex                enunciado  \
# 4      4  \left|{2 x - 4}\right| - 2> 0  (Abs(2*x - 4) - 2, '>')
#
#                                             solucion  \
# 4  \left(-\infty < x \wedge x < 1\right) \vee \le...
#
#                                    texto curso            titulo n_ejercicio  \
# 4  Resolver las siguientes inecuaciones:   1BC  Autoevaluación 1      a01e01
#
#    dificultad  n_columnas  puntos
# 4           1           1       1
# **Ejercicio: **a01e02
#     index                                    enunciado_latex  \
# 9       9  {2^{ - 5}} \cdot {( {\frac{1}{2}} )^{ - 2}} \c...
# 12     12  \frac{{{5^{ - 3}} \cdot {5^{ - 1}} \cdot {5^2}...
# 15     15  \frac{{{4^{\frac{1}{2}}} \cdot {2^{ - 1}} \cdo...
# 13     13  {( {\frac{2}{5}} )^{ - 2}} \cdot {( {\frac{5}{...
# 14     14  \frac{{\sqrt {2}  \cdot {{( {\sqrt {2} } )}^3}...
#
#                                             enunciado              solucion  \
# 9                          2**7*(2**(-5)*(1/2)**(-2))                    16
# 12                   (5**2*(5**(-3)/5))/(5**0 + 5**6)      \frac{1}{390650}
# 15                    (2**(9/2)*(4**(1/2)/2))/sqrt(2)                    16
# 13                               (2/5)**(-2)*(5/2)**4      \frac{15625}{64}
# 14  ((sqrt(2)*(sqrt(2))**3)*(sqrt(5))**3)/(5*sqrt(...  \frac{2 \sqrt{5}}{5}
#
#         texto curso            titulo n_ejercicio  dificultad  n_columnas  \
# 9   Calcula :   1BC  Autoevaluación 1      a01e02           1           1
# 12  Calcula :   1BC  Autoevaluación 1      a01e02           1           1
# 15  Calcula :   1BC  Autoevaluación 1      a01e02           1           1
# 13  Calcula :   1BC  Autoevaluación 1      a01e02           1           1
# 14  Calcula :   1BC  Autoevaluación 1      a01e02           1           1
#
#     puntos
# 9        1
# 12       1
# 15       1
# 13       1
# 14       1
# **Ejercicio: **a01e04
#     index         enunciado_latex           enunciado          solucion  \
# 19     19  ( {1 + 3\sqrt{ 2} })^3  (1 + 3*sqrt(2))**3  55 + 63 \sqrt{2}
#
#                                                 texto curso            titulo  \
# 19  Realiza los desarrollos de los siguientes bino...   1BC  Autoevaluación 1
#
#    n_ejercicio  dificultad  n_columnas  puntos
# 19      a01e04           1           1       1
# **Ejercicio: **a01e06
#     index                  enunciado_latex                      enunciado  \
# 30     30     6 x^{3} + 2 x^{2} - 24 x - 8    -24*x + 6*x**3 + 2*x**2 - 8
# 28     28    2 x^{3} - 6 x^{2} - 26 x + 30   -26*x + 2*x**3 - 6*x**2 + 30
# 31     31  2 x^{5} - 8 x^{3} - 2 x^{2} + 8  -2*x**2 + 2*x**5 - 8*x**3 + 8
#
#                                              solucion  \
# 30  6 \left(x - 2\right) \left(x + \frac{1}{3}\rig...
# 28  2 \left(x - 5\right) \left(x - 1\right) \left(...
# 31  2 \left(x - 2\right) \left(x - 1\right) \left(...
#
#                       texto curso            titulo n_ejercicio  dificultad  \
# 30  Descomponer en factores   1BC  Autoevaluación 1      a01e06           1
# 28  Descomponer en factores   1BC  Autoevaluación 1      a01e06           1
# 31  Descomponer en factores   1BC  Autoevaluación 1      a01e06           1
#
#     n_columnas  puntos
# 30           1       1
# 28           1       1
# 31           1       1

# %%
fichero = 'autoevaluacion'
titulo = 'Autoevaluación'
tipo = 'ejerc'
n_pdf = list(string.ascii_uppercase)[:3]

if tipo != 'ejercicios' :
 
    lista = np.unique(df.n_ejercicio.tolist())
    numero = 1

    for s in n_pdf:
        df_ejercicios = pd.concat(df.loc[np.random.choice(df[df.n_ejercicio==s].index, numero, replace=False)] for s in lista)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = False)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = True)

else :
    exportar_pdf(df, fichero, titulo, tipo)
# Out:
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right) , \  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       1
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right) , \  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       1
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right) , \  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       1
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right) , \  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       1
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right) , \  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       1
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  A \cup  B = \left(-\infty, \infty\right) , \  ...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 0     ex01e01           1           1       1

# %%
# Generador de prueb: Cambia los parámetros 

fichero = 'parcial'
titulo = 'Parcial'
tipo = 'ejerc'
n_pdf = list(string.ascii_uppercase)[:1]

if tipo != 'ejercicios' :
 

    numero = 2
    lista1 = np.unique(df.n_ejercicio.tolist())
    lista2 =[]
    for i in range(lista1.size) : lista2.append(numero)
    lista = list(zip(lista1,lista2))
    
    for s in n_pdf:
        df_ejercicios = pd.concat(df.loc[np.random.choice(df[df.n_ejercicio==s[0]].index, s[1], replace=False)] for s in lista)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = False)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = True)

else :
    exportar_pdf(df, fichero, titulo, tipo)
# Out:
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 1  A=\left\{ x \in \mathbb{R}| 3 \leq x \wedge x ...
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 1  [Interval.Ropen(3, 8), Union(Interval.open(-oo...
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 1  A \cup  B = \left(-\infty, 1\right) \cup \left...
# 0  A \cup  B = \left(-\infty, \infty\right)  \\  ...
#
#                                                texto curso     titulo  \
# 1  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 1     ex01e01           1           1       1
# 0     ex01e01           1           1       1
# **Ejercicio: **ex01e02
#            enunciado_latex                   enunciado          solucion  \
# 2      {\binom{x}{2}} = 21      Eq(binomial(x, 2), 21)  \left\{7\right\}
# 4  {\binom{x}{x - 2}} = 10  Eq(binomial(x, x - 2), 10)  \left\{5\right\}
#
#                       texto curso     titulo n_ejercicio  dificultad  \
# 2  Resolver las ecuaciones:   1BC  Parcial 1     ex01e02           1
# 4  Resolver las ecuaciones:   1BC  Parcial 1     ex01e02           1
#
#    n_columnas  puntos
# 2           1       1
# 4           1       1
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 1  A=\left\{ x \in \mathbb{R}| 3 \leq x \wedge x ...
# 0  A=\left\{ x \in \mathbb{R}| -2 \leq x \wedge x...
#
#                                            enunciado  \
# 1  [Interval.Ropen(3, 8), Union(Interval.open(-oo...
# 0  [Interval(-2, 5), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 1  A \cup  B = \left(-\infty, 1\right) \cup \left...
# 0  A \cup  B = \left(-\infty, \infty\right)  \\  ...
#
#                                                texto curso     titulo  \
# 1  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos
# 1     ex01e01           1           1       1
# 0     ex01e01           1           1       1
# **Ejercicio: **ex01e02
#            enunciado_latex                   enunciado          solucion  \
# 2      {\binom{x}{2}} = 21      Eq(binomial(x, 2), 21)  \left\{7\right\}
# 4  {\binom{x}{x - 2}} = 10  Eq(binomial(x, x - 2), 10)  \left\{5\right\}
#
#                       texto curso     titulo n_ejercicio  dificultad  \
# 2  Resolver las ecuaciones:   1BC  Parcial 1     ex01e02           1
# 4  Resolver las ecuaciones:   1BC  Parcial 1     ex01e02           1
#
#    n_columnas  puntos
# 2           1       1
# 4           1       1

# %%
lista
# Out:
# [('a01e01', 4),
#  ('a01e02', 4),
#  ('a01e03', 4),
#  ('a01e04', 4),
#  ('a01e05', 4),
#  ('a01e06', 4)]

# %%
lista1 = np.unique(df.n_ejercicio.tolist())
lista2 =[]
for i in range(lista.size) : lista2.append(2)
    
lista = list(zip(lista,lista2))
lista[0][0]
# Out:
# 'a01e01'
