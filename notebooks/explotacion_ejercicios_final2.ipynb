# %%
import pandas as pd
import numpy as np
from docparts import escribir_ejercicios, escribir_fin, escribir_preambulo, generar_tex, exportar_pdf
from IPython.display import Markdown as md
from IPython.display import display
import string
import random

# %%
df = pd.read_csv('ejercicios_final2.csv', index_col=False)

# %%
df
# Out:
#                                       enunciado_latex  \
# 0   \overrightarrow{u}=(4, 12) \, \ \overrightarro...
# 1   \overrightarrow{u}=(1, 2) \, \ \overrightarrow...
# 2              r\equiv2x-y-2=0\  y \ s\equiv3x+2y-4=0
# 3    A(2, -3)\  , \ B=(5, 2) \ y \  C \in r\equiv ...
# 4               A=(2, 1), \ B=(4, 3),\  y \ C=(6, -1)
# 5                        2\cos^2{x}-\sqrt{3}\cos{x}=0
# 6                               \cos{2x}-3\cos{x}+1=0
# 7                      \frac{(1+2i)i^7}{(3-2i)-(2+i)}
# 8                                     2 - 2\sqrt {3}i
# 9                                                  2i
# 10                                                 -4
#
#                                             enunciado  \
# 0   Point(4, 12).is_collinear(Point(2, 6), Point(0...
# 1   Point(1, 2).is_collinear(Point(3, 4), Point(0,0))
# 2                           ['2x-y-2=0', '3x+2y-4=0']
# 3                     [(2, -3), (5, 2), '-x+3y-16=0']
# 4                           [(2, 1), (4, 3), (6, -1)]
# 5                 Eq(2*cos(x)**2 - sqrt(3)*cos(x), 0)
# 6                     Eq(-3*cos(x) + cos(2*x) + 1, 0)
# 7                 (i**7*(2*i + 1))/(-2*i + 3 - i - 2)
# 8                                    -2*sqrt(3)*i + 2
# 9                                                 2*i
# 10                                                 -4
#
#                                              solucion  \
# 0                                               False
# 1                                                True
# 2                                  119.74488129694222
# 3   \left [ \left \{ x : -4, \quad y : 4\right \}\...
# 4   \left [ y - 1 = 0, \quad - 2 x - 2 y + 10 = 0,...
# 5   \left [ 30, \quad 90, \quad 270, \quad 330\rig...
# 6                       \left [ -90, \quad 90\right ]
# 7                           \frac{1}{2} + \frac{i}{2}
# 8                                 4_{- \frac{\pi}{3}}
# 9                                   2_{\frac{\pi}{2}}
# 10                                            4_{\pi}
#
#                                                 texto curso        titulo  \
# 0   Justifica si los siguientes pares de vectores ...   1BC  Final 2ª Ev.
# 1   Justifica si los siguientes pares de vectores ...   1BC  Final 2ª Ev.
# 2        Determinar el ángulo formado por las rectas:   1BC  Final 2ª Ev.
# 3   Calcula el vértice C de un triángulo isósceles...   1BC  Final 2ª Ev.
# 4   Dado el triángulo ABC, hallar: \\ \n\begin{ite...   1BC  Final 2ª Ev.
# 5                 Resolver las siguientes ecuaciones:   1BC  Final 2ª Ev.
# 6                 Resolver las siguientes ecuaciones:   1BC  Final 2ª Ev.
# 7                                            Calcula:   1BC  Final 2ª Ev.
# 8   Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
# 9   Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
# 10  Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 0      ex12e01           1           2       1      True     True
# 1      ex12e01           1           2       1      True     True
# 2      ex12e02           1           2       1      True     True
# 3      ex12e03           1           1       1      True     True
# 4      ex12e04           5           1       1      True     True
# 5      ex12e05           1           1       1      True     True
# 6      ex12e05           1           1       1      True     True
# 7      ex12e06           2           2       1      True     True
# 8      ex12e07           1           2       1      True     True
# 9      ex12e07           1           2       1      True     True
# 10     ex12e07           1           2       1      True     True

# %%
df.pivot_table(index = ['n_ejercicio'], columns=['texto','puntos'])
# Out:
#                                                                    dificultad  \
# texto       Calcula el vértice C de un triángulo isósceles ABC, sabiendo que:
# puntos                                                                      1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                    1.0
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#                       \
# texto       Calcula:
# puntos             1
# n_ejercicio
# ex12e01          NaN
# ex12e02          NaN
# ex12e03          NaN
# ex12e04          NaN
# ex12e05          NaN
# ex12e06          2.0
# ex12e07          NaN
#
#                                                                                                                                                                                                    \
# texto       Dado el triángulo ABC, hallar: \\ \n\begin{itemize} \item la mediana correspondiente al vértice A \item la mediatriz correspondiente al lado AB \item y el área \end{itemize} Siendo:
# puntos                                                                                                                                                                                          1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                    5.0
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#                                                           \
# texto       Determinar el ángulo formado por las rectas:
# puntos                                                 1
# n_ejercicio
# ex12e01                                              NaN
# ex12e02                                              1.0
# ex12e03                                              NaN
# ex12e04                                              NaN
# ex12e05                                              NaN
# ex12e06                                              NaN
# ex12e07                                              NaN
#
#                                                                                                    \
# texto       Escribe los siguientes números complejos en forma polar con el argumento en radianes:
# puntos                                                                                          1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    1.0
#
#                                                                                           \
# texto       Justifica si los siguientes pares de vectores forman base de $\mathbb{R}^2$:
# puntos                                                                                 1
# n_ejercicio
# ex12e01                                                    1.0
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#                                                  \
# texto       Resolver las siguientes ecuaciones:
# puntos                                        1
# n_ejercicio
# ex12e01                                     NaN
# ex12e02                                     NaN
# ex12e03                                     NaN
# ex12e04                                     NaN
# ex12e05                                     1.0
# ex12e06                                     NaN
# ex12e07                                     NaN
#
#                                                                      enun_tex  \
# texto       Calcula el vértice C de un triángulo isósceles ABC, sabiendo que:
# puntos                                                                      1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                   True
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#                       \
# texto       Calcula:
# puntos             1
# n_ejercicio
# ex12e01          NaN
# ex12e02          NaN
# ex12e03          NaN
# ex12e04          NaN
# ex12e05          NaN
# ex12e06         True
# ex12e07          NaN
#
#                                                                                                                                                                                                    \
# texto       Dado el triángulo ABC, hallar: \\ \n\begin{itemize} \item la mediana correspondiente al vértice A \item la mediatriz correspondiente al lado AB \item y el área \end{itemize} Siendo:
# puntos                                                                                                                                                                                          1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                   True
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#                             ...                  \
# texto                       ...
# puntos                      ...
# n_ejercicio                 ...
# ex12e01                     ...
# ex12e02                     ...
# ex12e03                     ...
# ex12e04                     ...
# ex12e05                     ...
# ex12e06                     ...
# ex12e07                     ...
#
#                                                                                        n_columnas  \
# texto       Escribe los siguientes números complejos en forma polar con el argumento en radianes:
# puntos                                                                                          1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    2.0
#
#                                                                                           \
# texto       Justifica si los siguientes pares de vectores forman base de $\mathbb{R}^2$:
# puntos                                                                                 1
# n_ejercicio
# ex12e01                                                    2.0
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#                                                  \
# texto       Resolver las siguientes ecuaciones:
# puntos                                        1
# n_ejercicio
# ex12e01                                     NaN
# ex12e02                                     NaN
# ex12e03                                     NaN
# ex12e04                                     NaN
# ex12e05                                     1.0
# ex12e06                                     NaN
# ex12e07                                     NaN
#
#                                                                       sol_tex  \
# texto       Calcula el vértice C de un triángulo isósceles ABC, sabiendo que:
# puntos                                                                      1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                   True
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#                       \
# texto       Calcula:
# puntos             1
# n_ejercicio
# ex12e01          NaN
# ex12e02          NaN
# ex12e03          NaN
# ex12e04          NaN
# ex12e05          NaN
# ex12e06         True
# ex12e07          NaN
#
#                                                                                                                                                                                                    \
# texto       Dado el triángulo ABC, hallar: \\ \n\begin{itemize} \item la mediana correspondiente al vértice A \item la mediatriz correspondiente al lado AB \item y el área \end{itemize} Siendo:
# puntos                                                                                                                                                                                          1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                   True
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#                                                           \
# texto       Determinar el ángulo formado por las rectas:
# puntos                                                 1
# n_ejercicio
# ex12e01                                              NaN
# ex12e02                                             True
# ex12e03                                              NaN
# ex12e04                                              NaN
# ex12e05                                              NaN
# ex12e06                                              NaN
# ex12e07                                              NaN
#
#                                                                                                    \
# texto       Escribe los siguientes números complejos en forma polar con el argumento en radianes:
# puntos                                                                                          1
# n_ejercicio
# ex12e01                                                    NaN
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                   True
#
#                                                                                           \
# texto       Justifica si los siguientes pares de vectores forman base de $\mathbb{R}^2$:
# puntos                                                                                 1
# n_ejercicio
# ex12e01                                                   True
# ex12e02                                                    NaN
# ex12e03                                                    NaN
# ex12e04                                                    NaN
# ex12e05                                                    NaN
# ex12e06                                                    NaN
# ex12e07                                                    NaN
#
#
# texto       Resolver las siguientes ecuaciones:
# puntos                                        1
# n_ejercicio
# ex12e01                                     NaN
# ex12e02                                     NaN
# ex12e03                                     NaN
# ex12e04                                     NaN
# ex12e05                                    True
# ex12e06                                     NaN
# ex12e07                                     NaN
#
# [7 rows x 28 columns]

# %%
# Generador de prueb: Cambia los parámetros 

fichero = 'final2'
titulo = 'Final 2ª evaluación'
tipo = 'ejerc'  # Todo lo que sea diferente a 'ejercicios' lo generará

n_pdf = list(string.ascii_uppercase)[:1] # Pruebas diferentes a generar

if tipo != 'ejercicios' :
 
    #Construcción de lista de ejercicios
    numero = 2 # Número de ejercicios por defecto de cada ejercicio
    
    lista1 = np.unique(df.n_ejercicio.tolist())
    lista2 =[]
    for i in range(lista1.size) : lista2.append(numero)
    lista = list(zip(lista1,lista2))
    
    # Si queremos poner nuestra propia lista: lista =[('texto_nejercicio',nº de ejercicios)], si no comentar la linea siguiente
    # lista = [('ex01e01', 1),('ex01e02', 1),('ex01e03', 1),('ex01e05', 2),('ex01e06', 1),('ex01e08', 1)]
    lista = [('ex12e01', 2),('ex12e02', 1),('ex12e03', 1),('ex12e04', 1),('ex12e05', 2),('ex12e06', 1),('ex12e07', 3)]
    
    for s in n_pdf:
        random.shuffle(lista)
        df_ejercicios = pd.concat(df.loc[np.random.choice(df[df.n_ejercicio==s[0]].index, s[1], replace=False)] for s in lista)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = False)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = True)

else :
    exportar_pdf(df, fichero, titulo, tipo)
# Out:
# **Ejercicio: **ex12e01
#                                      enunciado_latex  \
# 1  \overrightarrow{u}=(1, 2) \, \ \overrightarrow...
# 0  \overrightarrow{u}=(4, 12) \, \ \overrightarro...
#
#                                            enunciado solucion  \
# 1  Point(1, 2).is_collinear(Point(3, 4), Point(0,0))     True
# 0  Point(4, 12).is_collinear(Point(2, 6), Point(0...    False
#
#                                                texto curso        titulo  \
# 1  Justifica si los siguientes pares de vectores ...   1BC  Final 2ª Ev.
# 0  Justifica si los siguientes pares de vectores ...   1BC  Final 2ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 1     ex12e01           1           1       1      True     True
# 0     ex12e01           1           1       1      True     True
# **Ejercicio: **ex12e02
#                           enunciado_latex                  enunciado  \
# 2  r\equiv2x-y-2=0\  y \ s\equiv3x+2y-4=0  ['2x-y-2=0', '3x+2y-4=0']
#
#              solucion                                         texto curso  \
# 2  119.74488129694222  Determinar el ángulo formado por las rectas:   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 2  Final 2ª Ev.     ex12e02           1           1       1      True     True
# **Ejercicio: **ex12e03
#                                      enunciado_latex  \
# 3   A(2, -3)\  , \ B=(5, 2) \ y \  C \in r\equiv ...
#
#                          enunciado  \
# 3  [(2, -3), (5, 2), '-x+3y-16=0']
#
#                                             solucion  \
# 3  \left [ \left \{ x : -4, \quad y : 4\right \}\...
#
#                                                texto curso        titulo  \
# 3  Calcula el vértice C de un triángulo isósceles...   1BC  Final 2ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 3     ex12e03           1           1       1      True     True
# **Ejercicio: **ex12e04
#                          enunciado_latex                  enunciado  \
# 4  A=(2, 1), \ B=(4, 3),\  y \ C=(6, -1)  [(2, 1), (4, 3), (6, -1)]
#
#                                             solucion  \
# 4  \left [ y - 1 = 0, \quad - 2 x - 2 y + 10 = 0,...
#
#                                                texto curso        titulo  \
# 4  Dado el triángulo ABC, hallar: \\ \n\begin{ite...   1BC  Final 2ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 4     ex12e04           5           1       1      True     True
# **Ejercicio: **ex12e05
#                 enunciado_latex                            enunciado  \
# 6         \cos{2x}-3\cos{x}+1=0      Eq(-3*cos(x) + cos(2*x) + 1, 0)
# 5  2\cos^2{x}-\sqrt{3}\cos{x}=0  Eq(2*cos(x)**2 - sqrt(3)*cos(x), 0)
#
#                                             solucion  \
# 6                      \left [ -90, \quad 90\right ]
# 5  \left [ 30, \quad 90, \quad 270, \quad 330\rig...
#
#                                  texto curso        titulo n_ejercicio  \
# 6  Resolver las siguientes ecuaciones:   1BC  Final 2ª Ev.     ex12e05
# 5  Resolver las siguientes ecuaciones:   1BC  Final 2ª Ev.     ex12e05
#
#    dificultad  n_columnas  puntos  enun_tex  sol_tex
# 6           1           1       1      True     True
# 5           1           1       1      True     True
# **Ejercicio: **ex12e06
#                   enunciado_latex                            enunciado  \
# 7  \frac{(1+2i)i^7}{(3-2i)-(2+i)}  (i**7*(2*i + 1))/(-2*i + 3 - i - 2)
#
#                     solucion     texto curso        titulo n_ejercicio  \
# 7  \frac{1}{2} + \frac{i}{2}  Calcula:   1BC  Final 2ª Ev.     ex12e06
#
#    dificultad  n_columnas  puntos  enun_tex  sol_tex
# 7           2           1       1      True     True
# **Ejercicio: **ex12e07
#     enunciado_latex         enunciado             solucion  \
# 10               -4                -4              4_{\pi}
# 9                2i               2*i    2_{\frac{\pi}{2}}
# 8   2 - 2\sqrt {3}i  -2*sqrt(3)*i + 2  4_{- \frac{\pi}{3}}
#
#                                                 texto curso        titulo  \
# 10  Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
# 9   Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
# 8   Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 10     ex12e07           1           1       1      True     True
# 9      ex12e07           1           1       1      True     True
# 8      ex12e07           1           1       1      True     True
# **Ejercicio: **ex12e01
#                                      enunciado_latex  \
# 1  \overrightarrow{u}=(1, 2) \, \ \overrightarrow...
# 0  \overrightarrow{u}=(4, 12) \, \ \overrightarro...
#
#                                            enunciado solucion  \
# 1  Point(1, 2).is_collinear(Point(3, 4), Point(0,0))     True
# 0  Point(4, 12).is_collinear(Point(2, 6), Point(0...    False
#
#                                                texto curso        titulo  \
# 1  Justifica si los siguientes pares de vectores ...   1BC  Final 2ª Ev.
# 0  Justifica si los siguientes pares de vectores ...   1BC  Final 2ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 1     ex12e01           1           1       1      True     True
# 0     ex12e01           1           1       1      True     True
# **Ejercicio: **ex12e02
#                           enunciado_latex                  enunciado  \
# 2  r\equiv2x-y-2=0\  y \ s\equiv3x+2y-4=0  ['2x-y-2=0', '3x+2y-4=0']
#
#              solucion                                         texto curso  \
# 2  119.74488129694222  Determinar el ángulo formado por las rectas:   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 2  Final 2ª Ev.     ex12e02           1           1       1      True     True
# **Ejercicio: **ex12e03
#                                      enunciado_latex  \
# 3   A(2, -3)\  , \ B=(5, 2) \ y \  C \in r\equiv ...
#
#                          enunciado  \
# 3  [(2, -3), (5, 2), '-x+3y-16=0']
#
#                                             solucion  \
# 3  \left [ \left \{ x : -4, \quad y : 4\right \}\...
#
#                                                texto curso        titulo  \
# 3  Calcula el vértice C de un triángulo isósceles...   1BC  Final 2ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 3     ex12e03           1           1       1      True     True
# **Ejercicio: **ex12e04
#                          enunciado_latex                  enunciado  \
# 4  A=(2, 1), \ B=(4, 3),\  y \ C=(6, -1)  [(2, 1), (4, 3), (6, -1)]
#
#                                             solucion  \
# 4  \left [ y - 1 = 0, \quad - 2 x - 2 y + 10 = 0,...
#
#                                                texto curso        titulo  \
# 4  Dado el triángulo ABC, hallar: \\ \n\begin{ite...   1BC  Final 2ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 4     ex12e04           5           1       1      True     True
# **Ejercicio: **ex12e05
#                 enunciado_latex                            enunciado  \
# 6         \cos{2x}-3\cos{x}+1=0      Eq(-3*cos(x) + cos(2*x) + 1, 0)
# 5  2\cos^2{x}-\sqrt{3}\cos{x}=0  Eq(2*cos(x)**2 - sqrt(3)*cos(x), 0)
#
#                                             solucion  \
# 6                      \left [ -90, \quad 90\right ]
# 5  \left [ 30, \quad 90, \quad 270, \quad 330\rig...
#
#                                  texto curso        titulo n_ejercicio  \
# 6  Resolver las siguientes ecuaciones:   1BC  Final 2ª Ev.     ex12e05
# 5  Resolver las siguientes ecuaciones:   1BC  Final 2ª Ev.     ex12e05
#
#    dificultad  n_columnas  puntos  enun_tex  sol_tex
# 6           1           1       1      True     True
# 5           1           1       1      True     True
# **Ejercicio: **ex12e06
#                   enunciado_latex                            enunciado  \
# 7  \frac{(1+2i)i^7}{(3-2i)-(2+i)}  (i**7*(2*i + 1))/(-2*i + 3 - i - 2)
#
#                     solucion     texto curso        titulo n_ejercicio  \
# 7  \frac{1}{2} + \frac{i}{2}  Calcula:   1BC  Final 2ª Ev.     ex12e06
#
#    dificultad  n_columnas  puntos  enun_tex  sol_tex
# 7           2           1       1      True     True
# **Ejercicio: **ex12e07
#     enunciado_latex         enunciado             solucion  \
# 10               -4                -4              4_{\pi}
# 9                2i               2*i    2_{\frac{\pi}{2}}
# 8   2 - 2\sqrt {3}i  -2*sqrt(3)*i + 2  4_{- \frac{\pi}{3}}
#
#                                                 texto curso        titulo  \
# 10  Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
# 9   Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
# 8   Escribe los siguientes números complejos en fo...   1BC  Final 2ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 10     ex12e07           1           1       1      True     True
# 9      ex12e07           1           1       1      True     True
# 8      ex12e07           1           1       1      True     True
