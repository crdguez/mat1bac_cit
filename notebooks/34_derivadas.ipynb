# %%
from sympy import init_session
from sympy import div, QQ
from sympy.parsing.latex import parse_latex
from sympy.parsing.sympy_parser import parse_expr
from IPython.display import Markdown as md
from IPython.display import display
import pandas as pd

import numpy as np




init_session()

a, b, c, d = symbols('a b c d', real = True)
from docparts import añadir_ejercicios, doc_ejer, escribir_preambulo, escribir_ejercicios, escribir_fin

df_ejercicios = pd.DataFrame()

fichero = 'deriv'
titulo = 'Derivadas'
curso = '1BC'


x,y = symbols('x, y', real=True)

import matplotlib.pyplot as plt
from matplotlib import style
#style.use('ggplot')
style.use('seaborn-whitegrid')


# %matplotlib inline
# Out:
# IPython console for SymPy 1.4 (Python 3.6.8-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.4/

# %%
puntuacion = '1'                          
                      
datos =  [  
            '2*x', '3*x-5', '7*x**5-3*x**2+x+2345', 'x*(x+2)', '(x+1)*(x-1)', 
            '5/7*x**4-1/55*x**3-3/4*x**2+x-1255', '(x+1)**3', '(x**3+x+1)**4',
            '(3*x+1)**2 - (3*x-1)**2', '1/x**2', '1/(x+1)', '(x**2-3)/(x**3+x)', '(x+1)/x',
            '(x*(x**2-1)/3*x**2-3)', 'x**(-3)', 'x**(1/2)', 'x**(2/3)', 'x**(-2/3)',
            'x**(1/2)+x**(1/6)+x**(1/5)', 'sqrt(3*x)', 
   
         ]
        

# vectores iniciales correspondientes al texto del enunciado

n_ejercicio = 'p80e16'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t))))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=2 x$ $ \rightarrow $$y'=2$
# $y=3 x - 5$ $ \rightarrow $$y'=3$
# $y=7 x^{5} - 3 x^{2} + x + 2345$ $ \rightarrow $$y'=35 x^{4} - 6 x + 1$
# $y=x \left(x + 2\right)$ $ \rightarrow $$y'=2 x + 2$
# $y=\left(x - 1\right) \left(x + 1\right)$ $ \rightarrow $$y'=2 x$
# $y=\frac{5 x^{4}}{7} - \frac{x^{3}}{55} - \frac{3 x^{2}}{4} + x - 1255$ $ \rightarrow $$y'=\frac{20 x^{3}}{7} - \frac{3 x^{2}}{55} - \frac{3 x}{2} + 1$
# $y=\left(x + 1\right)^{3}$ $ \rightarrow $$y'=3 \left(x + 1\right)^{2}$
# $y=\left(x^{3} + x + 1\right)^{4}$ $ \rightarrow $$y'=\left(12 x^{2} + 4\right) \left(x^{3} + x + 1\right)^{3}$
# $y=- \left(3 x - 1\right)^{2} + \left(3 x + 1\right)^{2}$ $ \rightarrow $$y'=12$
# $y=\frac{1}{x^{2}}$ $ \rightarrow $$y'=- \frac{2}{x^{3}}$
# $y=\frac{1}{x + 1}$ $ \rightarrow $$y'=- \frac{1}{\left(x + 1\right)^{2}}$
# $y=\frac{x^{2} - 3}{x^{3} + x}$ $ \rightarrow $$y'=\frac{- x^{4} + 10 x^{2} + 3}{x^{2} \left(x^{4} + 2 x^{2} + 1\right)}$
# $y=\frac{x + 1}{x}$ $ \rightarrow $$y'=- \frac{1}{x^{2}}$
# $y=\frac{x x^{2} \left(x^{2} - 1\right)}{3} - 3$ $ \rightarrow $$y'=\frac{5 x^{4}}{3} - x^{2}$
# $y=\frac{1}{x^{3}}$ $ \rightarrow $$y'=- \frac{3}{x^{4}}$
# $y=x^{\frac{1}{2}}$ $ \rightarrow $$y'=\frac{1}{2 \sqrt{x}}$
# $y=x^{\frac{2}{3}}$ $ \rightarrow $$y'=\frac{2}{3 \sqrt[3]{x}}$
# $y=x^{\frac{-2}{3}}$ $ \rightarrow $$y'=- \frac{2}{3 x^{\frac{5}{3}}}$
# $y=x^{\frac{1}{2}} + x^{\frac{1}{5}} + x^{\frac{1}{6}}$ $ \rightarrow $$y'=\frac{\frac{x^{\frac{49}{30}}}{2} + \frac{x^{\frac{13}{10}}}{6} + \frac{x^{\frac{4}{3}}}{5}}{x^{\frac{32}{15}}}$
# $y=\sqrt{3} \sqrt{x}$ $ \rightarrow $$y'=\frac{\sqrt{3}}{2 \sqrt{x}}$

# %%
puntuacion = '1'                          
                      
datos =  [  
            'x**3/sqrt(x)', 'x**3*x**(1/3)',
            'sqrt(x)/x','(1-x**2)**3', 'sqrt(2*x-4)', 'sqrt(2-x)', 'cbrt(2*x**2)',
            'sqrt(3*x**2-1)', '(2*x)/sqrt(x-1)', 'sqrt((1-x)/(1+x))', 'E**(2*x)',
            '2**(5*x)', '8**(3*x**2-1)', 'a**x*x**a','E**sqrt(x)','log(2*x-1,10)','log(x+3,E)',
            'cos(5*x)','3*tan(2*x)','sin(x)**2','sin(x**2)'
            
    
   
         ]
        

# vectores iniciales correspondientes al texto del enunciado

n_ejercicio = 'p80e16-cont'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    #sol=r"$y'="+latex(simplify(diff(S(t))))+r"$"
    sol=r"$y'="+latex(simplify(nsimplify(diff(eval(t),x))))+r"$"

    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=\frac{x^{3}}{\sqrt{x}}$ $ \rightarrow $$y'=\frac{5 x^{\frac{3}{2}}}{2}$
# $y=x^{3} x^{\frac{1}{3}}$ $ \rightarrow $$y'=\frac{10 x^{\frac{7}{3}}}{3}$
# $y=\frac{\sqrt{x}}{x}$ $ \rightarrow $$y'=- \frac{1}{2 x^{\frac{3}{2}}}$
# $y=\left(1 - x^{2}\right)^{3}$ $ \rightarrow $$y'=- 6 x \left(x^{2} - 1\right)^{2}$
# $y=\sqrt{2 x - 4}$ $ \rightarrow $$y'=\frac{\sqrt{2}}{2 \sqrt{x - 2}}$
# $y=\sqrt{2 - x}$ $ \rightarrow $$y'=- \frac{1}{2 \sqrt{2 - x}}$
# $y=\sqrt[3]{2} \sqrt[3]{x^{2}}$ $ \rightarrow $$y'=\frac{2 \sqrt[3]{2} \operatorname{sign}{\left(x \right)}}{3 \sqrt[3]{\left|{x}\right|}}$
# $y=\sqrt{3 x^{2} - 1}$ $ \rightarrow $$y'=\frac{3 x}{\sqrt{3 x^{2} - 1}}$
# $y=\frac{2 x}{\sqrt{x - 1}}$ $ \rightarrow $$y'=\frac{x - 2}{\left(x - 1\right)^{\frac{3}{2}}}$
# $y=\sqrt{\frac{1 - x}{x + 1}}$ $ \rightarrow $$y'=\frac{\sqrt{\frac{1 - x}{x + 1}}}{x^{2} - 1}$
# $y=e^{2 x}$ $ \rightarrow $$y'=2 e^{2 x}$
# $y=2^{5 x}$ $ \rightarrow $$y'=5 \cdot 32^{x} \log{\left(2 \right)}$
# $y=8^{3 x^{2} - 1}$ $ \rightarrow $$y'=9 \cdot 2^{9 x^{2} - 2} x \log{\left(2 \right)}$
# $y=a^{x} x^{a}$ $ \rightarrow $$y'=a^{x} x^{a - 1} \left(a + x \log{\left(a \right)}\right)$
# $y=e^{\sqrt{x}}$ $ \rightarrow $$y'=\frac{e^{\sqrt{x}}}{2 \sqrt{x}}$
# $y=\frac{\log{\left(2 x - 1 \right)}}{\log{\left(10 \right)}}$ $ \rightarrow $$y'=\frac{2}{\left(2 x - 1\right) \log{\left(10 \right)}}$
# $y=\log{\left(x + 3 \right)}$ $ \rightarrow $$y'=\frac{1}{x + 3}$
# $y=\cos{\left(5 x \right)}$ $ \rightarrow $$y'=- 5 \sin{\left(5 x \right)}$
# $y=3 \tan{\left(2 x \right)}$ $ \rightarrow $$y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# $y=\sin^{2}{\left(x \right)}$ $ \rightarrow $$y'=\sin{\left(2 x \right)}$
# $y=\sin{\left(x^{2} \right)}$ $ \rightarrow $$y'=2 x \cos{\left(x^{2} \right)}$

# %%
puntuacion = '1'                          
                      
datos =  [  
        'log(3*x**2-7)','log((x-2)**2)','log(x**2-2*x,10)','log(2*x**3+3*x**2,2)',
        'sqrt(log(x))','log(x)/x','log((1-x)/(1+x))','log(x**(3/4))','log(1+2*x,4)',
        'log((E**x/(E**x-1)))', '(1-log(x))/(1+log(x))', 'E**x/(x-1)',
        '(E**x-E**(-x))/E**x+E**(-x)', 'E**(sqrt(x**2+1))','sin(2*x)', 'sin(7*x-3)',
        'cos(5*x)','3*tan(2*x)','(sin(x))**2','sin(x**2)',
   
         ]
        

# vectores iniciales correspondientes al texto del enunciado

n_ejercicio = 'p80e17'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex(simplify(diff(S(t))))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=\log{\left(3 x^{2} - 7 \right)}$ $ \rightarrow $$y'=\frac{6 x}{3 x^{2} - 7}$
# $y=\log{\left(\left(x - 2\right)^{2} \right)}$ $ \rightarrow $$y'=\frac{2}{x - 2}$
# $y=\frac{\log{\left(x^{2} - 2 x \right)}}{\log{\left(10 \right)}}$ $ \rightarrow $$y'=\frac{2 \left(x - 1\right)}{x \left(x - 2\right) \log{\left(10 \right)}}$
# $y=\frac{\log{\left(2 x^{3} + 3 x^{2} \right)}}{\log{\left(2 \right)}}$ $ \rightarrow $$y'=\frac{6 \left(x + 1\right)}{x \left(2 x + 3\right) \log{\left(2 \right)}}$
# $y=\sqrt{\log{\left(x \right)}}$ $ \rightarrow $$y'=\frac{1}{2 x \sqrt{\log{\left(x \right)}}}$
# $y=\frac{\log{\left(x \right)}}{x}$ $ \rightarrow $$y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# $y=\log{\left(\frac{1 - x}{x + 1} \right)}$ $ \rightarrow $$y'=\frac{2}{x^{2} - 1}$
# $y=\log{\left(x^{\frac{3}{4}} \right)}$ $ \rightarrow $$y'=\frac{3}{4 x}$
# $y=\frac{\log{\left(2 x + 1 \right)}}{\log{\left(4 \right)}}$ $ \rightarrow $$y'=\frac{1}{\left(2 x + 1\right) \log{\left(2 \right)}}$
# $y=\log{\left(\frac{e^{x}}{e^{x} - 1} \right)}$ $ \rightarrow $$y'=\frac{1}{1 - e^{x}}$
# $y=\frac{1 - \log{\left(x \right)}}{\log{\left(x \right)} + 1}$ $ \rightarrow $$y'=- \frac{2}{x \left(\log{\left(x \right)} + 1\right)^{2}}$
# $y=\frac{e^{x}}{x - 1}$ $ \rightarrow $$y'=\frac{\left(x - 2\right) e^{x}}{x^{2} - 2 x + 1}$
# $y=e^{- x} + \frac{e^{x} - e^{- x}}{e^{x}}$ $ \rightarrow $$y'=\left(2 - e^{x}\right) e^{- 2 x}$
# $y=e^{\sqrt{x^{2} + 1}}$ $ \rightarrow $$y'=\frac{x e^{\sqrt{x^{2} + 1}}}{\sqrt{x^{2} + 1}}$
# $y=\sin{\left(2 x \right)}$ $ \rightarrow $$y'=2 \cos{\left(2 x \right)}$
# $y=\sin{\left(7 x - 3 \right)}$ $ \rightarrow $$y'=7 \cos{\left(7 x - 3 \right)}$
# $y=\cos{\left(5 x \right)}$ $ \rightarrow $$y'=- 5 \sin{\left(5 x \right)}$
# $y=3 \tan{\left(2 x \right)}$ $ \rightarrow $$y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# $y=\sin^{2}{\left(x \right)}$ $ \rightarrow $$y'=\sin{\left(2 x \right)}$
# $y=\sin{\left(x^{2} \right)}$ $ \rightarrow $$y'=2 x \cos{\left(x^{2} \right)}$

# %%
puntuacion = '1'                          
                      
datos =  [ 
    
    'cos(x**2+1)**2','tan(5*x)**3',
        'sin(4*x)**3','sqrt(sin(2*x))','log(tan(1-x))','cbrt(sin(x))','(sin(x)**3)*cos(x)',
        'sec(5*x+2)','asin(2*x)','acos(x**2)','atan((x-1)/(1-x))','asin((x+1)/(x-1))',
        'tan(sin(x))**2','(sin(x))**(1/x)','x**tan(x)','2**(log(cos(x)))','sin(x)**atan(x)',
        'atan(x)**x','x**sec(x)'
   
         ]
        

# vectores iniciales correspondientes al texto del enunciado

n_ejercicio = 'p80e17-cont'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(nsimplify(S(t)))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex((diff(S(t))))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=\cos^{2}{\left(x^{2} + 1 \right)}$ $ \rightarrow $$y'=- 4 x \sin{\left(x^{2} + 1 \right)} \cos{\left(x^{2} + 1 \right)}$
# $y=\tan^{3}{\left(5 x \right)}$ $ \rightarrow $$y'=\left(15 \tan^{2}{\left(5 x \right)} + 15\right) \tan^{2}{\left(5 x \right)}$
# $y=\sin^{3}{\left(4 x \right)}$ $ \rightarrow $$y'=12 \sin^{2}{\left(4 x \right)} \cos{\left(4 x \right)}$
# $y=\sqrt{\sin{\left(2 x \right)}}$ $ \rightarrow $$y'=\frac{\cos{\left(2 x \right)}}{\sqrt{\sin{\left(2 x \right)}}}$
# $y=\log{\left(- \tan{\left(x - 1 \right)} \right)}$ $ \rightarrow $$y'=- \frac{- \tan^{2}{\left(x - 1 \right)} - 1}{\tan{\left(x - 1 \right)}}$
# $y=\sqrt[3]{\sin{\left(x \right)}}$ $ \rightarrow $$y'=\frac{\cos{\left(x \right)}}{3 \sin^{\frac{2}{3}}{\left(x \right)}}$
# $y=\sin^{3}{\left(x \right)} \cos{\left(x \right)}$ $ \rightarrow $$y'=- \sin^{4}{\left(x \right)} + 3 \sin^{2}{\left(x \right)} \cos^{2}{\left(x \right)}$
# $y=\sec{\left(5 x + 2 \right)}$ $ \rightarrow $$y'=5 \tan{\left(5 x + 2 \right)} \sec{\left(5 x + 2 \right)}$
# $y=\operatorname{asin}{\left(2 x \right)}$ $ \rightarrow $$y'=\frac{2}{\sqrt{1 - 4 x^{2}}}$
# $y=\operatorname{acos}{\left(x^{2} \right)}$ $ \rightarrow $$y'=- \frac{2 x}{\sqrt{1 - x^{4}}}$
# $y=\operatorname{atan}{\left(\frac{x - 1}{1 - x} \right)}$ $ \rightarrow $$y'=\frac{\frac{1}{1 - x} + \frac{x - 1}{\left(1 - x\right)^{2}}}{1 + \frac{\left(x - 1\right)^{2}}{\left(1 - x\right)^{2}}}$
# $y=\operatorname{asin}{\left(\frac{x + 1}{x - 1} \right)}$ $ \rightarrow $$y'=\frac{\frac{1}{x - 1} - \frac{x + 1}{\left(x - 1\right)^{2}}}{\sqrt{1 - \frac{\left(x + 1\right)^{2}}{\left(x - 1\right)^{2}}}}$
# $y=\tan^{2}{\left(\sin{\left(x \right)} \right)}$ $ \rightarrow $$y'=2 \left(\tan^{2}{\left(\sin{\left(x \right)} \right)} + 1\right) \cos{\left(x \right)} \tan{\left(\sin{\left(x \right)} \right)}$
# $y=\sin^{\frac{1}{x}}{\left(x \right)}$ $ \rightarrow $$y'=\left(\frac{\cos{\left(x \right)}}{x \sin{\left(x \right)}} - \frac{\log{\left(\sin{\left(x \right)} \right)}}{x^{2}}\right) \sin^{\frac{1}{x}}{\left(x \right)}$
# $y=x^{\tan{\left(x \right)}}$ $ \rightarrow $$y'=x^{\tan{\left(x \right)}} \left(\left(\tan^{2}{\left(x \right)} + 1\right) \log{\left(x \right)} + \frac{\tan{\left(x \right)}}{x}\right)$
# $y=2^{\log{\left(\cos{\left(x \right)} \right)}}$ $ \rightarrow $$y'=- \frac{2^{\log{\left(\cos{\left(x \right)} \right)}} \log{\left(2 \right)} \sin{\left(x \right)}}{\cos{\left(x \right)}}$
# $y=\sin^{\operatorname{atan}{\left(x \right)}}{\left(x \right)}$ $ \rightarrow $$y'=\left(\frac{\cos{\left(x \right)} \operatorname{atan}{\left(x \right)}}{\sin{\left(x \right)}} + \frac{\log{\left(\sin{\left(x \right)} \right)}}{x^{2} + 1}\right) \sin^{\operatorname{atan}{\left(x \right)}}{\left(x \right)}$
# $y=\operatorname{atan}^{x}{\left(x \right)}$ $ \rightarrow $$y'=\left(\frac{x}{\left(x^{2} + 1\right) \operatorname{atan}{\left(x \right)}} + \log{\left(\operatorname{atan}{\left(x \right)} \right)}\right) \operatorname{atan}^{x}{\left(x \right)}$
# $y=x^{\sec{\left(x \right)}}$ $ \rightarrow $$y'=x^{\sec{\left(x \right)}} \left(\log{\left(x \right)} \tan{\left(x \right)} \sec{\left(x \right)} + \frac{\sec{\left(x \right)}}{x}\right)$

# %%
puntuacion = '1'                          
                      
datos =  [  
        'x**log(x)','root(x,x)','cos(x)**sin(x)'
   
         ]
        

# vectores iniciales correspondientes al texto del enunciado

n_ejercicio = 'p81e18'
enunciado_latex, enunciado, solucion = [],[],[]

texto_ejercicio = r"""Calcula las siguientes derivadas:
"""

display(md("**"+texto_ejercicio+"**"))

for j, t in enumerate(datos):
    enunciado_latex.append(r'$y='+latex(S(t,evaluate=False))+r'$')
    enunciado.append(r'diff('+str(S(t))+r')')
    #display(S(t),diff(S(t)))
    sol=r"$y'="+latex((diff(S(t))))+r"$"
    solucion.append(sol)
    display(md(enunciado_latex[j] +" $ \\rightarrow $" + solucion[j] ))


df_ejercicios = df_ejercicios.append(añadir_ejercicios(enunciado_latex, enunciado, solucion, texto_ejercicio, curso, titulo , n_ejercicio, '5', '2', enun_tex=False, sol_tex=False), ignore_index=True)
# Out:
# **Calcula las siguientes derivadas:
# **
# $y=x^{\log{\left(x \right)}}$ $ \rightarrow $$y'=\frac{2 x^{\log{\left(x \right)}} \log{\left(x \right)}}{x}$
# $y=x^{\frac{1}{x}}$ $ \rightarrow $$y'=x^{\frac{1}{x}} \left(- \frac{\log{\left(x \right)}}{x^{2}} + \frac{1}{x^{2}}\right)$
# $y=\cos^{\sin{\left(x \right)}}{\left(x \right)}$ $ \rightarrow $$y'=\left(\log{\left(\cos{\left(x \right)} \right)} \cos{\left(x \right)} - \frac{\sin^{2}{\left(x \right)}}{\cos{\left(x \right)}}\right) \cos^{\sin{\left(x \right)}}{\left(x \right)}$

# %%
df_ejercicios
# Out:
#                                       enunciado_latex  \
# 0                                             $y=2 x$
# 1                                         $y=3 x - 5$
# 2                    $y=7 x^{5} - 3 x^{2} + x + 2345$
# 3                            $y=x \left(x + 2\right)$
# 4           $y=\left(x - 1\right) \left(x + 1\right)$
# 5   $y=\frac{5 x^{4}}{7} - \frac{x^{3}}{55} - \fra...
# 6                          $y=\left(x + 1\right)^{3}$
# 7                  $y=\left(x^{3} + x + 1\right)^{4}$
# 8   $y=- \left(3 x - 1\right)^{2} + \left(3 x + 1\...
# 9                                 $y=\frac{1}{x^{2}}$
# 10                                $y=\frac{1}{x + 1}$
# 11                    $y=\frac{x^{2} - 3}{x^{3} + x}$
# 12                                $y=\frac{x + 1}{x}$
# 13   $y=\frac{x x^{2} \left(x^{2} - 1\right)}{3} - 3$
# 14                                $y=\frac{1}{x^{3}}$
# 15                                $y=x^{\frac{1}{2}}$
# 16                                $y=x^{\frac{2}{3}}$
# 17                               $y=x^{\frac{-2}{3}}$
# 18  $y=x^{\frac{1}{2}} + x^{\frac{1}{5}} + x^{\fra...
# 19                              $y=\sqrt{3} \sqrt{x}$
# 20                         $y=\frac{x^{3}}{\sqrt{x}}$
# 21                          $y=x^{3} x^{\frac{1}{3}}$
# 22                             $y=\frac{\sqrt{x}}{x}$
# 23                     $y=\left(1 - x^{2}\right)^{3}$
# 24                                 $y=\sqrt{2 x - 4}$
# 25                                   $y=\sqrt{2 - x}$
# 26                    $y=\sqrt[3]{2} \sqrt[3]{x^{2}}$
# 27                             $y=\sqrt{3 x^{2} - 1}$
# 28                       $y=\frac{2 x}{\sqrt{x - 1}}$
# 29                     $y=\sqrt{\frac{1 - x}{x + 1}}$
# ..                                                ...
# 53        $y=e^{- x} + \frac{e^{x} - e^{- x}}{e^{x}}$
# 54                           $y=e^{\sqrt{x^{2} + 1}}$
# 55                        $y=\sin{\left(2 x \right)}$
# 56                    $y=\sin{\left(7 x - 3 \right)}$
# 57                        $y=\cos{\left(5 x \right)}$
# 58                      $y=3 \tan{\left(2 x \right)}$
# 59                      $y=\sin^{2}{\left(x \right)}$
# 60                      $y=\sin{\left(x^{2} \right)}$
# 61              $y=\cos^{2}{\left(x^{2} + 1 \right)}$
# 62                    $y=\tan^{3}{\left(5 x \right)}$
# 63                    $y=\sin^{3}{\left(4 x \right)}$
# 64                 $y=\sqrt{\sin{\left(2 x \right)}}$
# 65  $y=\log{\left(- \tan{\left(x - 1 \right)} \rig...
# 66                $y=\sqrt[3]{\sin{\left(x \right)}}$
# 67  $y=\sin^{3}{\left(x \right)} \cos{\left(x \rig...
# 68                    $y=\sec{\left(5 x + 2 \right)}$
# 69         $y=\operatorname{asin}{\left(2 x \right)}$
# 70       $y=\operatorname{acos}{\left(x^{2} \right)}$
# 71  $y=\operatorname{atan}{\left(\frac{x - 1}{1 - ...
# 72  $y=\operatorname{asin}{\left(\frac{x + 1}{x - ...
# 73  $y=\tan^{2}{\left(\sin{\left(x \right)} \right)}$
# 74            $y=\sin^{\frac{1}{x}}{\left(x \right)}$
# 75                      $y=x^{\tan{\left(x \right)}}$
# 76  $y=2^{\log{\left(\cos{\left(x \right)} \right)}}$
# 77  $y=\sin^{\operatorname{atan}{\left(x \right)}}...
# 78       $y=\operatorname{atan}^{x}{\left(x \right)}$
# 79                      $y=x^{\sec{\left(x \right)}}$
# 80                      $y=x^{\log{\left(x \right)}}$
# 81                                $y=x^{\frac{1}{x}}$
# 82  $y=\cos^{\sin{\left(x \right)}}{\left(x \right)}$
#
#                                          enunciado  \
# 0                                        diff(2*x)
# 1                                    diff(3*x - 5)
# 2                 diff(7*x**5 - 3*x**2 + x + 2345)
# 3                                  diff(x*(x + 2))
# 4                            diff((x - 1)*(x + 1))
# 5   diff(5*x**4/7 - x**3/55 - 3*x**2/4 + x - 1255)
# 6                                 diff((x + 1)**3)
# 7                          diff((x**3 + x + 1)**4)
# 8               diff(-(3*x - 1)**2 + (3*x + 1)**2)
# 9                                    diff(x**(-2))
# 10                                 diff(1/(x + 1))
# 11                     diff((x**2 - 3)/(x**3 + x))
# 12                                 diff((x + 1)/x)
# 13                     diff(x**3*(x**2 - 1)/3 - 3)
# 14                                   diff(x**(-3))
# 15                                   diff(sqrt(x))
# 16                                  diff(x**(2/3))
# 17                                 diff(x**(-2/3))
# 18             diff(x**(1/6) + x**(1/5) + sqrt(x))
# 19                           diff(sqrt(3)*sqrt(x))
# 20                                  diff(x**(5/2))
# 21                                 diff(x**(10/3))
# 22                                 diff(1/sqrt(x))
# 23                             diff((1 - x**2)**3)
# 24                             diff(sqrt(2*x - 4))
# 25                               diff(sqrt(2 - x))
# 26                    diff(2**(1/3)*(x**2)**(1/3))
# 27                          diff(sqrt(3*x**2 - 1))
# 28                           diff(2*x/sqrt(x - 1))
# 29                     diff(sqrt((1 - x)/(x + 1)))
# ..                                             ...
# 53      diff((exp(x) - exp(-x))*exp(-x) + exp(-x))
# 54                       diff(exp(sqrt(x**2 + 1)))
# 55                                  diff(sin(2*x))
# 56                              diff(sin(7*x - 3))
# 57                                  diff(cos(5*x))
# 58                                diff(3*tan(2*x))
# 59                                 diff(sin(x)**2)
# 60                                 diff(sin(x**2))
# 61                          diff(cos(x**2 + 1)**2)
# 62                               diff(tan(5*x)**3)
# 63                               diff(sin(4*x)**3)
# 64                            diff(sqrt(sin(2*x)))
# 65                          diff(log(-tan(x - 1)))
# 66                             diff(sin(x)**(1/3))
# 67                          diff(sin(x)**3*cos(x))
# 68                              diff(sec(5*x + 2))
# 69                                 diff(asin(2*x))
# 70                                diff(acos(x**2))
# 71                     diff(atan((x - 1)/(1 - x)))
# 72                     diff(asin((x + 1)/(x - 1)))
# 73                            diff(tan(sin(x))**2)
# 74                             diff(sin(x)**(1/x))
# 75                                 diff(x**tan(x))
# 76                            diff(2**log(cos(x)))
# 77                           diff(sin(x)**atan(x))
# 78                                diff(atan(x)**x)
# 79                                 diff(x**sec(x))
# 80                                 diff(x**log(x))
# 81                                  diff(x**(1/x))
# 82                            diff(cos(x)**sin(x))
#
#                                              solucion  \
# 0                                              $y'=2$
# 1                                              $y'=3$
# 2                             $y'=35 x^{4} - 6 x + 1$
# 3                                        $y'=2 x + 2$
# 4                                            $y'=2 x$
# 5   $y'=\frac{20 x^{3}}{7} - \frac{3 x^{2}}{55} - ...
# 6                       $y'=3 \left(x + 1\right)^{2}$
# 7   $y'=\left(12 x^{2} + 4\right) \left(x^{3} + x ...
# 8                                             $y'=12$
# 9                              $y'=- \frac{2}{x^{3}}$
# 10            $y'=- \frac{1}{\left(x + 1\right)^{2}}$
# 11  $y'=\frac{- x^{4} + 10 x^{2} + 3}{x^{2} \left(...
# 12                             $y'=- \frac{1}{x^{2}}$
# 13                     $y'=\frac{5 x^{4}}{3} - x^{2}$
# 14                             $y'=- \frac{3}{x^{4}}$
# 15                          $y'=\frac{1}{2 \sqrt{x}}$
# 16                       $y'=\frac{2}{3 \sqrt[3]{x}}$
# 17                 $y'=- \frac{2}{3 x^{\frac{5}{3}}}$
# 18  $y'=\frac{\frac{x^{\frac{49}{30}}}{2} + \frac{...
# 19                   $y'=\frac{\sqrt{3}}{2 \sqrt{x}}$
# 20                   $y'=\frac{5 x^{\frac{3}{2}}}{2}$
# 21                  $y'=\frac{10 x^{\frac{7}{3}}}{3}$
# 22                 $y'=- \frac{1}{2 x^{\frac{3}{2}}}$
# 23              $y'=- 6 x \left(x^{2} - 1\right)^{2}$
# 24               $y'=\frac{\sqrt{2}}{2 \sqrt{x - 2}}$
# 25                    $y'=- \frac{1}{2 \sqrt{2 - x}}$
# 26  $y'=\frac{2 \sqrt[3]{2} \operatorname{sign}{\l...
# 27                $y'=\frac{3 x}{\sqrt{3 x^{2} - 1}}$
# 28  $y'=\frac{x - 2}{\left(x - 1\right)^{\frac{3}{...
# 29  $y'=\frac{\sqrt{\frac{1 - x}{x + 1}}}{x^{2} - 1}$
# ..                                                ...
# 53              $y'=\left(2 - e^{x}\right) e^{- 2 x}$
# 54  $y'=\frac{x e^{\sqrt{x^{2} + 1}}}{\sqrt{x^{2} ...
# 55                     $y'=2 \cos{\left(2 x \right)}$
# 56                 $y'=7 \cos{\left(7 x - 3 \right)}$
# 57                   $y'=- 5 \sin{\left(5 x \right)}$
# 58         $y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# 59                       $y'=\sin{\left(2 x \right)}$
# 60                 $y'=2 x \cos{\left(x^{2} \right)}$
# 61  $y'=- 4 x \sin{\left(x^{2} + 1 \right)} \cos{\...
# 62  $y'=\left(15 \tan^{2}{\left(5 x \right)} + 15\...
# 63  $y'=12 \sin^{2}{\left(4 x \right)} \cos{\left(...
# 64  $y'=\frac{\cos{\left(2 x \right)}}{\sqrt{\sin{...
# 65  $y'=- \frac{- \tan^{2}{\left(x - 1 \right)} - ...
# 66  $y'=\frac{\cos{\left(x \right)}}{3 \sin^{\frac...
# 67  $y'=- \sin^{4}{\left(x \right)} + 3 \sin^{2}{\...
# 68  $y'=5 \tan{\left(5 x + 2 \right)} \sec{\left(5...
# 69                  $y'=\frac{2}{\sqrt{1 - 4 x^{2}}}$
# 70                $y'=- \frac{2 x}{\sqrt{1 - x^{4}}}$
# 71  $y'=\frac{\frac{1}{1 - x} + \frac{x - 1}{\left...
# 72  $y'=\frac{\frac{1}{x - 1} - \frac{x + 1}{\left...
# 73  $y'=2 \left(\tan^{2}{\left(\sin{\left(x \right...
# 74  $y'=\left(\frac{\cos{\left(x \right)}}{x \sin{...
# 75  $y'=x^{\tan{\left(x \right)}} \left(\left(\tan...
# 76  $y'=- \frac{2^{\log{\left(\cos{\left(x \right)...
# 77  $y'=\left(\frac{\cos{\left(x \right)} \operato...
# 78  $y'=\left(\frac{x}{\left(x^{2} + 1\right) \ope...
# 79  $y'=x^{\sec{\left(x \right)}} \left(\log{\left...
# 80  $y'=\frac{2 x^{\log{\left(x \right)}} \log{\le...
# 81  $y'=x^{\frac{1}{x}} \left(- \frac{\log{\left(x...
# 82  $y'=\left(\log{\left(\cos{\left(x \right)} \ri...
#
#                                   texto curso     titulo  n_ejercicio  \
# 0   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 1   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 2   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 3   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 4   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 5   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 6   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 7   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 8   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 9   Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 10  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 11  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 12  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 13  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 14  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 15  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 16  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 17  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 18  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 19  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e16
# 20  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 21  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 22  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 23  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 24  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 25  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 26  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 27  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 28  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 29  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# ..                                  ...   ...        ...          ...
# 53  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e17
# 54  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e17
# 55  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e17
# 56  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e17
# 57  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e17
# 58  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e17
# 59  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e17
# 60  Calcula las siguientes derivadas:\n   1BC  Derivadas       p80e17
# 61  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 62  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 63  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 64  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 65  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 66  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 67  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 68  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 69  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 70  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 71  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 72  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 73  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 74  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 75  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 76  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 77  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 78  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 79  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 80  Calcula las siguientes derivadas:\n   1BC  Derivadas       p81e18
# 81  Calcula las siguientes derivadas:\n   1BC  Derivadas       p81e18
# 82  Calcula las siguientes derivadas:\n   1BC  Derivadas       p81e18
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 0           5          2      1     False    False
# 1           5          2      1     False    False
# 2           5          2      1     False    False
# 3           5          2      1     False    False
# 4           5          2      1     False    False
# 5           5          2      1     False    False
# 6           5          2      1     False    False
# 7           5          2      1     False    False
# 8           5          2      1     False    False
# 9           5          2      1     False    False
# 10          5          2      1     False    False
# 11          5          2      1     False    False
# 12          5          2      1     False    False
# 13          5          2      1     False    False
# 14          5          2      1     False    False
# 15          5          2      1     False    False
# 16          5          2      1     False    False
# 17          5          2      1     False    False
# 18          5          2      1     False    False
# 19          5          2      1     False    False
# 20          5          2      1     False    False
# 21          5          2      1     False    False
# 22          5          2      1     False    False
# 23          5          2      1     False    False
# 24          5          2      1     False    False
# 25          5          2      1     False    False
# 26          5          2      1     False    False
# 27          5          2      1     False    False
# 28          5          2      1     False    False
# 29          5          2      1     False    False
# ..        ...        ...    ...       ...      ...
# 53          5          2      1     False    False
# 54          5          2      1     False    False
# 55          5          2      1     False    False
# 56          5          2      1     False    False
# 57          5          2      1     False    False
# 58          5          2      1     False    False
# 59          5          2      1     False    False
# 60          5          2      1     False    False
# 61          5          2      1     False    False
# 62          5          2      1     False    False
# 63          5          2      1     False    False
# 64          5          2      1     False    False
# 65          5          2      1     False    False
# 66          5          2      1     False    False
# 67          5          2      1     False    False
# 68          5          2      1     False    False
# 69          5          2      1     False    False
# 70          5          2      1     False    False
# 71          5          2      1     False    False
# 72          5          2      1     False    False
# 73          5          2      1     False    False
# 74          5          2      1     False    False
# 75          5          2      1     False    False
# 76          5          2      1     False    False
# 77          5          2      1     False    False
# 78          5          2      1     False    False
# 79          5          2      1     False    False
# 80          5          2      1     False    False
# 81          5          2      1     False    False
# 82          5          2      1     False    False
#
# [83 rows x 12 columns]

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **p80e16
#                                       enunciado_latex  \
# 0                                             $y=2 x$
# 1                                         $y=3 x - 5$
# 2                    $y=7 x^{5} - 3 x^{2} + x + 2345$
# 3                            $y=x \left(x + 2\right)$
# 4           $y=\left(x - 1\right) \left(x + 1\right)$
# 5   $y=\frac{5 x^{4}}{7} - \frac{x^{3}}{55} - \fra...
# 6                          $y=\left(x + 1\right)^{3}$
# 7                  $y=\left(x^{3} + x + 1\right)^{4}$
# 8   $y=- \left(3 x - 1\right)^{2} + \left(3 x + 1\...
# 9                                 $y=\frac{1}{x^{2}}$
# 10                                $y=\frac{1}{x + 1}$
# 11                    $y=\frac{x^{2} - 3}{x^{3} + x}$
# 12                                $y=\frac{x + 1}{x}$
# 13   $y=\frac{x x^{2} \left(x^{2} - 1\right)}{3} - 3$
# 14                                $y=\frac{1}{x^{3}}$
# 15                                $y=x^{\frac{1}{2}}$
# 16                                $y=x^{\frac{2}{3}}$
# 17                               $y=x^{\frac{-2}{3}}$
# 18  $y=x^{\frac{1}{2}} + x^{\frac{1}{5}} + x^{\fra...
# 19                              $y=\sqrt{3} \sqrt{x}$
#
#                                          enunciado  \
# 0                                        diff(2*x)
# 1                                    diff(3*x - 5)
# 2                 diff(7*x**5 - 3*x**2 + x + 2345)
# 3                                  diff(x*(x + 2))
# 4                            diff((x - 1)*(x + 1))
# 5   diff(5*x**4/7 - x**3/55 - 3*x**2/4 + x - 1255)
# 6                                 diff((x + 1)**3)
# 7                          diff((x**3 + x + 1)**4)
# 8               diff(-(3*x - 1)**2 + (3*x + 1)**2)
# 9                                    diff(x**(-2))
# 10                                 diff(1/(x + 1))
# 11                     diff((x**2 - 3)/(x**3 + x))
# 12                                 diff((x + 1)/x)
# 13                     diff(x**3*(x**2 - 1)/3 - 3)
# 14                                   diff(x**(-3))
# 15                                   diff(sqrt(x))
# 16                                  diff(x**(2/3))
# 17                                 diff(x**(-2/3))
# 18             diff(x**(1/6) + x**(1/5) + sqrt(x))
# 19                           diff(sqrt(3)*sqrt(x))
#
#                                              solucion  \
# 0                                              $y'=2$
# 1                                              $y'=3$
# 2                             $y'=35 x^{4} - 6 x + 1$
# 3                                        $y'=2 x + 2$
# 4                                            $y'=2 x$
# 5   $y'=\frac{20 x^{3}}{7} - \frac{3 x^{2}}{55} - ...
# 6                       $y'=3 \left(x + 1\right)^{2}$
# 7   $y'=\left(12 x^{2} + 4\right) \left(x^{3} + x ...
# 8                                             $y'=12$
# 9                              $y'=- \frac{2}{x^{3}}$
# 10            $y'=- \frac{1}{\left(x + 1\right)^{2}}$
# 11  $y'=\frac{- x^{4} + 10 x^{2} + 3}{x^{2} \left(...
# 12                             $y'=- \frac{1}{x^{2}}$
# 13                     $y'=\frac{5 x^{4}}{3} - x^{2}$
# 14                             $y'=- \frac{3}{x^{4}}$
# 15                          $y'=\frac{1}{2 \sqrt{x}}$
# 16                       $y'=\frac{2}{3 \sqrt[3]{x}}$
# 17                 $y'=- \frac{2}{3 x^{\frac{5}{3}}}$
# 18  $y'=\frac{\frac{x^{\frac{49}{30}}}{2} + \frac{...
# 19                   $y'=\frac{\sqrt{3}}{2 \sqrt{x}}$
#
#                                   texto curso     titulo n_ejercicio  \
# 0   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 1   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 2   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 3   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 4   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 5   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 6   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 7   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 8   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 9   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 10  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 11  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 12  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 13  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 14  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 15  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 16  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 17  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 18  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 19  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 0           5          2      1     False    False
# 1           5          2      1     False    False
# 2           5          2      1     False    False
# 3           5          2      1     False    False
# 4           5          2      1     False    False
# 5           5          2      1     False    False
# 6           5          2      1     False    False
# 7           5          2      1     False    False
# 8           5          2      1     False    False
# 9           5          2      1     False    False
# 10          5          2      1     False    False
# 11          5          2      1     False    False
# 12          5          2      1     False    False
# 13          5          2      1     False    False
# 14          5          2      1     False    False
# 15          5          2      1     False    False
# 16          5          2      1     False    False
# 17          5          2      1     False    False
# 18          5          2      1     False    False
# 19          5          2      1     False    False
# **Ejercicio: **p80e16-cont
#                                       enunciado_latex  \
# 20                         $y=\frac{x^{3}}{\sqrt{x}}$
# 21                          $y=x^{3} x^{\frac{1}{3}}$
# 22                             $y=\frac{\sqrt{x}}{x}$
# 23                     $y=\left(1 - x^{2}\right)^{3}$
# 24                                 $y=\sqrt{2 x - 4}$
# 25                                   $y=\sqrt{2 - x}$
# 26                    $y=\sqrt[3]{2} \sqrt[3]{x^{2}}$
# 27                             $y=\sqrt{3 x^{2} - 1}$
# 28                       $y=\frac{2 x}{\sqrt{x - 1}}$
# 29                     $y=\sqrt{\frac{1 - x}{x + 1}}$
# 30                                        $y=e^{2 x}$
# 31                                        $y=2^{5 x}$
# 32                                $y=8^{3 x^{2} - 1}$
# 33                                    $y=a^{x} x^{a}$
# 34                                   $y=e^{\sqrt{x}}$
# 35  $y=\frac{\log{\left(2 x - 1 \right)}}{\log{\le...
# 36                      $y=\log{\left(x + 3 \right)}$
# 37                        $y=\cos{\left(5 x \right)}$
# 38                      $y=3 \tan{\left(2 x \right)}$
# 39                      $y=\sin^{2}{\left(x \right)}$
# 40                      $y=\sin{\left(x^{2} \right)}$
#
#                        enunciado  \
# 20                diff(x**(5/2))
# 21               diff(x**(10/3))
# 22               diff(1/sqrt(x))
# 23           diff((1 - x**2)**3)
# 24           diff(sqrt(2*x - 4))
# 25             diff(sqrt(2 - x))
# 26  diff(2**(1/3)*(x**2)**(1/3))
# 27        diff(sqrt(3*x**2 - 1))
# 28         diff(2*x/sqrt(x - 1))
# 29   diff(sqrt((1 - x)/(x + 1)))
# 30                diff(exp(2*x))
# 31                diff(2**(5*x))
# 32         diff(8**(3*x**2 - 1))
# 33               diff(a**x*x**a)
# 34            diff(exp(sqrt(x)))
# 35    diff(log(2*x - 1)/log(10))
# 36              diff(log(x + 3))
# 37                diff(cos(5*x))
# 38              diff(3*tan(2*x))
# 39               diff(sin(x)**2)
# 40               diff(sin(x**2))
#
#                                              solucion  \
# 20                   $y'=\frac{5 x^{\frac{3}{2}}}{2}$
# 21                  $y'=\frac{10 x^{\frac{7}{3}}}{3}$
# 22                 $y'=- \frac{1}{2 x^{\frac{3}{2}}}$
# 23              $y'=- 6 x \left(x^{2} - 1\right)^{2}$
# 24               $y'=\frac{\sqrt{2}}{2 \sqrt{x - 2}}$
# 25                    $y'=- \frac{1}{2 \sqrt{2 - x}}$
# 26  $y'=\frac{2 \sqrt[3]{2} \operatorname{sign}{\l...
# 27                $y'=\frac{3 x}{\sqrt{3 x^{2} - 1}}$
# 28  $y'=\frac{x - 2}{\left(x - 1\right)^{\frac{3}{...
# 29  $y'=\frac{\sqrt{\frac{1 - x}{x + 1}}}{x^{2} - 1}$
# 30                                     $y'=2 e^{2 x}$
# 31          $y'=5 \cdot 32^{x} \log{\left(2 \right)}$
# 32  $y'=9 \cdot 2^{9 x^{2} - 2} x \log{\left(2 \ri...
# 33  $y'=a^{x} x^{a - 1} \left(a + x \log{\left(a \...
# 34               $y'=\frac{e^{\sqrt{x}}}{2 \sqrt{x}}$
# 35  $y'=\frac{2}{\left(2 x - 1\right) \log{\left(1...
# 36                               $y'=\frac{1}{x + 3}$
# 37                   $y'=- 5 \sin{\left(5 x \right)}$
# 38         $y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# 39                       $y'=\sin{\left(2 x \right)}$
# 40                 $y'=2 x \cos{\left(x^{2} \right)}$
#
#                                   texto curso     titulo  n_ejercicio  \
# 20  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 21  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 22  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 23  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 24  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 25  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 26  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 27  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 28  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 29  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 30  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 31  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 32  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 33  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 34  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 35  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 36  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 37  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 38  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 39  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 40  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 20          5          2      1     False    False
# 21          5          2      1     False    False
# 22          5          2      1     False    False
# 23          5          2      1     False    False
# 24          5          2      1     False    False
# 25          5          2      1     False    False
# 26          5          2      1     False    False
# 27          5          2      1     False    False
# 28          5          2      1     False    False
# 29          5          2      1     False    False
# 30          5          2      1     False    False
# 31          5          2      1     False    False
# 32          5          2      1     False    False
# 33          5          2      1     False    False
# 34          5          2      1     False    False
# 35          5          2      1     False    False
# 36          5          2      1     False    False
# 37          5          2      1     False    False
# 38          5          2      1     False    False
# 39          5          2      1     False    False
# 40          5          2      1     False    False
# **Ejercicio: **p80e17
#                                       enunciado_latex  \
# 41                $y=\log{\left(3 x^{2} - 7 \right)}$
# 42     $y=\log{\left(\left(x - 2\right)^{2} \right)}$
# 43  $y=\frac{\log{\left(x^{2} - 2 x \right)}}{\log...
# 44  $y=\frac{\log{\left(2 x^{3} + 3 x^{2} \right)}...
# 45                   $y=\sqrt{\log{\left(x \right)}}$
# 46                $y=\frac{\log{\left(x \right)}}{x}$
# 47        $y=\log{\left(\frac{1 - x}{x + 1} \right)}$
# 48            $y=\log{\left(x^{\frac{3}{4}} \right)}$
# 49  $y=\frac{\log{\left(2 x + 1 \right)}}{\log{\le...
# 50    $y=\log{\left(\frac{e^{x}}{e^{x} - 1} \right)}$
# 51  $y=\frac{1 - \log{\left(x \right)}}{\log{\left...
# 52                            $y=\frac{e^{x}}{x - 1}$
# 53        $y=e^{- x} + \frac{e^{x} - e^{- x}}{e^{x}}$
# 54                           $y=e^{\sqrt{x^{2} + 1}}$
# 55                        $y=\sin{\left(2 x \right)}$
# 56                    $y=\sin{\left(7 x - 3 \right)}$
# 57                        $y=\cos{\left(5 x \right)}$
# 58                      $y=3 \tan{\left(2 x \right)}$
# 59                      $y=\sin^{2}{\left(x \right)}$
# 60                      $y=\sin{\left(x^{2} \right)}$
#
#                                      enunciado  \
# 41                       diff(log(3*x**2 - 7))
# 42                       diff(log((x - 2)**2))
# 43               diff(log(x**2 - 2*x)/log(10))
# 44           diff(log(2*x**3 + 3*x**2)/log(2))
# 45                          diff(sqrt(log(x)))
# 46                              diff(log(x)/x)
# 47                  diff(log((1 - x)/(x + 1)))
# 48                         diff(log(x**(3/4)))
# 49                   diff(log(2*x + 1)/log(4))
# 50              diff(log(exp(x)/(exp(x) - 1)))
# 51             diff((1 - log(x))/(log(x) + 1))
# 52                        diff(exp(x)/(x - 1))
# 53  diff((exp(x) - exp(-x))*exp(-x) + exp(-x))
# 54                   diff(exp(sqrt(x**2 + 1)))
# 55                              diff(sin(2*x))
# 56                          diff(sin(7*x - 3))
# 57                              diff(cos(5*x))
# 58                            diff(3*tan(2*x))
# 59                             diff(sin(x)**2)
# 60                             diff(sin(x**2))
#
#                                              solucion  \
# 41                       $y'=\frac{6 x}{3 x^{2} - 7}$
# 42                               $y'=\frac{2}{x - 2}$
# 43  $y'=\frac{2 \left(x - 1\right)}{x \left(x - 2\...
# 44  $y'=\frac{6 \left(x + 1\right)}{x \left(2 x + ...
# 45    $y'=\frac{1}{2 x \sqrt{\log{\left(x \right)}}}$
# 46       $y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# 47                           $y'=\frac{2}{x^{2} - 1}$
# 48                                 $y'=\frac{3}{4 x}$
# 49  $y'=\frac{1}{\left(2 x + 1\right) \log{\left(2...
# 50                           $y'=\frac{1}{1 - e^{x}}$
# 51  $y'=- \frac{2}{x \left(\log{\left(x \right)} +...
# 52  $y'=\frac{\left(x - 2\right) e^{x}}{x^{2} - 2 ...
# 53              $y'=\left(2 - e^{x}\right) e^{- 2 x}$
# 54  $y'=\frac{x e^{\sqrt{x^{2} + 1}}}{\sqrt{x^{2} ...
# 55                     $y'=2 \cos{\left(2 x \right)}$
# 56                 $y'=7 \cos{\left(7 x - 3 \right)}$
# 57                   $y'=- 5 \sin{\left(5 x \right)}$
# 58         $y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# 59                       $y'=\sin{\left(2 x \right)}$
# 60                 $y'=2 x \cos{\left(x^{2} \right)}$
#
#                                   texto curso     titulo n_ejercicio  \
# 41  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 42  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 43  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 44  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 45  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 46  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 47  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 48  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 49  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 50  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 51  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 52  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 53  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 54  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 55  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 56  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 57  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 58  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 59  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 60  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 41          5          2      1     False    False
# 42          5          2      1     False    False
# 43          5          2      1     False    False
# 44          5          2      1     False    False
# 45          5          2      1     False    False
# 46          5          2      1     False    False
# 47          5          2      1     False    False
# 48          5          2      1     False    False
# 49          5          2      1     False    False
# 50          5          2      1     False    False
# 51          5          2      1     False    False
# 52          5          2      1     False    False
# 53          5          2      1     False    False
# 54          5          2      1     False    False
# 55          5          2      1     False    False
# 56          5          2      1     False    False
# 57          5          2      1     False    False
# 58          5          2      1     False    False
# 59          5          2      1     False    False
# 60          5          2      1     False    False
# **Ejercicio: **p80e17-cont
#                                       enunciado_latex  \
# 61              $y=\cos^{2}{\left(x^{2} + 1 \right)}$
# 62                    $y=\tan^{3}{\left(5 x \right)}$
# 63                    $y=\sin^{3}{\left(4 x \right)}$
# 64                 $y=\sqrt{\sin{\left(2 x \right)}}$
# 65  $y=\log{\left(- \tan{\left(x - 1 \right)} \rig...
# 66                $y=\sqrt[3]{\sin{\left(x \right)}}$
# 67  $y=\sin^{3}{\left(x \right)} \cos{\left(x \rig...
# 68                    $y=\sec{\left(5 x + 2 \right)}$
# 69         $y=\operatorname{asin}{\left(2 x \right)}$
# 70       $y=\operatorname{acos}{\left(x^{2} \right)}$
# 71  $y=\operatorname{atan}{\left(\frac{x - 1}{1 - ...
# 72  $y=\operatorname{asin}{\left(\frac{x + 1}{x - ...
# 73  $y=\tan^{2}{\left(\sin{\left(x \right)} \right)}$
# 74            $y=\sin^{\frac{1}{x}}{\left(x \right)}$
# 75                      $y=x^{\tan{\left(x \right)}}$
# 76  $y=2^{\log{\left(\cos{\left(x \right)} \right)}}$
# 77  $y=\sin^{\operatorname{atan}{\left(x \right)}}...
# 78       $y=\operatorname{atan}^{x}{\left(x \right)}$
# 79                      $y=x^{\sec{\left(x \right)}}$
#
#                       enunciado  \
# 61       diff(cos(x**2 + 1)**2)
# 62            diff(tan(5*x)**3)
# 63            diff(sin(4*x)**3)
# 64         diff(sqrt(sin(2*x)))
# 65       diff(log(-tan(x - 1)))
# 66          diff(sin(x)**(1/3))
# 67       diff(sin(x)**3*cos(x))
# 68           diff(sec(5*x + 2))
# 69              diff(asin(2*x))
# 70             diff(acos(x**2))
# 71  diff(atan((x - 1)/(1 - x)))
# 72  diff(asin((x + 1)/(x - 1)))
# 73         diff(tan(sin(x))**2)
# 74          diff(sin(x)**(1/x))
# 75              diff(x**tan(x))
# 76         diff(2**log(cos(x)))
# 77        diff(sin(x)**atan(x))
# 78             diff(atan(x)**x)
# 79              diff(x**sec(x))
#
#                                              solucion  \
# 61  $y'=- 4 x \sin{\left(x^{2} + 1 \right)} \cos{\...
# 62  $y'=\left(15 \tan^{2}{\left(5 x \right)} + 15\...
# 63  $y'=12 \sin^{2}{\left(4 x \right)} \cos{\left(...
# 64  $y'=\frac{\cos{\left(2 x \right)}}{\sqrt{\sin{...
# 65  $y'=- \frac{- \tan^{2}{\left(x - 1 \right)} - ...
# 66  $y'=\frac{\cos{\left(x \right)}}{3 \sin^{\frac...
# 67  $y'=- \sin^{4}{\left(x \right)} + 3 \sin^{2}{\...
# 68  $y'=5 \tan{\left(5 x + 2 \right)} \sec{\left(5...
# 69                  $y'=\frac{2}{\sqrt{1 - 4 x^{2}}}$
# 70                $y'=- \frac{2 x}{\sqrt{1 - x^{4}}}$
# 71  $y'=\frac{\frac{1}{1 - x} + \frac{x - 1}{\left...
# 72  $y'=\frac{\frac{1}{x - 1} - \frac{x + 1}{\left...
# 73  $y'=2 \left(\tan^{2}{\left(\sin{\left(x \right...
# 74  $y'=\left(\frac{\cos{\left(x \right)}}{x \sin{...
# 75  $y'=x^{\tan{\left(x \right)}} \left(\left(\tan...
# 76  $y'=- \frac{2^{\log{\left(\cos{\left(x \right)...
# 77  $y'=\left(\frac{\cos{\left(x \right)} \operato...
# 78  $y'=\left(\frac{x}{\left(x^{2} + 1\right) \ope...
# 79  $y'=x^{\sec{\left(x \right)}} \left(\log{\left...
#
#                                   texto curso     titulo  n_ejercicio  \
# 61  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 62  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 63  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 64  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 65  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 66  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 67  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 68  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 69  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 70  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 71  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 72  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 73  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 74  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 75  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 76  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 77  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 78  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 79  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 61          5          2      1     False    False
# 62          5          2      1     False    False
# 63          5          2      1     False    False
# 64          5          2      1     False    False
# 65          5          2      1     False    False
# 66          5          2      1     False    False
# 67          5          2      1     False    False
# 68          5          2      1     False    False
# 69          5          2      1     False    False
# 70          5          2      1     False    False
# 71          5          2      1     False    False
# 72          5          2      1     False    False
# 73          5          2      1     False    False
# 74          5          2      1     False    False
# 75          5          2      1     False    False
# 76          5          2      1     False    False
# 77          5          2      1     False    False
# 78          5          2      1     False    False
# 79          5          2      1     False    False
# **Ejercicio: **p81e18
#                                       enunciado_latex             enunciado  \
# 80                      $y=x^{\log{\left(x \right)}}$       diff(x**log(x))
# 81                                $y=x^{\frac{1}{x}}$        diff(x**(1/x))
# 82  $y=\cos^{\sin{\left(x \right)}}{\left(x \right)}$  diff(cos(x)**sin(x))
#
#                                              solucion  \
# 80  $y'=\frac{2 x^{\log{\left(x \right)}} \log{\le...
# 81  $y'=x^{\frac{1}{x}} \left(- \frac{\log{\left(x...
# 82  $y'=\left(\log{\left(\cos{\left(x \right)} \ri...
#
#                                   texto curso     titulo n_ejercicio  \
# 80  Calcula las siguientes derivadas:\n   1BC  Derivadas      p81e18
# 81  Calcula las siguientes derivadas:\n   1BC  Derivadas      p81e18
# 82  Calcula las siguientes derivadas:\n   1BC  Derivadas      p81e18
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 80          5          2      1     False    False
# 81          5          2      1     False    False
# 82          5          2      1     False    False

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **p80e16
#                                       enunciado_latex  \
# 0                                             $y=2 x$
# 1                                         $y=3 x - 5$
# 2                    $y=7 x^{5} - 3 x^{2} + x + 2345$
# 3                            $y=x \left(x + 2\right)$
# 4           $y=\left(x - 1\right) \left(x + 1\right)$
# 5   $y=\frac{5 x^{4}}{7} - \frac{x^{3}}{55} - \fra...
# 6                          $y=\left(x + 1\right)^{3}$
# 7                  $y=\left(x^{3} + x + 1\right)^{4}$
# 8   $y=- \left(3 x - 1\right)^{2} + \left(3 x + 1\...
# 9                                 $y=\frac{1}{x^{2}}$
# 10                                $y=\frac{1}{x + 1}$
# 11                    $y=\frac{x^{2} - 3}{x^{3} + x}$
# 12                                $y=\frac{x + 1}{x}$
# 13   $y=\frac{x x^{2} \left(x^{2} - 1\right)}{3} - 3$
# 14                                $y=\frac{1}{x^{3}}$
# 15                                $y=x^{\frac{1}{2}}$
# 16                                $y=x^{\frac{2}{3}}$
# 17                               $y=x^{\frac{-2}{3}}$
# 18  $y=x^{\frac{1}{2}} + x^{\frac{1}{5}} + x^{\fra...
# 19                              $y=\sqrt{3} \sqrt{x}$
#
#                                          enunciado  \
# 0                                        diff(2*x)
# 1                                    diff(3*x - 5)
# 2                 diff(7*x**5 - 3*x**2 + x + 2345)
# 3                                  diff(x*(x + 2))
# 4                            diff((x - 1)*(x + 1))
# 5   diff(5*x**4/7 - x**3/55 - 3*x**2/4 + x - 1255)
# 6                                 diff((x + 1)**3)
# 7                          diff((x**3 + x + 1)**4)
# 8               diff(-(3*x - 1)**2 + (3*x + 1)**2)
# 9                                    diff(x**(-2))
# 10                                 diff(1/(x + 1))
# 11                     diff((x**2 - 3)/(x**3 + x))
# 12                                 diff((x + 1)/x)
# 13                     diff(x**3*(x**2 - 1)/3 - 3)
# 14                                   diff(x**(-3))
# 15                                   diff(sqrt(x))
# 16                                  diff(x**(2/3))
# 17                                 diff(x**(-2/3))
# 18             diff(x**(1/6) + x**(1/5) + sqrt(x))
# 19                           diff(sqrt(3)*sqrt(x))
#
#                                              solucion  \
# 0                                              $y'=2$
# 1                                              $y'=3$
# 2                             $y'=35 x^{4} - 6 x + 1$
# 3                                        $y'=2 x + 2$
# 4                                            $y'=2 x$
# 5   $y'=\frac{20 x^{3}}{7} - \frac{3 x^{2}}{55} - ...
# 6                       $y'=3 \left(x + 1\right)^{2}$
# 7   $y'=\left(12 x^{2} + 4\right) \left(x^{3} + x ...
# 8                                             $y'=12$
# 9                              $y'=- \frac{2}{x^{3}}$
# 10            $y'=- \frac{1}{\left(x + 1\right)^{2}}$
# 11  $y'=\frac{- x^{4} + 10 x^{2} + 3}{x^{2} \left(...
# 12                             $y'=- \frac{1}{x^{2}}$
# 13                     $y'=\frac{5 x^{4}}{3} - x^{2}$
# 14                             $y'=- \frac{3}{x^{4}}$
# 15                          $y'=\frac{1}{2 \sqrt{x}}$
# 16                       $y'=\frac{2}{3 \sqrt[3]{x}}$
# 17                 $y'=- \frac{2}{3 x^{\frac{5}{3}}}$
# 18  $y'=\frac{\frac{x^{\frac{49}{30}}}{2} + \frac{...
# 19                   $y'=\frac{\sqrt{3}}{2 \sqrt{x}}$
#
#                                   texto curso     titulo n_ejercicio  \
# 0   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 1   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 2   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 3   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 4   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 5   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 6   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 7   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 8   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 9   Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 10  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 11  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 12  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 13  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 14  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 15  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 16  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 17  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 18  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
# 19  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e16
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 0           5          2      1     False    False
# 1           5          2      1     False    False
# 2           5          2      1     False    False
# 3           5          2      1     False    False
# 4           5          2      1     False    False
# 5           5          2      1     False    False
# 6           5          2      1     False    False
# 7           5          2      1     False    False
# 8           5          2      1     False    False
# 9           5          2      1     False    False
# 10          5          2      1     False    False
# 11          5          2      1     False    False
# 12          5          2      1     False    False
# 13          5          2      1     False    False
# 14          5          2      1     False    False
# 15          5          2      1     False    False
# 16          5          2      1     False    False
# 17          5          2      1     False    False
# 18          5          2      1     False    False
# 19          5          2      1     False    False
# **Ejercicio: **p80e16-cont
#                                       enunciado_latex  \
# 20                         $y=\frac{x^{3}}{\sqrt{x}}$
# 21                          $y=x^{3} x^{\frac{1}{3}}$
# 22                             $y=\frac{\sqrt{x}}{x}$
# 23                     $y=\left(1 - x^{2}\right)^{3}$
# 24                                 $y=\sqrt{2 x - 4}$
# 25                                   $y=\sqrt{2 - x}$
# 26                    $y=\sqrt[3]{2} \sqrt[3]{x^{2}}$
# 27                             $y=\sqrt{3 x^{2} - 1}$
# 28                       $y=\frac{2 x}{\sqrt{x - 1}}$
# 29                     $y=\sqrt{\frac{1 - x}{x + 1}}$
# 30                                        $y=e^{2 x}$
# 31                                        $y=2^{5 x}$
# 32                                $y=8^{3 x^{2} - 1}$
# 33                                    $y=a^{x} x^{a}$
# 34                                   $y=e^{\sqrt{x}}$
# 35  $y=\frac{\log{\left(2 x - 1 \right)}}{\log{\le...
# 36                      $y=\log{\left(x + 3 \right)}$
# 37                        $y=\cos{\left(5 x \right)}$
# 38                      $y=3 \tan{\left(2 x \right)}$
# 39                      $y=\sin^{2}{\left(x \right)}$
# 40                      $y=\sin{\left(x^{2} \right)}$
#
#                        enunciado  \
# 20                diff(x**(5/2))
# 21               diff(x**(10/3))
# 22               diff(1/sqrt(x))
# 23           diff((1 - x**2)**3)
# 24           diff(sqrt(2*x - 4))
# 25             diff(sqrt(2 - x))
# 26  diff(2**(1/3)*(x**2)**(1/3))
# 27        diff(sqrt(3*x**2 - 1))
# 28         diff(2*x/sqrt(x - 1))
# 29   diff(sqrt((1 - x)/(x + 1)))
# 30                diff(exp(2*x))
# 31                diff(2**(5*x))
# 32         diff(8**(3*x**2 - 1))
# 33               diff(a**x*x**a)
# 34            diff(exp(sqrt(x)))
# 35    diff(log(2*x - 1)/log(10))
# 36              diff(log(x + 3))
# 37                diff(cos(5*x))
# 38              diff(3*tan(2*x))
# 39               diff(sin(x)**2)
# 40               diff(sin(x**2))
#
#                                              solucion  \
# 20                   $y'=\frac{5 x^{\frac{3}{2}}}{2}$
# 21                  $y'=\frac{10 x^{\frac{7}{3}}}{3}$
# 22                 $y'=- \frac{1}{2 x^{\frac{3}{2}}}$
# 23              $y'=- 6 x \left(x^{2} - 1\right)^{2}$
# 24               $y'=\frac{\sqrt{2}}{2 \sqrt{x - 2}}$
# 25                    $y'=- \frac{1}{2 \sqrt{2 - x}}$
# 26  $y'=\frac{2 \sqrt[3]{2} \operatorname{sign}{\l...
# 27                $y'=\frac{3 x}{\sqrt{3 x^{2} - 1}}$
# 28  $y'=\frac{x - 2}{\left(x - 1\right)^{\frac{3}{...
# 29  $y'=\frac{\sqrt{\frac{1 - x}{x + 1}}}{x^{2} - 1}$
# 30                                     $y'=2 e^{2 x}$
# 31          $y'=5 \cdot 32^{x} \log{\left(2 \right)}$
# 32  $y'=9 \cdot 2^{9 x^{2} - 2} x \log{\left(2 \ri...
# 33  $y'=a^{x} x^{a - 1} \left(a + x \log{\left(a \...
# 34               $y'=\frac{e^{\sqrt{x}}}{2 \sqrt{x}}$
# 35  $y'=\frac{2}{\left(2 x - 1\right) \log{\left(1...
# 36                               $y'=\frac{1}{x + 3}$
# 37                   $y'=- 5 \sin{\left(5 x \right)}$
# 38         $y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# 39                       $y'=\sin{\left(2 x \right)}$
# 40                 $y'=2 x \cos{\left(x^{2} \right)}$
#
#                                   texto curso     titulo  n_ejercicio  \
# 20  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 21  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 22  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 23  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 24  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 25  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 26  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 27  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 28  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 29  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 30  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 31  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 32  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 33  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 34  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 35  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 36  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 37  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 38  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 39  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
# 40  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e16-cont
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 20          5          2      1     False    False
# 21          5          2      1     False    False
# 22          5          2      1     False    False
# 23          5          2      1     False    False
# 24          5          2      1     False    False
# 25          5          2      1     False    False
# 26          5          2      1     False    False
# 27          5          2      1     False    False
# 28          5          2      1     False    False
# 29          5          2      1     False    False
# 30          5          2      1     False    False
# 31          5          2      1     False    False
# 32          5          2      1     False    False
# 33          5          2      1     False    False
# 34          5          2      1     False    False
# 35          5          2      1     False    False
# 36          5          2      1     False    False
# 37          5          2      1     False    False
# 38          5          2      1     False    False
# 39          5          2      1     False    False
# 40          5          2      1     False    False
# **Ejercicio: **p80e17
#                                       enunciado_latex  \
# 41                $y=\log{\left(3 x^{2} - 7 \right)}$
# 42     $y=\log{\left(\left(x - 2\right)^{2} \right)}$
# 43  $y=\frac{\log{\left(x^{2} - 2 x \right)}}{\log...
# 44  $y=\frac{\log{\left(2 x^{3} + 3 x^{2} \right)}...
# 45                   $y=\sqrt{\log{\left(x \right)}}$
# 46                $y=\frac{\log{\left(x \right)}}{x}$
# 47        $y=\log{\left(\frac{1 - x}{x + 1} \right)}$
# 48            $y=\log{\left(x^{\frac{3}{4}} \right)}$
# 49  $y=\frac{\log{\left(2 x + 1 \right)}}{\log{\le...
# 50    $y=\log{\left(\frac{e^{x}}{e^{x} - 1} \right)}$
# 51  $y=\frac{1 - \log{\left(x \right)}}{\log{\left...
# 52                            $y=\frac{e^{x}}{x - 1}$
# 53        $y=e^{- x} + \frac{e^{x} - e^{- x}}{e^{x}}$
# 54                           $y=e^{\sqrt{x^{2} + 1}}$
# 55                        $y=\sin{\left(2 x \right)}$
# 56                    $y=\sin{\left(7 x - 3 \right)}$
# 57                        $y=\cos{\left(5 x \right)}$
# 58                      $y=3 \tan{\left(2 x \right)}$
# 59                      $y=\sin^{2}{\left(x \right)}$
# 60                      $y=\sin{\left(x^{2} \right)}$
#
#                                      enunciado  \
# 41                       diff(log(3*x**2 - 7))
# 42                       diff(log((x - 2)**2))
# 43               diff(log(x**2 - 2*x)/log(10))
# 44           diff(log(2*x**3 + 3*x**2)/log(2))
# 45                          diff(sqrt(log(x)))
# 46                              diff(log(x)/x)
# 47                  diff(log((1 - x)/(x + 1)))
# 48                         diff(log(x**(3/4)))
# 49                   diff(log(2*x + 1)/log(4))
# 50              diff(log(exp(x)/(exp(x) - 1)))
# 51             diff((1 - log(x))/(log(x) + 1))
# 52                        diff(exp(x)/(x - 1))
# 53  diff((exp(x) - exp(-x))*exp(-x) + exp(-x))
# 54                   diff(exp(sqrt(x**2 + 1)))
# 55                              diff(sin(2*x))
# 56                          diff(sin(7*x - 3))
# 57                              diff(cos(5*x))
# 58                            diff(3*tan(2*x))
# 59                             diff(sin(x)**2)
# 60                             diff(sin(x**2))
#
#                                              solucion  \
# 41                       $y'=\frac{6 x}{3 x^{2} - 7}$
# 42                               $y'=\frac{2}{x - 2}$
# 43  $y'=\frac{2 \left(x - 1\right)}{x \left(x - 2\...
# 44  $y'=\frac{6 \left(x + 1\right)}{x \left(2 x + ...
# 45    $y'=\frac{1}{2 x \sqrt{\log{\left(x \right)}}}$
# 46       $y'=\frac{1 - \log{\left(x \right)}}{x^{2}}$
# 47                           $y'=\frac{2}{x^{2} - 1}$
# 48                                 $y'=\frac{3}{4 x}$
# 49  $y'=\frac{1}{\left(2 x + 1\right) \log{\left(2...
# 50                           $y'=\frac{1}{1 - e^{x}}$
# 51  $y'=- \frac{2}{x \left(\log{\left(x \right)} +...
# 52  $y'=\frac{\left(x - 2\right) e^{x}}{x^{2} - 2 ...
# 53              $y'=\left(2 - e^{x}\right) e^{- 2 x}$
# 54  $y'=\frac{x e^{\sqrt{x^{2} + 1}}}{\sqrt{x^{2} ...
# 55                     $y'=2 \cos{\left(2 x \right)}$
# 56                 $y'=7 \cos{\left(7 x - 3 \right)}$
# 57                   $y'=- 5 \sin{\left(5 x \right)}$
# 58         $y'=\frac{6}{\cos^{2}{\left(2 x \right)}}$
# 59                       $y'=\sin{\left(2 x \right)}$
# 60                 $y'=2 x \cos{\left(x^{2} \right)}$
#
#                                   texto curso     titulo n_ejercicio  \
# 41  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 42  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 43  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 44  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 45  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 46  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 47  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 48  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 49  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 50  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 51  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 52  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 53  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 54  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 55  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 56  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 57  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 58  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 59  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
# 60  Calcula las siguientes derivadas:\n   1BC  Derivadas      p80e17
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 41          5          2      1     False    False
# 42          5          2      1     False    False
# 43          5          2      1     False    False
# 44          5          2      1     False    False
# 45          5          2      1     False    False
# 46          5          2      1     False    False
# 47          5          2      1     False    False
# 48          5          2      1     False    False
# 49          5          2      1     False    False
# 50          5          2      1     False    False
# 51          5          2      1     False    False
# 52          5          2      1     False    False
# 53          5          2      1     False    False
# 54          5          2      1     False    False
# 55          5          2      1     False    False
# 56          5          2      1     False    False
# 57          5          2      1     False    False
# 58          5          2      1     False    False
# 59          5          2      1     False    False
# 60          5          2      1     False    False
# **Ejercicio: **p80e17-cont
#                                       enunciado_latex  \
# 61              $y=\cos^{2}{\left(x^{2} + 1 \right)}$
# 62                    $y=\tan^{3}{\left(5 x \right)}$
# 63                    $y=\sin^{3}{\left(4 x \right)}$
# 64                 $y=\sqrt{\sin{\left(2 x \right)}}$
# 65  $y=\log{\left(- \tan{\left(x - 1 \right)} \rig...
# 66                $y=\sqrt[3]{\sin{\left(x \right)}}$
# 67  $y=\sin^{3}{\left(x \right)} \cos{\left(x \rig...
# 68                    $y=\sec{\left(5 x + 2 \right)}$
# 69         $y=\operatorname{asin}{\left(2 x \right)}$
# 70       $y=\operatorname{acos}{\left(x^{2} \right)}$
# 71  $y=\operatorname{atan}{\left(\frac{x - 1}{1 - ...
# 72  $y=\operatorname{asin}{\left(\frac{x + 1}{x - ...
# 73  $y=\tan^{2}{\left(\sin{\left(x \right)} \right)}$
# 74            $y=\sin^{\frac{1}{x}}{\left(x \right)}$
# 75                      $y=x^{\tan{\left(x \right)}}$
# 76  $y=2^{\log{\left(\cos{\left(x \right)} \right)}}$
# 77  $y=\sin^{\operatorname{atan}{\left(x \right)}}...
# 78       $y=\operatorname{atan}^{x}{\left(x \right)}$
# 79                      $y=x^{\sec{\left(x \right)}}$
#
#                       enunciado  \
# 61       diff(cos(x**2 + 1)**2)
# 62            diff(tan(5*x)**3)
# 63            diff(sin(4*x)**3)
# 64         diff(sqrt(sin(2*x)))
# 65       diff(log(-tan(x - 1)))
# 66          diff(sin(x)**(1/3))
# 67       diff(sin(x)**3*cos(x))
# 68           diff(sec(5*x + 2))
# 69              diff(asin(2*x))
# 70             diff(acos(x**2))
# 71  diff(atan((x - 1)/(1 - x)))
# 72  diff(asin((x + 1)/(x - 1)))
# 73         diff(tan(sin(x))**2)
# 74          diff(sin(x)**(1/x))
# 75              diff(x**tan(x))
# 76         diff(2**log(cos(x)))
# 77        diff(sin(x)**atan(x))
# 78             diff(atan(x)**x)
# 79              diff(x**sec(x))
#
#                                              solucion  \
# 61  $y'=- 4 x \sin{\left(x^{2} + 1 \right)} \cos{\...
# 62  $y'=\left(15 \tan^{2}{\left(5 x \right)} + 15\...
# 63  $y'=12 \sin^{2}{\left(4 x \right)} \cos{\left(...
# 64  $y'=\frac{\cos{\left(2 x \right)}}{\sqrt{\sin{...
# 65  $y'=- \frac{- \tan^{2}{\left(x - 1 \right)} - ...
# 66  $y'=\frac{\cos{\left(x \right)}}{3 \sin^{\frac...
# 67  $y'=- \sin^{4}{\left(x \right)} + 3 \sin^{2}{\...
# 68  $y'=5 \tan{\left(5 x + 2 \right)} \sec{\left(5...
# 69                  $y'=\frac{2}{\sqrt{1 - 4 x^{2}}}$
# 70                $y'=- \frac{2 x}{\sqrt{1 - x^{4}}}$
# 71  $y'=\frac{\frac{1}{1 - x} + \frac{x - 1}{\left...
# 72  $y'=\frac{\frac{1}{x - 1} - \frac{x + 1}{\left...
# 73  $y'=2 \left(\tan^{2}{\left(\sin{\left(x \right...
# 74  $y'=\left(\frac{\cos{\left(x \right)}}{x \sin{...
# 75  $y'=x^{\tan{\left(x \right)}} \left(\left(\tan...
# 76  $y'=- \frac{2^{\log{\left(\cos{\left(x \right)...
# 77  $y'=\left(\frac{\cos{\left(x \right)} \operato...
# 78  $y'=\left(\frac{x}{\left(x^{2} + 1\right) \ope...
# 79  $y'=x^{\sec{\left(x \right)}} \left(\log{\left...
#
#                                   texto curso     titulo  n_ejercicio  \
# 61  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 62  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 63  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 64  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 65  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 66  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 67  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 68  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 69  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 70  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 71  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 72  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 73  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 74  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 75  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 76  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 77  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 78  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
# 79  Calcula las siguientes derivadas:\n   1BC  Derivadas  p80e17-cont
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 61          5          2      1     False    False
# 62          5          2      1     False    False
# 63          5          2      1     False    False
# 64          5          2      1     False    False
# 65          5          2      1     False    False
# 66          5          2      1     False    False
# 67          5          2      1     False    False
# 68          5          2      1     False    False
# 69          5          2      1     False    False
# 70          5          2      1     False    False
# 71          5          2      1     False    False
# 72          5          2      1     False    False
# 73          5          2      1     False    False
# 74          5          2      1     False    False
# 75          5          2      1     False    False
# 76          5          2      1     False    False
# 77          5          2      1     False    False
# 78          5          2      1     False    False
# 79          5          2      1     False    False
# **Ejercicio: **p81e18
#                                       enunciado_latex             enunciado  \
# 80                      $y=x^{\log{\left(x \right)}}$       diff(x**log(x))
# 81                                $y=x^{\frac{1}{x}}$        diff(x**(1/x))
# 82  $y=\cos^{\sin{\left(x \right)}}{\left(x \right)}$  diff(cos(x)**sin(x))
#
#                                              solucion  \
# 80  $y'=\frac{2 x^{\log{\left(x \right)}} \log{\le...
# 81  $y'=x^{\frac{1}{x}} \left(- \frac{\log{\left(x...
# 82  $y'=\left(\log{\left(\cos{\left(x \right)} \ri...
#
#                                   texto curso     titulo n_ejercicio  \
# 80  Calcula las siguientes derivadas:\n   1BC  Derivadas      p81e18
# 81  Calcula las siguientes derivadas:\n   1BC  Derivadas      p81e18
# 82  Calcula las siguientes derivadas:\n   1BC  Derivadas      p81e18
#
#    dificultad n_columnas puntos  enun_tex  sol_tex
# 80          5          2      1     False    False
# 81          5          2      1     False    False
# 82          5          2      1     False    False
