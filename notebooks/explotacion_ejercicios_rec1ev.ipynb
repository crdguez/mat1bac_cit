# %%
import pandas as pd
import numpy as np
from docparts import escribir_ejercicios, escribir_fin, escribir_preambulo, generar_tex, exportar_pdf
from IPython.display import Markdown as md
from IPython.display import display
import string
import random

# %%
df = pd.read_csv('ejercicios_rec1.csv', index_col=False)

# %%
df
# Out:
#                                       enunciado_latex  \
# 0   A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
# 1   A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
# 2   P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
# 3   P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
# 4   \frac{{3\sqrt{ 2 } - 2\sqrt {3} }}{{3\sqrt {2}...
# 5   \frac{{( {2\sqrt {7}  + 2\sqrt {3} } )^2}\cdot...
# 6   tres números pares consecutivos y negativos sa...
# 7   tres números pares consecutivos sabiendo que s...
# 8   \frac{{3{x^2} + 5x - 2}}{{{x^4} + 2{x^2} - 15}...
# 9   \frac{{{x^2} - 4}}{{{x^3} - {x^2} + 3x - 3}}:\...
# 10  \frac{\frac{x}{{{x^2} - 2x + 1}}}{{\frac{{x + ...
# 11  \left\{\begin{matrix}2\log x + \log y = 8 \\\l...
# 12  \left\{\begin{matrix}2\log x - 2\log y = 6\\\l...
# 13  \left\{\begin{matrix}\log_{2}(x) + \log_{2}(x ...
# 14  Mezclamos café de 6 euros el kg. con otro de 9...
# 15  Un padre tiene 31 años más que su hijo, y el a...
# 16  \left\{\begin{matrix}{5^x} = {5^y} \cdot 625 \...
# 17  \left\{\begin{matrix}{2^x} + {2^y} = 24\\{2^{x...
#
#                                             enunciado  \
# 0   [['Abs(x - 3)', '>', '0'], Union(Interval.open...
# 1   [['Abs(x - 3)', '<', '10'], Union(Interval.ope...
# 2                           ((2*x - 3/x)**8, x**(-8))
# 3                        ((3*x**2 + 1/x)**7, x**(-7))
# 4   (-2*sqrt(3) + 3*sqrt(2))/(2*sqrt(3) + 3*sqrt(2...
# 5   ((-sqrt(21) + 5)*(2*sqrt(3) + 2*sqrt(7))**2)/(...
# 6   Eq(2*x + 2 + 2*x + 2*x - 2, (((2*x)*(2*x + 2))...
# 7   Eq(2*x + 2 + 2*x + 2*x - 2, (((2*x)*(2*x + 2))...
# 8   ((3*x**2 + 5*x - 2)/(x**4 + 2*x**2 - 15))/(((9...
# 9   ((x**2 - 4)/(3*x + x**3 - x**2 - 3))/(((x**2 -...
# 10  (x/(x**2 - 2*x + 1))/(-(x - 1)/(x + 1) + (x + ...
# 11  [Eq(2*log(x, 10) + log(y, 10), 8), Eq(log(x, 1...
# 12  [Eq(2*log(x, 10) - 2*log(y, 10), 6), Eq(log(x,...
# 13   [Eq(log(x, 2) + log(x + y, 2), 4), Eq(x + y, 2)]
# 14                                6x+9(60-x)<7\cdot60
# 15                        (x-1-31)+(x-1)+(x-1+31)<102
# 16           [Eq(5**x, 625*5**y), Eq(2**x*2**y, 256)]
# 17         [Eq(2**x + 2**y, 24), Eq(2**(x + y), 128)]
#
#                                              solucion  \
# 0   A=\left(-\infty, 3\right) \cup \left(3, \infty...
# 1   A=\left(-7, 13\right) \ C=\left(-\infty, -3\ri...
# 2                                                6561
# 3                                                   1
# 4                          - \frac{3 \sqrt{6}}{2} + 5
# 5                                                   8
# 6   \left [ -2, \quad 0, \quad 2\right ] \to \left...
# 7   \left [ 0, \quad - \frac{\sqrt{10}}{2}, \quad ...
# 8   \frac{x^{3} + 2 x^{2}}{3 x^{3} - x^{2} - 9 x + 3}
# 9                 \frac{x^{2} + 2 x}{x^{2} - 2 x + 1}
# 10                              \frac{x + 1}{4 x - 4}
# 11  \left [ \left \{ x : 1000, \quad y : 100\right...
# 12  \left [ \left \{ x : 10000, \quad y : 10\right...
# 13  \left [ \left \{ x : 8, \quad y : -6\right \}\...
# 14  6x+9(60-x)<7\cdot60  \rightarrow  \\\left(40, ...
# 15  (x-1-31)+(x-1)+(x-1+31)<102  \rightarrow  \\\l...
# 16  \left [ \left \{ x : 6, \quad y : 2\right \}\r...
# 17  \left [ \left \{ x : 3, \quad y : 4\right \}, ...
#
#                                                 texto curso  \
# 0   Dados los siguientes conjuntos A, B y C, repre...   1BC
# 1   Dados los siguientes conjuntos A, B y C, repre...   1BC
# 2   Calcula, sin hacer todo el desarrollo, el coef...   1BC
# 3   Calcula, sin hacer todo el desarrollo, el coef...   1BC
# 4                                           Calcular:   1BC
# 5                                           Calcular:   1BC
# 6                                              Halla:   1BC
# 7                                              Halla:   1BC
# 8                                         Simplifica:   1BC
# 9                                         Simplifica:   1BC
# 10                                        Simplifica:   1BC
# 11                                         Resolver :   1BC
# 12                                         Resolver :   1BC
# 13                                         Resolver :   1BC
# 14                                         Resolver :   1BC
# 15                                         Resolver :   1BC
# 16                                          Resuelve:   1BC
# 17                                          Resuelve:   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 0   Recuperación 1ª Ev.     ex03e01           1           3       1      True
# 1   Recuperación 1ª Ev.     ex03e01           1           3       1      True
# 2   Recuperación 1ª Ev.    ex03e01b           1           3       1      True
# 3   Recuperación 1ª Ev.    ex03e01b           1           3       1      True
# 4   Recuperación 1ª Ev.     ex03e02           1           3       1      True
# 5   Recuperación 1ª Ev.     ex03e02           1           3       1      True
# 6   Recuperación 1ª Ev.     ex03e03           1           3       2     False
# 7   Recuperación 1ª Ev.     ex03e03           1           3       2     False
# 8   Recuperación 1ª Ev.     ex03e04           1           3       1      True
# 9   Recuperación 1ª Ev.     ex03e04           1           3       1      True
# 10  Recuperación 1ª Ev.     ex03e04           1           3       1      True
# 11  Recuperación 1ª Ev.     ex03e05           1           3       1      True
# 12  Recuperación 1ª Ev.     ex03e05           1           3       1      True
# 13  Recuperación 1ª Ev.     ex03e05           1           3       1      True
# 14  Recuperación 1ª Ev.     ex03e03           1           3       2     False
# 15  Recuperación 1ª Ev.     ex03e03           1           3       2     False
# 16  Recuperación 1ª Ev.     ex03e05           1           3       1      True
# 17  Recuperación 1ª Ev.     ex03e05           1           3       1      True
#
#     sol_tex
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True

# %%
df.pivot_table(index = ['n_ejercicio'], columns=['texto','puntos'])
# Out:
#                                                                                dificultad  \
# texto       Calcula, sin hacer todo el desarrollo, el coeficiente del término asociado a:
# puntos                                                                                  1
# n_ejercicio
# ex03e01                                                    NaN
# ex03e01b                                                   1.0
# ex03e02                                                    NaN
# ex03e03                                                    NaN
# ex03e04                                                    NaN
# ex03e05                                                    NaN
#
#                        \
# texto       Calcular:
# puntos              1
# n_ejercicio
# ex03e01           NaN
# ex03e01b          NaN
# ex03e02           1.0
# ex03e03           NaN
# ex03e04           NaN
# ex03e05           NaN
#
#                                                                                                                                                                                                      \
# texto       Dados los siguientes conjuntos A, B y C, represéntalos en la recta real. A continuación, calcula $A \cap B$ y $(A \cup B) \cap C$ , \ny expresa los resultados en forma de Intervalos.
# puntos                                                                                                                                                                                            1
# n_ejercicio
# ex03e01                                                    1.0
# ex03e01b                                                   NaN
# ex03e02                                                    NaN
# ex03e03                                                    NaN
# ex03e04                                                    NaN
# ex03e05                                                    NaN
#
#                                                           \
# texto       Halla: Resolver :      Resuelve: Simplifica:
# puntos           2          1    2         1           1
# n_ejercicio
# ex03e01        NaN        NaN  NaN       NaN         NaN
# ex03e01b       NaN        NaN  NaN       NaN         NaN
# ex03e02        NaN        NaN  NaN       NaN         NaN
# ex03e03        1.0        NaN  1.0       NaN         NaN
# ex03e04        NaN        NaN  NaN       NaN         1.0
# ex03e05        NaN        1.0  NaN       1.0         NaN
#
#                                                                                  enun_tex  \
# texto       Calcula, sin hacer todo el desarrollo, el coeficiente del término asociado a:
# puntos                                                                                  1
# n_ejercicio
# ex03e01                                                    NaN
# ex03e01b                                                  True
# ex03e02                                                    NaN
# ex03e03                                                    NaN
# ex03e04                                                    NaN
# ex03e05                                                    NaN
#
#                           ...     n_columnas              \
# texto       Calcular:     ...      Resuelve: Simplifica:
# puntos              1     ...              1           1
# n_ejercicio               ...
# ex03e01           NaN     ...            NaN         NaN
# ex03e01b          NaN     ...            NaN         NaN
# ex03e02          True     ...            NaN         NaN
# ex03e03           NaN     ...            NaN         NaN
# ex03e04           NaN     ...            NaN         3.0
# ex03e05           NaN     ...            3.0         NaN
#
#                                                                                   sol_tex  \
# texto       Calcula, sin hacer todo el desarrollo, el coeficiente del término asociado a:
# puntos                                                                                  1
# n_ejercicio
# ex03e01                                                    NaN
# ex03e01b                                                  True
# ex03e02                                                    NaN
# ex03e03                                                    NaN
# ex03e04                                                    NaN
# ex03e05                                                    NaN
#
#                        \
# texto       Calcular:
# puntos              1
# n_ejercicio
# ex03e01           NaN
# ex03e01b          NaN
# ex03e02          True
# ex03e03           NaN
# ex03e04           NaN
# ex03e05           NaN
#
#                                                                                                                                                                                                      \
# texto       Dados los siguientes conjuntos A, B y C, represéntalos en la recta real. A continuación, calcula $A \cap B$ y $(A \cup B) \cap C$ , \ny expresa los resultados en forma de Intervalos.
# puntos                                                                                                                                                                                            1
# n_ejercicio
# ex03e01                                                   True
# ex03e01b                                                   NaN
# ex03e02                                                    NaN
# ex03e03                                                    NaN
# ex03e04                                                    NaN
# ex03e05                                                    NaN
#
#
# texto       Halla: Resolver :       Resuelve: Simplifica:
# puntos           2          1     2         1           1
# n_ejercicio
# ex03e01        NaN        NaN   NaN       NaN         NaN
# ex03e01b       NaN        NaN   NaN       NaN         NaN
# ex03e02        NaN        NaN   NaN       NaN         NaN
# ex03e03       True        NaN  True       NaN         NaN
# ex03e04        NaN        NaN   NaN       NaN        True
# ex03e05        NaN       True   NaN      True         NaN
#
# [6 rows x 32 columns]

# %%
# Generador de prueb: Cambia los parámetros 

fichero = 'rec1'
titulo = 'Recuperación 1ª evaluación'
tipo = 'ejerc'  # Todo lo que sea diferente a 'ejercicios' lo generará

n_pdf = list(string.ascii_uppercase)[:4] # Pruebas diferentes a generar

if tipo != 'ejercicios' :
 
    #Construcción de lista de ejercicios
    numero = 2 # Número de ejercicios por defecto de cada ejercicio
    
    lista1 = np.unique(df.n_ejercicio.tolist())
    lista2 =[]
    for i in range(lista1.size) : lista2.append(numero)
    lista = list(zip(lista1,lista2))
    
    # Si queremos poner nuestra propia lista: lista =[('texto_nejercicio',nº de ejercicios)], si no comentar la linea siguiente
    # lista = [('ex01e01', 1),('ex01e02', 1),('ex01e03', 1),('ex01e05', 2),('ex01e06', 1),('ex01e08', 1)]
    lista = [('ex03e01', 1),('ex03e01b', 1),('ex03e02', 1),('ex03e03', 1),('ex03e04', 1),('ex03e05', 1)]
    
    for s in n_pdf:
        random.shuffle(lista)
        df_ejercicios = pd.concat(df.loc[np.random.choice(df[df.n_ejercicio==s[0]].index, s[1], replace=False)] for s in lista)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = False)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = True)

else :
    exportar_pdf(df, fichero, titulo, tipo)
# Out:
# **Ejercicio: **ex03e01
#                                      enunciado_latex  \
# 1  A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
#
#                                            enunciado  \
# 1  [['Abs(x - 3)', '<', '10'], Union(Interval.ope...
#
#                                             solucion  \
# 1  A=\left(-7, 13\right) \ C=\left(-\infty, -3\ri...
#
#                                                texto curso  \
# 1  Dados los siguientes conjuntos A, B y C, repre...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 1  Recuperación 1ª Ev.     ex03e01           1           1       1      True
#
#    sol_tex
# 1     True
# **Ejercicio: **ex03e01b
#                                      enunciado_latex  \
# 2  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
#
#                    enunciado solucion  \
# 2  ((2*x - 3/x)**8, x**(-8))     6561
#
#                                                texto curso  \
# 2  Calcula, sin hacer todo el desarrollo, el coef...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 2  Recuperación 1ª Ev.    ex03e01b           1           1       1      True
#
#    sol_tex
# 2     True
# **Ejercicio: **ex03e02
#                                      enunciado_latex  \
# 5  \frac{{( {2\sqrt {7}  + 2\sqrt {3} } )^2}\cdot...
#
#                                            enunciado solucion      texto  \
# 5  ((-sqrt(21) + 5)*(2*sqrt(3) + 2*sqrt(7))**2)/(...        8  Calcular:
#
#   curso               titulo n_ejercicio  dificultad  n_columnas  puntos  \
# 5   1BC  Recuperación 1ª Ev.     ex03e02           1           1       1
#
#    enun_tex  sol_tex
# 5      True     True
# **Ejercicio: **ex03e03
#                                      enunciado_latex  \
# 6  tres números pares consecutivos y negativos sa...
#
#                                            enunciado  \
# 6  Eq(2*x + 2 + 2*x + 2*x - 2, (((2*x)*(2*x + 2))...
#
#                                             solucion   texto curso  \
# 6  \left [ -2, \quad 0, \quad 2\right ] \to \left...  Halla:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 6  Recuperación 1ª Ev.     ex03e03           1           1       2     False
#
#    sol_tex
# 6     True
# **Ejercicio: **ex03e04
#                                       enunciado_latex  \
# 10  \frac{\frac{x}{{{x^2} - 2x + 1}}}{{\frac{{x + ...
#
#                                             enunciado               solucion  \
# 10  (x/(x**2 - 2*x + 1))/(-(x - 1)/(x + 1) + (x + ...  \frac{x + 1}{4 x - 4}
#
#           texto curso               titulo n_ejercicio  dificultad  \
# 10  Simplifica:   1BC  Recuperación 1ª Ev.     ex03e04           1
#
#     n_columnas  puntos  enun_tex  sol_tex
# 10           1       1      True     True
# **Ejercicio: **ex03e05
#                                       enunciado_latex  \
# 13  \left\{\begin{matrix}\log_{2}(x) + \log_{2}(x ...
#
#                                            enunciado  \
# 13  [Eq(log(x, 2) + log(x + y, 2), 4), Eq(x + y, 2)]
#
#                                              solucion       texto curso  \
# 13  \left [ \left \{ x : 8, \quad y : -6\right \}\...  Resolver :   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 13  Recuperación 1ª Ev.     ex03e05           1           1       1      True
#
#     sol_tex
# 13     True
# **Ejercicio: **ex03e01
#                                      enunciado_latex  \
# 1  A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
#
#                                            enunciado  \
# 1  [['Abs(x - 3)', '<', '10'], Union(Interval.ope...
#
#                                             solucion  \
# 1  A=\left(-7, 13\right) \ C=\left(-\infty, -3\ri...
#
#                                                texto curso  \
# 1  Dados los siguientes conjuntos A, B y C, repre...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 1  Recuperación 1ª Ev.     ex03e01           1           1       1      True
#
#    sol_tex
# 1     True
# **Ejercicio: **ex03e01b
#                                      enunciado_latex  \
# 2  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
#
#                    enunciado solucion  \
# 2  ((2*x - 3/x)**8, x**(-8))     6561
#
#                                                texto curso  \
# 2  Calcula, sin hacer todo el desarrollo, el coef...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 2  Recuperación 1ª Ev.    ex03e01b           1           1       1      True
#
#    sol_tex
# 2     True
# **Ejercicio: **ex03e02
#                                      enunciado_latex  \
# 5  \frac{{( {2\sqrt {7}  + 2\sqrt {3} } )^2}\cdot...
#
#                                            enunciado solucion      texto  \
# 5  ((-sqrt(21) + 5)*(2*sqrt(3) + 2*sqrt(7))**2)/(...        8  Calcular:
#
#   curso               titulo n_ejercicio  dificultad  n_columnas  puntos  \
# 5   1BC  Recuperación 1ª Ev.     ex03e02           1           1       1
#
#    enun_tex  sol_tex
# 5      True     True
# **Ejercicio: **ex03e03
#                                      enunciado_latex  \
# 6  tres números pares consecutivos y negativos sa...
#
#                                            enunciado  \
# 6  Eq(2*x + 2 + 2*x + 2*x - 2, (((2*x)*(2*x + 2))...
#
#                                             solucion   texto curso  \
# 6  \left [ -2, \quad 0, \quad 2\right ] \to \left...  Halla:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 6  Recuperación 1ª Ev.     ex03e03           1           1       2     False
#
#    sol_tex
# 6     True
# **Ejercicio: **ex03e04
#                                       enunciado_latex  \
# 10  \frac{\frac{x}{{{x^2} - 2x + 1}}}{{\frac{{x + ...
#
#                                             enunciado               solucion  \
# 10  (x/(x**2 - 2*x + 1))/(-(x - 1)/(x + 1) + (x + ...  \frac{x + 1}{4 x - 4}
#
#           texto curso               titulo n_ejercicio  dificultad  \
# 10  Simplifica:   1BC  Recuperación 1ª Ev.     ex03e04           1
#
#     n_columnas  puntos  enun_tex  sol_tex
# 10           1       1      True     True
# **Ejercicio: **ex03e05
#                                       enunciado_latex  \
# 13  \left\{\begin{matrix}\log_{2}(x) + \log_{2}(x ...
#
#                                            enunciado  \
# 13  [Eq(log(x, 2) + log(x + y, 2), 4), Eq(x + y, 2)]
#
#                                              solucion       texto curso  \
# 13  \left [ \left \{ x : 8, \quad y : -6\right \}\...  Resolver :   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 13  Recuperación 1ª Ev.     ex03e05           1           1       1      True
#
#     sol_tex
# 13     True
# **Ejercicio: **ex03e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
#
#                                            enunciado  \
# 0  [['Abs(x - 3)', '>', '0'], Union(Interval.open...
#
#                                             solucion  \
# 0  A=\left(-\infty, 3\right) \cup \left(3, \infty...
#
#                                                texto curso  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 0  Recuperación 1ª Ev.     ex03e01           1           1       1      True
#
#    sol_tex
# 0     True
# **Ejercicio: **ex03e01b
#                                      enunciado_latex  \
# 3  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
#
#                       enunciado solucion  \
# 3  ((3*x**2 + 1/x)**7, x**(-7))        1
#
#                                                texto curso  \
# 3  Calcula, sin hacer todo el desarrollo, el coef...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 3  Recuperación 1ª Ev.    ex03e01b           1           1       1      True
#
#    sol_tex
# 3     True
# **Ejercicio: **ex03e02
#                                      enunciado_latex  \
# 5  \frac{{( {2\sqrt {7}  + 2\sqrt {3} } )^2}\cdot...
#
#                                            enunciado solucion      texto  \
# 5  ((-sqrt(21) + 5)*(2*sqrt(3) + 2*sqrt(7))**2)/(...        8  Calcular:
#
#   curso               titulo n_ejercicio  dificultad  n_columnas  puntos  \
# 5   1BC  Recuperación 1ª Ev.     ex03e02           1           1       1
#
#    enun_tex  sol_tex
# 5      True     True
# **Ejercicio: **ex03e03
#                                       enunciado_latex            enunciado  \
# 14  Mezclamos café de 6 euros el kg. con otro de 9...  6x+9(60-x)<7\cdot60
#
#                                              solucion       texto curso  \
# 14  6x+9(60-x)<7\cdot60  \rightarrow  \\\left(40, ...  Resolver :   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 14  Recuperación 1ª Ev.     ex03e03           1           1       2     False
#
#     sol_tex
# 14     True
# **Ejercicio: **ex03e04
#                                       enunciado_latex  \
# 10  \frac{\frac{x}{{{x^2} - 2x + 1}}}{{\frac{{x + ...
#
#                                             enunciado               solucion  \
# 10  (x/(x**2 - 2*x + 1))/(-(x - 1)/(x + 1) + (x + ...  \frac{x + 1}{4 x - 4}
#
#           texto curso               titulo n_ejercicio  dificultad  \
# 10  Simplifica:   1BC  Recuperación 1ª Ev.     ex03e04           1
#
#     n_columnas  puntos  enun_tex  sol_tex
# 10           1       1      True     True
# **Ejercicio: **ex03e05
#                                       enunciado_latex  \
# 17  \left\{\begin{matrix}{2^x} + {2^y} = 24\\{2^{x...
#
#                                      enunciado  \
# 17  [Eq(2**x + 2**y, 24), Eq(2**(x + y), 128)]
#
#                                              solucion      texto curso  \
# 17  \left [ \left \{ x : 3, \quad y : 4\right \}, ...  Resuelve:   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 17  Recuperación 1ª Ev.     ex03e05           1           1       1      True
#
#     sol_tex
# 17     True
# **Ejercicio: **ex03e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
#
#                                            enunciado  \
# 0  [['Abs(x - 3)', '>', '0'], Union(Interval.open...
#
#                                             solucion  \
# 0  A=\left(-\infty, 3\right) \cup \left(3, \infty...
#
#                                                texto curso  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 0  Recuperación 1ª Ev.     ex03e01           1           1       1      True
#
#    sol_tex
# 0     True
# **Ejercicio: **ex03e01b
#                                      enunciado_latex  \
# 3  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
#
#                       enunciado solucion  \
# 3  ((3*x**2 + 1/x)**7, x**(-7))        1
#
#                                                texto curso  \
# 3  Calcula, sin hacer todo el desarrollo, el coef...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 3  Recuperación 1ª Ev.    ex03e01b           1           1       1      True
#
#    sol_tex
# 3     True
# **Ejercicio: **ex03e02
#                                      enunciado_latex  \
# 5  \frac{{( {2\sqrt {7}  + 2\sqrt {3} } )^2}\cdot...
#
#                                            enunciado solucion      texto  \
# 5  ((-sqrt(21) + 5)*(2*sqrt(3) + 2*sqrt(7))**2)/(...        8  Calcular:
#
#   curso               titulo n_ejercicio  dificultad  n_columnas  puntos  \
# 5   1BC  Recuperación 1ª Ev.     ex03e02           1           1       1
#
#    enun_tex  sol_tex
# 5      True     True
# **Ejercicio: **ex03e03
#                                       enunciado_latex            enunciado  \
# 14  Mezclamos café de 6 euros el kg. con otro de 9...  6x+9(60-x)<7\cdot60
#
#                                              solucion       texto curso  \
# 14  6x+9(60-x)<7\cdot60  \rightarrow  \\\left(40, ...  Resolver :   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 14  Recuperación 1ª Ev.     ex03e03           1           1       2     False
#
#     sol_tex
# 14     True
# **Ejercicio: **ex03e04
#                                       enunciado_latex  \
# 10  \frac{\frac{x}{{{x^2} - 2x + 1}}}{{\frac{{x + ...
#
#                                             enunciado               solucion  \
# 10  (x/(x**2 - 2*x + 1))/(-(x - 1)/(x + 1) + (x + ...  \frac{x + 1}{4 x - 4}
#
#           texto curso               titulo n_ejercicio  dificultad  \
# 10  Simplifica:   1BC  Recuperación 1ª Ev.     ex03e04           1
#
#     n_columnas  puntos  enun_tex  sol_tex
# 10           1       1      True     True
# **Ejercicio: **ex03e05
#                                       enunciado_latex  \
# 17  \left\{\begin{matrix}{2^x} + {2^y} = 24\\{2^{x...
#
#                                      enunciado  \
# 17  [Eq(2**x + 2**y, 24), Eq(2**(x + y), 128)]
#
#                                              solucion      texto curso  \
# 17  \left [ \left \{ x : 3, \quad y : 4\right \}, ...  Resuelve:   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 17  Recuperación 1ª Ev.     ex03e05           1           1       1      True
#
#     sol_tex
# 17     True
# **Ejercicio: **ex03e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
#
#                                            enunciado  \
# 0  [['Abs(x - 3)', '>', '0'], Union(Interval.open...
#
#                                             solucion  \
# 0  A=\left(-\infty, 3\right) \cup \left(3, \infty...
#
#                                                texto curso  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 0  Recuperación 1ª Ev.     ex03e01           1           1       1      True
#
#    sol_tex
# 0     True
# **Ejercicio: **ex03e01b
#                                      enunciado_latex  \
# 3  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
#
#                       enunciado solucion  \
# 3  ((3*x**2 + 1/x)**7, x**(-7))        1
#
#                                                texto curso  \
# 3  Calcula, sin hacer todo el desarrollo, el coef...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 3  Recuperación 1ª Ev.    ex03e01b           1           1       1      True
#
#    sol_tex
# 3     True
# **Ejercicio: **ex03e02
#                                      enunciado_latex  \
# 5  \frac{{( {2\sqrt {7}  + 2\sqrt {3} } )^2}\cdot...
#
#                                            enunciado solucion      texto  \
# 5  ((-sqrt(21) + 5)*(2*sqrt(3) + 2*sqrt(7))**2)/(...        8  Calcular:
#
#   curso               titulo n_ejercicio  dificultad  n_columnas  puntos  \
# 5   1BC  Recuperación 1ª Ev.     ex03e02           1           1       1
#
#    enun_tex  sol_tex
# 5      True     True
# **Ejercicio: **ex03e03
#                                      enunciado_latex  \
# 6  tres números pares consecutivos y negativos sa...
#
#                                            enunciado  \
# 6  Eq(2*x + 2 + 2*x + 2*x - 2, (((2*x)*(2*x + 2))...
#
#                                             solucion   texto curso  \
# 6  \left [ -2, \quad 0, \quad 2\right ] \to \left...  Halla:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 6  Recuperación 1ª Ev.     ex03e03           1           1       2     False
#
#    sol_tex
# 6     True
# **Ejercicio: **ex03e04
#                                      enunciado_latex  \
# 9  \frac{{{x^2} - 4}}{{{x^3} - {x^2} + 3x - 3}}:\...
#
#                                            enunciado  \
# 9  ((x**2 - 4)/(3*x + x**3 - x**2 - 3))/(((x**2 -...
#
#                               solucion        texto curso  \
# 9  \frac{x^{2} + 2 x}{x^{2} - 2 x + 1}  Simplifica:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 9  Recuperación 1ª Ev.     ex03e04           1           1       1      True
#
#    sol_tex
# 9     True
# **Ejercicio: **ex03e05
#                                       enunciado_latex  \
# 16  \left\{\begin{matrix}{5^x} = {5^y} \cdot 625 \...
#
#                                    enunciado  \
# 16  [Eq(5**x, 625*5**y), Eq(2**x*2**y, 256)]
#
#                                              solucion      texto curso  \
# 16  \left [ \left \{ x : 6, \quad y : 2\right \}\r...  Resuelve:   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 16  Recuperación 1ª Ev.     ex03e05           1           1       1      True
#
#     sol_tex
# 16     True
# **Ejercicio: **ex03e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
#
#                                            enunciado  \
# 0  [['Abs(x - 3)', '>', '0'], Union(Interval.open...
#
#                                             solucion  \
# 0  A=\left(-\infty, 3\right) \cup \left(3, \infty...
#
#                                                texto curso  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 0  Recuperación 1ª Ev.     ex03e01           1           1       1      True
#
#    sol_tex
# 0     True
# **Ejercicio: **ex03e01b
#                                      enunciado_latex  \
# 3  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
#
#                       enunciado solucion  \
# 3  ((3*x**2 + 1/x)**7, x**(-7))        1
#
#                                                texto curso  \
# 3  Calcula, sin hacer todo el desarrollo, el coef...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 3  Recuperación 1ª Ev.    ex03e01b           1           1       1      True
#
#    sol_tex
# 3     True
# **Ejercicio: **ex03e02
#                                      enunciado_latex  \
# 5  \frac{{( {2\sqrt {7}  + 2\sqrt {3} } )^2}\cdot...
#
#                                            enunciado solucion      texto  \
# 5  ((-sqrt(21) + 5)*(2*sqrt(3) + 2*sqrt(7))**2)/(...        8  Calcular:
#
#   curso               titulo n_ejercicio  dificultad  n_columnas  puntos  \
# 5   1BC  Recuperación 1ª Ev.     ex03e02           1           1       1
#
#    enun_tex  sol_tex
# 5      True     True
# **Ejercicio: **ex03e03
#                                      enunciado_latex  \
# 6  tres números pares consecutivos y negativos sa...
#
#                                            enunciado  \
# 6  Eq(2*x + 2 + 2*x + 2*x - 2, (((2*x)*(2*x + 2))...
#
#                                             solucion   texto curso  \
# 6  \left [ -2, \quad 0, \quad 2\right ] \to \left...  Halla:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 6  Recuperación 1ª Ev.     ex03e03           1           1       2     False
#
#    sol_tex
# 6     True
# **Ejercicio: **ex03e04
#                                      enunciado_latex  \
# 9  \frac{{{x^2} - 4}}{{{x^3} - {x^2} + 3x - 3}}:\...
#
#                                            enunciado  \
# 9  ((x**2 - 4)/(3*x + x**3 - x**2 - 3))/(((x**2 -...
#
#                               solucion        texto curso  \
# 9  \frac{x^{2} + 2 x}{x^{2} - 2 x + 1}  Simplifica:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 9  Recuperación 1ª Ev.     ex03e04           1           1       1      True
#
#    sol_tex
# 9     True
# **Ejercicio: **ex03e05
#                                       enunciado_latex  \
# 16  \left\{\begin{matrix}{5^x} = {5^y} \cdot 625 \...
#
#                                    enunciado  \
# 16  [Eq(5**x, 625*5**y), Eq(2**x*2**y, 256)]
#
#                                              solucion      texto curso  \
# 16  \left [ \left \{ x : 6, \quad y : 2\right \}\r...  Resuelve:   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 16  Recuperación 1ª Ev.     ex03e05           1           1       1      True
#
#     sol_tex
# 16     True
# **Ejercicio: **ex03e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
#
#                                            enunciado  \
# 0  [['Abs(x - 3)', '>', '0'], Union(Interval.open...
#
#                                             solucion  \
# 0  A=\left(-\infty, 3\right) \cup \left(3, \infty...
#
#                                                texto curso  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 0  Recuperación 1ª Ev.     ex03e01           1           1       1      True
#
#    sol_tex
# 0     True
# **Ejercicio: **ex03e01b
#                                      enunciado_latex  \
# 2  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
#
#                    enunciado solucion  \
# 2  ((2*x - 3/x)**8, x**(-8))     6561
#
#                                                texto curso  \
# 2  Calcula, sin hacer todo el desarrollo, el coef...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 2  Recuperación 1ª Ev.    ex03e01b           1           1       1      True
#
#    sol_tex
# 2     True
# **Ejercicio: **ex03e02
#                                      enunciado_latex  \
# 4  \frac{{3\sqrt{ 2 } - 2\sqrt {3} }}{{3\sqrt {2}...
#
#                                            enunciado  \
# 4  (-2*sqrt(3) + 3*sqrt(2))/(2*sqrt(3) + 3*sqrt(2...
#
#                      solucion      texto curso               titulo  \
# 4  - \frac{3 \sqrt{6}}{2} + 5  Calcular:   1BC  Recuperación 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 4     ex03e02           1           1       1      True     True
# **Ejercicio: **ex03e03
#                                      enunciado_latex  \
# 6  tres números pares consecutivos y negativos sa...
#
#                                            enunciado  \
# 6  Eq(2*x + 2 + 2*x + 2*x - 2, (((2*x)*(2*x + 2))...
#
#                                             solucion   texto curso  \
# 6  \left [ -2, \quad 0, \quad 2\right ] \to \left...  Halla:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 6  Recuperación 1ª Ev.     ex03e03           1           1       2     False
#
#    sol_tex
# 6     True
# **Ejercicio: **ex03e04
#                                      enunciado_latex  \
# 9  \frac{{{x^2} - 4}}{{{x^3} - {x^2} + 3x - 3}}:\...
#
#                                            enunciado  \
# 9  ((x**2 - 4)/(3*x + x**3 - x**2 - 3))/(((x**2 -...
#
#                               solucion        texto curso  \
# 9  \frac{x^{2} + 2 x}{x^{2} - 2 x + 1}  Simplifica:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 9  Recuperación 1ª Ev.     ex03e04           1           1       1      True
#
#    sol_tex
# 9     True
# **Ejercicio: **ex03e05
#                                       enunciado_latex  \
# 16  \left\{\begin{matrix}{5^x} = {5^y} \cdot 625 \...
#
#                                    enunciado  \
# 16  [Eq(5**x, 625*5**y), Eq(2**x*2**y, 256)]
#
#                                              solucion      texto curso  \
# 16  \left [ \left \{ x : 6, \quad y : 2\right \}\r...  Resuelve:   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 16  Recuperación 1ª Ev.     ex03e05           1           1       1      True
#
#     sol_tex
# 16     True
# **Ejercicio: **ex03e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| \left|{x - 3}\righ...
#
#                                            enunciado  \
# 0  [['Abs(x - 3)', '>', '0'], Union(Interval.open...
#
#                                             solucion  \
# 0  A=\left(-\infty, 3\right) \cup \left(3, \infty...
#
#                                                texto curso  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 0  Recuperación 1ª Ev.     ex03e01           1           1       1      True
#
#    sol_tex
# 0     True
# **Ejercicio: **ex03e01b
#                                      enunciado_latex  \
# 2  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
#
#                    enunciado solucion  \
# 2  ((2*x - 3/x)**8, x**(-8))     6561
#
#                                                texto curso  \
# 2  Calcula, sin hacer todo el desarrollo, el coef...   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 2  Recuperación 1ª Ev.    ex03e01b           1           1       1      True
#
#    sol_tex
# 2     True
# **Ejercicio: **ex03e02
#                                      enunciado_latex  \
# 4  \frac{{3\sqrt{ 2 } - 2\sqrt {3} }}{{3\sqrt {2}...
#
#                                            enunciado  \
# 4  (-2*sqrt(3) + 3*sqrt(2))/(2*sqrt(3) + 3*sqrt(2...
#
#                      solucion      texto curso               titulo  \
# 4  - \frac{3 \sqrt{6}}{2} + 5  Calcular:   1BC  Recuperación 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 4     ex03e02           1           1       1      True     True
# **Ejercicio: **ex03e03
#                                      enunciado_latex  \
# 6  tres números pares consecutivos y negativos sa...
#
#                                            enunciado  \
# 6  Eq(2*x + 2 + 2*x + 2*x - 2, (((2*x)*(2*x + 2))...
#
#                                             solucion   texto curso  \
# 6  \left [ -2, \quad 0, \quad 2\right ] \to \left...  Halla:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 6  Recuperación 1ª Ev.     ex03e03           1           1       2     False
#
#    sol_tex
# 6     True
# **Ejercicio: **ex03e04
#                                      enunciado_latex  \
# 9  \frac{{{x^2} - 4}}{{{x^3} - {x^2} + 3x - 3}}:\...
#
#                                            enunciado  \
# 9  ((x**2 - 4)/(3*x + x**3 - x**2 - 3))/(((x**2 -...
#
#                               solucion        texto curso  \
# 9  \frac{x^{2} + 2 x}{x^{2} - 2 x + 1}  Simplifica:   1BC
#
#                 titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 9  Recuperación 1ª Ev.     ex03e04           1           1       1      True
#
#    sol_tex
# 9     True
# **Ejercicio: **ex03e05
#                                       enunciado_latex  \
# 16  \left\{\begin{matrix}{5^x} = {5^y} \cdot 625 \...
#
#                                    enunciado  \
# 16  [Eq(5**x, 625*5**y), Eq(2**x*2**y, 256)]
#
#                                              solucion      texto curso  \
# 16  \left [ \left \{ x : 6, \quad y : 2\right \}\r...  Resuelve:   1BC
#
#                  titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 16  Recuperación 1ª Ev.     ex03e05           1           1       1      True
#
#     sol_tex
# 16     True
