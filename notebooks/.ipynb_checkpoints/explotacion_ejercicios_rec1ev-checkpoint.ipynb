# %%
import pandas as pd
import numpy as np
from docparts import escribir_ejercicios, escribir_fin, escribir_preambulo, generar_tex, exportar_pdf
from IPython.display import Markdown as md
from IPython.display import display
import string
import random

# %%
df = pd.read_csv('ejercicios_final1.csv', index_col=False)

# %%
df
# Out:
#                                       enunciado_latex  \
# 0   A=\left\{ x \in \mathbb{R}| -4 \leq x \wedge x...
# 1   A=\left\{ x \in \mathbb{R}| 3 \leq x \wedge x ...
# 2   A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
# 3   \frac{16\cdot\sqrt[3]{4}( {\sqrt {2} } )^3}{\s...
# 4   \frac{{3\sqrt{ 2 } - 2\sqrt {3} }}{{3\sqrt {2}...
# 5   {( {\sqrt {7}  + \sqrt {3} } )^2}\cdot( {5 - \...
# 6   Halla tres números naturales e impares consecu...
# 7   \frac{{7 - x}}{{x + 4}} - \frac{3}{{x - 5}} = ...
# 8                 \sqrt {x + 5}  - \sqrt {x - 1}  = 2
# 9   \left\{\begin{matrix}{2^x} + {2^y} = 24\\{2^x}...
# 10             \log_{3}(3x - 1) - \log_{3}(x + 1) = 2
# 11                 2 \log x - \log (x + 6) = 3 \log 2
# 12  \left\{\begin{matrix}2x - y + z = 6\\ 2x + 2y ...
# 13  \left\{\begin{matrix}x + 2y - 3z = 9\\ 4x - 2y...
# 14              {\binom{31}{5+2x}} = \binom{31}{2x-2}
# 15                  {\binom{17}{x}} = \binom{17}{x+1}
# 16  P(x)=4x^2+mx+9 \ no \ tenga\ ninguna \ ra \acu...
# 17  P(x)=9x^2-mx+\frac{1}{4} \ no \ tenga\ ninguna...
# 18  P(x)=16x^2-mx+\frac{9}{4} \ no \ tenga\ ningun...
# 19  \frac{{3x - 2}}{{x - 1}} - \frac{{3x + 2}}{{x ...
# 20        \frac{{{x^3} - 5{x^2} + 2x + 8}}{x^2+1} < 0
# 21  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 22  \frac{2+{ \frac{1}{x}}}{{2 + \frac{1}{{1 + \fr...
#
#                                             enunciado  \
# 0   [Interval(-4, 0), Union(Interval.open(-oo, -1)...
# 1   [Interval.Ropen(3, 10), Union(Interval.open(-o...
# 2   [Interval.Ropen(6, 8), Union(Interval.open(-oo...
# 3   (16*(2**(2/3)*(sqrt(2))**3))/((2**(1/3)*sqrt(2)))
# 4   -sqrt(6)/4 + (-2*sqrt(3) + 3*sqrt(2))/(2*sqrt(...
# 5              (-sqrt(21) + 5)*(sqrt(3) + sqrt(7))**2
# 6             6*x - (2*x - 1)*(2*x + 1)*(2*x + 3) + 9
# 7   Eq((-x + 7)/(x + 4) - 3/(x - 5), (26*x - 25)/(...
# 8                   Eq(-sqrt(x - 1) + sqrt(x + 5), 2)
# 9           [Eq(2**x + 2**y, 24), Eq(2**x*2**y, 128)]
# 10            Eq(-log(x + 1, 3) + log(3*x - 1, 3), 2)
# 11    Eq(2*log(x, 10) - log(x + 6, 10), 3*log(2, 10))
# 12  [Eq(2*x - y + z, 6), Eq(2*x + 2*y - 4*z, 2), E...
# 13  [Eq(x + 2*y - 3*z, 9), Eq(4*x - 2*y, 12), Eq(4...
# 14   Eq(binomial(31, 2*x + 5), binomial(31, 2*x - 2))
# 15           Eq(binomial(17, x), binomial(17, x + 1))
# 16                                   m*x + 4*x**2 + 9
# 17                                -m*x + 9*x**2 + 1/4
# 18                               -m*x + 16*x**2 + 9/4
# 19  -(3*x + 2)/(x + 1) + (3*x - 2)/(x - 1) >= (2*x...
# 20           (2*x + x**3 - 5*x**2 + 8)/(x**2 + 1) < 0
# 21  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 22                        (2 + 1/x)/(2 + 1/(1 + 1/x))
#
#                                              solucion  \
# 0   C=\left[-1, 5\right] \ \ A \cup  B = \left(-\i...
# 1   C=\left(-\infty, -6\right] \cup \left[10, \inf...
# 2   C=\left[-9, 15\right] \ \ A \cup  B = \left(-\...
# 3                                      32 \sqrt[3]{2}
# 4   \frac{- 7 \sqrt{3} + 3 \sqrt{2}}{2 \left(2 \sq...
# 5                                                   8
# 6   6 x - \left(2 x - 1\right) \left(2 x + 1\right...
# 7            \left [ - \frac{23}{2}, \quad -1\right ]
# 8                         \left [ \frac{5}{4}\right ]
# 9   \left [ \left \{ x : 3, \quad y : 4\right \}, ...
# 10                      \left [ - \frac{5}{3}\right ]
# 11                                 \left [ 12\right ]
# 12  \left[\begin{matrix}-1 & 2 & 1 & 6\\0 & 6 & -2...
# 13  \left[\begin{matrix}2 & 1 & -3 & 9\\0 & 5 & -3...
# 14                                   \left\{7\right\}
# 15                                   \left\{8\right\}
# 16  \left [ 4, \quad m, \quad 9\right ]\to -12 < m...
# 17  \left [ 9, \quad - m, \quad \frac{1}{4}\right ...
# 18  \left [ 16, \quad - m, \quad \frac{9}{4}\right...
# 19  \left(-\infty, -1\right) \cup \left(1, \infty\...
# 20    \left(-\infty, -1\right) \cup \left(2, 4\right)
# 21                          \frac{x^{2} + 2 x}{x - 1}
# 22            \frac{2 x^{2} + 3 x + 1}{3 x^{2} + 2 x}
#
#                                                 texto curso        titulo  \
# 0   Dados los siguientes conjuntos A, B y C, repre...   1BC  Final 1ª Ev.
# 1   Dados los siguientes conjuntos A, B y C, repre...   1BC  Final 1ª Ev.
# 2   Dados los siguientes conjuntos A, B y C, repre...   1BC  Final 1ª Ev.
# 3                                           Calcular:   1BC  Final 1ª Ev.
# 4                                           Calcular:   1BC  Final 1ª Ev.
# 5                                           Calcular:   1BC  Final 1ª Ev.
# 6          Resuelve mediante expresiones algebraicas:   1BC  Final 1ª Ev.
# 7                                           Resuelve:   1BC  Final 1ª Ev.
# 8                                           Resuelve:   1BC  Final 1ª Ev.
# 9                                          Resolver :   1BC  Final 1ª Ev.
# 10                                         Resolver :   1BC  Final 1ª Ev.
# 11                                         Resolver :   1BC  Final 1ª Ev.
# 12  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
# 13  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
# 14  Usando la definición y las propiedades de los ...   1BC  Final 1ª Ev.
# 15  Usando la definición y las propiedades de los ...   1BC  Final 1ª Ev.
# 16                  Calcula el valor de $m$ para que:   1BC  Final 1ª Ev.
# 17                  Calcula el valor de $m$ para que:   1BC  Final 1ª Ev.
# 18                  Calcula el valor de $m$ para que:   1BC  Final 1ª Ev.
# 19                                          Resuelve:   1BC  Final 1ª Ev.
# 20                                          Resuelve:   1BC  Final 1ª Ev.
# 21  Calcula expresando el resultado en forma de fr...   1BC  Final 1ª Ev.
# 22  Calcula expresando el resultado en forma de fr...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 0      ex02e01           1           3       1      True     True
# 1      ex02e01           1           3       1      True     True
# 2      ex02e01           1           3       1      True     True
# 3      ex02e02           1           3       1      True     True
# 4      ex02e02           1           3       1      True     True
# 5      ex02e02           1           3       1      True     True
# 6      ex02e03           1           3       1     False     True
# 7      ex02e04           1           3       1      True     True
# 8      ex02e04           1           3       1      True     True
# 9      ex02e05           1           3       1      True     True
# 10     ex02e06           1           3       1      True     True
# 11     ex02e06           1           3       1      True     True
# 12     ex02e07           1           3       1      True     True
# 13     ex02e07           1           3       1      True     True
# 14     ex02e08           1           3       1      True     True
# 15     ex02e08           1           3       1      True     True
# 16     ex02e09           1           3       1      True     True
# 17     ex02e09           1           3       1      True     True
# 18     ex02e09           1           3       1      True     True
# 19     ex02e10           1           3       1      True     True
# 20     ex02e10           1           3       1      True     True
# 21     ex02e11           1           3       1      True     True
# 22     ex02e11           1           3       1      True     True

# %%
df.pivot_table(index = ['n_ejercicio'], columns=['texto','puntos'])
# Out:
#                                    dificultad            \
# texto       Calcula el valor de $m$ para que: Calcular:
# puntos                                      1         1
# n_ejercicio
# ex02e01                                   NaN       NaN
# ex02e02                                   NaN       1.0
# ex02e03                                   NaN       NaN
# ex02e04                                   NaN       NaN
# ex02e05                                   NaN       NaN
# ex02e06                                   NaN       NaN
# ex02e07                                   NaN       NaN
# ex02e08                                   NaN       NaN
# ex02e09                                   1.0       NaN
#
#                                                                                                                                                                                                                                                                                                             \
# texto       Dados los siguientes conjuntos A, B y C, represéntalos en la recta real. A continuación, calcula $A \cup  B$ , $A \cap B$ y $(A \cup B) \cap C$ , \ny expresa los resultados en forma de Intervalos. \nIndica además, si existe, el máximo y el mínimo de cada uno de los conjuntos resultado.
# puntos                                                                                                                                                                                                                                                                                                   1
# n_ejercicio
# ex02e01                                                    1.0
# ex02e02                                                    NaN
# ex02e03                                                    NaN
# ex02e04                                                    NaN
# ex02e05                                                    NaN
# ex02e06                                                    NaN
# ex02e07                                                    NaN
# ex02e08                                                    NaN
# ex02e09                                                    NaN
#
#                                                                              \
# texto       Discute el tipo de sistema y resuelve si es posible: Resolver :
# puntos                                                         1          1
# n_ejercicio
# ex02e01                                                    NaN          NaN
# ex02e02                                                    NaN          NaN
# ex02e03                                                    NaN          NaN
# ex02e04                                                    NaN          NaN
# ex02e05                                                    NaN          1.0
# ex02e06                                                    NaN          1.0
# ex02e07                                                    1.0          NaN
# ex02e08                                                    NaN          NaN
# ex02e09                                                    NaN          NaN
#
#                                                                   \
# texto       Resuelve mediante expresiones algebraicas: Resuelve:
# puntos                                               1         1
# n_ejercicio
# ex02e01                                            NaN       NaN
# ex02e02                                            NaN       NaN
# ex02e03                                            1.0       NaN
# ex02e04                                            NaN       1.0
# ex02e05                                            NaN       NaN
# ex02e06                                            NaN       NaN
# ex02e07                                            NaN       NaN
# ex02e08                                            NaN       NaN
# ex02e09                                            NaN       NaN
#
#                                                                                                            \
# texto       Usando la definición y las propiedades de los números combinatorios, resolver las ecuaciones:
# puntos                                                                                                  1
# n_ejercicio
# ex02e01                                                    NaN
# ex02e02                                                    NaN
# ex02e03                                                    NaN
# ex02e04                                                    NaN
# ex02e05                                                    NaN
# ex02e06                                                    NaN
# ex02e07                                                    NaN
# ex02e08                                                    1.0
# ex02e09                                                    NaN
#
#                                      enun_tex            \
# texto       Calcula el valor de $m$ para que: Calcular:
# puntos                                      1         1
# n_ejercicio
# ex02e01                                   NaN       NaN
# ex02e02                                   NaN      True
# ex02e03                                   NaN       NaN
# ex02e04                                   NaN       NaN
# ex02e05                                   NaN       NaN
# ex02e06                                   NaN       NaN
# ex02e07                                   NaN       NaN
# ex02e08                                   NaN       NaN
# ex02e09                                  True       NaN
#
#                                                          ...                                               \
# texto                                                    ...
# puntos                                                   ...
# n_ejercicio                                              ...
# ex02e01                                                  ...
# ex02e02                                                  ...
# ex02e03                                                  ...
# ex02e04                                                  ...
# ex02e05                                                  ...
# ex02e06                                                  ...
# ex02e07                                                  ...
# ex02e08                                                  ...
# ex02e09                                                  ...
#
#             n_columnas  \
# texto        Resuelve:
# puntos               1
# n_ejercicio
# ex02e01            NaN
# ex02e02            NaN
# ex02e03            NaN
# ex02e04            3.0
# ex02e05            NaN
# ex02e06            NaN
# ex02e07            NaN
# ex02e08            NaN
# ex02e09            NaN
#
#                                                                                                            \
# texto       Usando la definición y las propiedades de los números combinatorios, resolver las ecuaciones:
# puntos                                                                                                  1
# n_ejercicio
# ex02e01                                                    NaN
# ex02e02                                                    NaN
# ex02e03                                                    NaN
# ex02e04                                                    NaN
# ex02e05                                                    NaN
# ex02e06                                                    NaN
# ex02e07                                                    NaN
# ex02e08                                                    3.0
# ex02e09                                                    NaN
#
#                                       sol_tex            \
# texto       Calcula el valor de $m$ para que: Calcular:
# puntos                                      1         1
# n_ejercicio
# ex02e01                                   NaN       NaN
# ex02e02                                   NaN      True
# ex02e03                                   NaN       NaN
# ex02e04                                   NaN       NaN
# ex02e05                                   NaN       NaN
# ex02e06                                   NaN       NaN
# ex02e07                                   NaN       NaN
# ex02e08                                   NaN       NaN
# ex02e09                                  True       NaN
#
#                                                                                                                                                                                                                                                                                                             \
# texto       Dados los siguientes conjuntos A, B y C, represéntalos en la recta real. A continuación, calcula $A \cup  B$ , $A \cap B$ y $(A \cup B) \cap C$ , \ny expresa los resultados en forma de Intervalos. \nIndica además, si existe, el máximo y el mínimo de cada uno de los conjuntos resultado.
# puntos                                                                                                                                                                                                                                                                                                   1
# n_ejercicio
# ex02e01                                                   True
# ex02e02                                                    NaN
# ex02e03                                                    NaN
# ex02e04                                                    NaN
# ex02e05                                                    NaN
# ex02e06                                                    NaN
# ex02e07                                                    NaN
# ex02e08                                                    NaN
# ex02e09                                                    NaN
#
#                                                                              \
# texto       Discute el tipo de sistema y resuelve si es posible: Resolver :
# puntos                                                         1          1
# n_ejercicio
# ex02e01                                                    NaN          NaN
# ex02e02                                                    NaN          NaN
# ex02e03                                                    NaN          NaN
# ex02e04                                                    NaN          NaN
# ex02e05                                                    NaN         True
# ex02e06                                                    NaN         True
# ex02e07                                                   True          NaN
# ex02e08                                                    NaN          NaN
# ex02e09                                                    NaN          NaN
#
#                                                                   \
# texto       Resuelve mediante expresiones algebraicas: Resuelve:
# puntos                                               1         1
# n_ejercicio
# ex02e01                                            NaN       NaN
# ex02e02                                            NaN       NaN
# ex02e03                                           True       NaN
# ex02e04                                            NaN      True
# ex02e05                                            NaN       NaN
# ex02e06                                            NaN       NaN
# ex02e07                                            NaN       NaN
# ex02e08                                            NaN       NaN
# ex02e09                                            NaN       NaN
#
#
# texto       Usando la definición y las propiedades de los números combinatorios, resolver las ecuaciones:
# puntos                                                                                                  1
# n_ejercicio
# ex02e01                                                    NaN
# ex02e02                                                    NaN
# ex02e03                                                    NaN
# ex02e04                                                    NaN
# ex02e05                                                    NaN
# ex02e06                                                    NaN
# ex02e07                                                    NaN
# ex02e08                                                   True
# ex02e09                                                    NaN
#
# [9 rows x 32 columns]

# %%
# Generador de prueb: Cambia los parámetros 

fichero = 'final'
titulo = 'Final 1ª evaluación'
tipo = 'ejerc'  # Todo lo que sea diferente a 'ejercicios' lo generará

n_pdf = list(string.ascii_uppercase)[:2] # Pruebas diferentes a generar

if tipo != 'ejercicios' :
 
    #Construcción de lista de ejercicios
    numero = 2 # Número de ejercicios por defecto de cada ejercicio
    
    lista1 = np.unique(df.n_ejercicio.tolist())
    lista2 =[]
    for i in range(lista1.size) : lista2.append(numero)
    lista = list(zip(lista1,lista2))
    
    # Si queremos poner nuestra propia lista: lista =[('texto_nejercicio',nº de ejercicios)], si no comentar la linea siguiente
    # lista = [('ex01e01', 1),('ex01e02', 1),('ex01e03', 1),('ex01e05', 2),('ex01e06', 1),('ex01e08', 1)]
    lista = [('ex02e01', 1),('ex02e02', 2),('ex02e03', 1),('ex02e04', 2),('ex02e05', 1),('ex02e06', 1),('ex02e07', 2),('ex02e08', 1),('ex02e09', 1),('ex02e10', 2),('ex02e11', 1)]
    
    for s in n_pdf:
        random.shuffle(lista)
        df_ejercicios = pd.concat(df.loc[np.random.choice(df[df.n_ejercicio==s[0]].index, s[1], replace=False)] for s in lista)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = False)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = True)

else :
    exportar_pdf(df, fichero, titulo, tipo)
# Out:
# **Ejercicio: **ex02e01
#                                      enunciado_latex  \
# 2  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 2  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 2  C=\left[-9, 15\right] \ \ A \cup  B = \left(-\...
#
#                                                texto curso        titulo  \
# 2  Dados los siguientes conjuntos A, B y C, repre...   1BC  Final 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 2     ex02e01           1           1       1      True     True
# **Ejercicio: **ex02e02
#                                      enunciado_latex  \
# 4  \frac{{3\sqrt{ 2 } - 2\sqrt {3} }}{{3\sqrt {2}...
# 3  \frac{16\cdot\sqrt[3]{4}( {\sqrt {2} } )^3}{\s...
#
#                                            enunciado  \
# 4  -sqrt(6)/4 + (-2*sqrt(3) + 3*sqrt(2))/(2*sqrt(...
# 3  (16*(2**(2/3)*(sqrt(2))**3))/((2**(1/3)*sqrt(2)))
#
#                                             solucion      texto curso  \
# 4  \frac{- 7 \sqrt{3} + 3 \sqrt{2}}{2 \left(2 \sq...  Calcular:   1BC
# 3                                     32 \sqrt[3]{2}  Calcular:   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 4  Final 1ª Ev.     ex02e02           1           1       1      True     True
# 3  Final 1ª Ev.     ex02e02           1           1       1      True     True
# **Ejercicio: **ex02e03
#                                      enunciado_latex  \
# 6  Halla tres números naturales e impares consecu...
#
#                                  enunciado  \
# 6  6*x - (2*x - 1)*(2*x + 1)*(2*x + 3) + 9
#
#                                             solucion  \
# 6  6 x - \left(2 x - 1\right) \left(2 x + 1\right...
#
#                                         texto curso        titulo n_ejercicio  \
# 6  Resuelve mediante expresiones algebraicas:   1BC  Final 1ª Ev.     ex02e03
#
#    dificultad  n_columnas  puntos  enun_tex  sol_tex
# 6           1           1       1     False     True
# **Ejercicio: **ex02e04
#                                      enunciado_latex  \
# 8                \sqrt {x + 5}  - \sqrt {x - 1}  = 2
# 7  \frac{{7 - x}}{{x + 4}} - \frac{3}{{x - 5}} = ...
#
#                                            enunciado  \
# 8                  Eq(-sqrt(x - 1) + sqrt(x + 5), 2)
# 7  Eq((-x + 7)/(x + 4) - 3/(x - 5), (26*x - 25)/(...
#
#                                    solucion      texto curso        titulo  \
# 8               \left [ \frac{5}{4}\right ]  Resuelve:   1BC  Final 1ª Ev.
# 7  \left [ - \frac{23}{2}, \quad -1\right ]  Resuelve:   1BC  Final 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 8     ex02e04           1           1       1      True     True
# 7     ex02e04           1           1       1      True     True
# **Ejercicio: **ex02e05
#                                      enunciado_latex  \
# 9  \left\{\begin{matrix}{2^x} + {2^y} = 24\\{2^x}...
#
#                                    enunciado  \
# 9  [Eq(2**x + 2**y, 24), Eq(2**x*2**y, 128)]
#
#                                             solucion       texto curso  \
# 9  \left [ \left \{ x : 3, \quad y : 4\right \}, ...  Resolver :   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 9  Final 1ª Ev.     ex02e05           1           1       1      True     True
# **Ejercicio: **ex02e06
#                        enunciado_latex  \
# 11  2 \log x - \log (x + 6) = 3 \log 2
#
#                                           enunciado            solucion  \
# 11  Eq(2*log(x, 10) - log(x + 6, 10), 3*log(2, 10))  \left [ 12\right ]
#
#          texto curso        titulo n_ejercicio  dificultad  n_columnas  \
# 11  Resolver :   1BC  Final 1ª Ev.     ex02e06           1           1
#
#     puntos  enun_tex  sol_tex
# 11       1      True     True
# **Ejercicio: **ex02e07
#                                       enunciado_latex  \
# 12  \left\{\begin{matrix}2x - y + z = 6\\ 2x + 2y ...
# 13  \left\{\begin{matrix}x + 2y - 3z = 9\\ 4x - 2y...
#
#                                             enunciado  \
# 12  [Eq(2*x - y + z, 6), Eq(2*x + 2*y - 4*z, 2), E...
# 13  [Eq(x + 2*y - 3*z, 9), Eq(4*x - 2*y, 12), Eq(4...
#
#                                              solucion  \
# 12  \left[\begin{matrix}-1 & 2 & 1 & 6\\0 & 6 & -2...
# 13  \left[\begin{matrix}2 & 1 & -3 & 9\\0 & 5 & -3...
#
#                                                 texto curso        titulo  \
# 12  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
# 13  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 12     ex02e07           1           1       1      True     True
# 13     ex02e07           1           1       1      True     True
# **Ejercicio: **ex02e08
#                           enunciado_latex  \
# 14  {\binom{31}{5+2x}} = \binom{31}{2x-2}
#
#                                            enunciado          solucion  \
# 14  Eq(binomial(31, 2*x + 5), binomial(31, 2*x - 2))  \left\{7\right\}
#
#                                                 texto curso        titulo  \
# 14  Usando la definición y las propiedades de los ...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 14     ex02e08           1           1       1      True     True
# **Ejercicio: **ex02e09
#                                       enunciado_latex            enunciado  \
# 17  P(x)=9x^2-mx+\frac{1}{4} \ no \ tenga\ ninguna...  -m*x + 9*x**2 + 1/4
#
#                                              solucion  \
# 17  \left [ 9, \quad - m, \quad \frac{1}{4}\right ...
#
#                                 texto curso        titulo n_ejercicio  \
# 17  Calcula el valor de $m$ para que:   1BC  Final 1ª Ev.     ex02e09
#
#     dificultad  n_columnas  puntos  enun_tex  sol_tex
# 17           1           1       1      True     True
# **Ejercicio: **ex02e10
#                                       enunciado_latex  \
# 19  \frac{{3x - 2}}{{x - 1}} - \frac{{3x + 2}}{{x ...
# 20        \frac{{{x^3} - 5{x^2} + 2x + 8}}{x^2+1} < 0
#
#                                             enunciado  \
# 19  -(3*x + 2)/(x + 1) + (3*x - 2)/(x - 1) >= (2*x...
# 20           (2*x + x**3 - 5*x**2 + 8)/(x**2 + 1) < 0
#
#                                              solucion      texto curso  \
# 19  \left(-\infty, -1\right) \cup \left(1, \infty\...  Resuelve:   1BC
# 20    \left(-\infty, -1\right) \cup \left(2, 4\right)  Resuelve:   1BC
#
#           titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 19  Final 1ª Ev.     ex02e10           1           1       1      True
# 20  Final 1ª Ev.     ex02e10           1           1       1      True
#
#     sol_tex
# 19     True
# 20     True
# **Ejercicio: **ex02e11
#                                       enunciado_latex  \
# 22  \frac{2+{ \frac{1}{x}}}{{2 + \frac{1}{{1 + \fr...
#
#                       enunciado                                 solucion  \
# 22  (2 + 1/x)/(2 + 1/(1 + 1/x))  \frac{2 x^{2} + 3 x + 1}{3 x^{2} + 2 x}
#
#                                                 texto curso        titulo  \
# 22  Calcula expresando el resultado en forma de fr...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 22     ex02e11           1           1       1      True     True
# **Ejercicio: **ex02e01
#                                      enunciado_latex  \
# 2  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 2  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 2  C=\left[-9, 15\right] \ \ A \cup  B = \left(-\...
#
#                                                texto curso        titulo  \
# 2  Dados los siguientes conjuntos A, B y C, repre...   1BC  Final 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 2     ex02e01           1           1       1      True     True
# **Ejercicio: **ex02e02
#                                      enunciado_latex  \
# 4  \frac{{3\sqrt{ 2 } - 2\sqrt {3} }}{{3\sqrt {2}...
# 3  \frac{16\cdot\sqrt[3]{4}( {\sqrt {2} } )^3}{\s...
#
#                                            enunciado  \
# 4  -sqrt(6)/4 + (-2*sqrt(3) + 3*sqrt(2))/(2*sqrt(...
# 3  (16*(2**(2/3)*(sqrt(2))**3))/((2**(1/3)*sqrt(2)))
#
#                                             solucion      texto curso  \
# 4  \frac{- 7 \sqrt{3} + 3 \sqrt{2}}{2 \left(2 \sq...  Calcular:   1BC
# 3                                     32 \sqrt[3]{2}  Calcular:   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 4  Final 1ª Ev.     ex02e02           1           1       1      True     True
# 3  Final 1ª Ev.     ex02e02           1           1       1      True     True
# **Ejercicio: **ex02e03
#                                      enunciado_latex  \
# 6  Halla tres números naturales e impares consecu...
#
#                                  enunciado  \
# 6  6*x - (2*x - 1)*(2*x + 1)*(2*x + 3) + 9
#
#                                             solucion  \
# 6  6 x - \left(2 x - 1\right) \left(2 x + 1\right...
#
#                                         texto curso        titulo n_ejercicio  \
# 6  Resuelve mediante expresiones algebraicas:   1BC  Final 1ª Ev.     ex02e03
#
#    dificultad  n_columnas  puntos  enun_tex  sol_tex
# 6           1           1       1     False     True
# **Ejercicio: **ex02e04
#                                      enunciado_latex  \
# 8                \sqrt {x + 5}  - \sqrt {x - 1}  = 2
# 7  \frac{{7 - x}}{{x + 4}} - \frac{3}{{x - 5}} = ...
#
#                                            enunciado  \
# 8                  Eq(-sqrt(x - 1) + sqrt(x + 5), 2)
# 7  Eq((-x + 7)/(x + 4) - 3/(x - 5), (26*x - 25)/(...
#
#                                    solucion      texto curso        titulo  \
# 8               \left [ \frac{5}{4}\right ]  Resuelve:   1BC  Final 1ª Ev.
# 7  \left [ - \frac{23}{2}, \quad -1\right ]  Resuelve:   1BC  Final 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 8     ex02e04           1           1       1      True     True
# 7     ex02e04           1           1       1      True     True
# **Ejercicio: **ex02e05
#                                      enunciado_latex  \
# 9  \left\{\begin{matrix}{2^x} + {2^y} = 24\\{2^x}...
#
#                                    enunciado  \
# 9  [Eq(2**x + 2**y, 24), Eq(2**x*2**y, 128)]
#
#                                             solucion       texto curso  \
# 9  \left [ \left \{ x : 3, \quad y : 4\right \}, ...  Resolver :   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 9  Final 1ª Ev.     ex02e05           1           1       1      True     True
# **Ejercicio: **ex02e06
#                        enunciado_latex  \
# 11  2 \log x - \log (x + 6) = 3 \log 2
#
#                                           enunciado            solucion  \
# 11  Eq(2*log(x, 10) - log(x + 6, 10), 3*log(2, 10))  \left [ 12\right ]
#
#          texto curso        titulo n_ejercicio  dificultad  n_columnas  \
# 11  Resolver :   1BC  Final 1ª Ev.     ex02e06           1           1
#
#     puntos  enun_tex  sol_tex
# 11       1      True     True
# **Ejercicio: **ex02e07
#                                       enunciado_latex  \
# 12  \left\{\begin{matrix}2x - y + z = 6\\ 2x + 2y ...
# 13  \left\{\begin{matrix}x + 2y - 3z = 9\\ 4x - 2y...
#
#                                             enunciado  \
# 12  [Eq(2*x - y + z, 6), Eq(2*x + 2*y - 4*z, 2), E...
# 13  [Eq(x + 2*y - 3*z, 9), Eq(4*x - 2*y, 12), Eq(4...
#
#                                              solucion  \
# 12  \left[\begin{matrix}-1 & 2 & 1 & 6\\0 & 6 & -2...
# 13  \left[\begin{matrix}2 & 1 & -3 & 9\\0 & 5 & -3...
#
#                                                 texto curso        titulo  \
# 12  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
# 13  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 12     ex02e07           1           1       1      True     True
# 13     ex02e07           1           1       1      True     True
# **Ejercicio: **ex02e08
#                           enunciado_latex  \
# 14  {\binom{31}{5+2x}} = \binom{31}{2x-2}
#
#                                            enunciado          solucion  \
# 14  Eq(binomial(31, 2*x + 5), binomial(31, 2*x - 2))  \left\{7\right\}
#
#                                                 texto curso        titulo  \
# 14  Usando la definición y las propiedades de los ...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 14     ex02e08           1           1       1      True     True
# **Ejercicio: **ex02e09
#                                       enunciado_latex            enunciado  \
# 17  P(x)=9x^2-mx+\frac{1}{4} \ no \ tenga\ ninguna...  -m*x + 9*x**2 + 1/4
#
#                                              solucion  \
# 17  \left [ 9, \quad - m, \quad \frac{1}{4}\right ...
#
#                                 texto curso        titulo n_ejercicio  \
# 17  Calcula el valor de $m$ para que:   1BC  Final 1ª Ev.     ex02e09
#
#     dificultad  n_columnas  puntos  enun_tex  sol_tex
# 17           1           1       1      True     True
# **Ejercicio: **ex02e10
#                                       enunciado_latex  \
# 19  \frac{{3x - 2}}{{x - 1}} - \frac{{3x + 2}}{{x ...
# 20        \frac{{{x^3} - 5{x^2} + 2x + 8}}{x^2+1} < 0
#
#                                             enunciado  \
# 19  -(3*x + 2)/(x + 1) + (3*x - 2)/(x - 1) >= (2*x...
# 20           (2*x + x**3 - 5*x**2 + 8)/(x**2 + 1) < 0
#
#                                              solucion      texto curso  \
# 19  \left(-\infty, -1\right) \cup \left(1, \infty\...  Resuelve:   1BC
# 20    \left(-\infty, -1\right) \cup \left(2, 4\right)  Resuelve:   1BC
#
#           titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 19  Final 1ª Ev.     ex02e10           1           1       1      True
# 20  Final 1ª Ev.     ex02e10           1           1       1      True
#
#     sol_tex
# 19     True
# 20     True
# **Ejercicio: **ex02e11
#                                       enunciado_latex  \
# 22  \frac{2+{ \frac{1}{x}}}{{2 + \frac{1}{{1 + \fr...
#
#                       enunciado                                 solucion  \
# 22  (2 + 1/x)/(2 + 1/(1 + 1/x))  \frac{2 x^{2} + 3 x + 1}{3 x^{2} + 2 x}
#
#                                                 texto curso        titulo  \
# 22  Calcula expresando el resultado en forma de fr...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 22     ex02e11           1           1       1      True     True
# **Ejercicio: **ex02e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -4 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-4, 0), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  C=\left[-1, 5\right] \ \ A \cup  B = \left(-\i...
#
#                                                texto curso        titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Final 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 0     ex02e01           1           1       1      True     True
# **Ejercicio: **ex02e02
#                                      enunciado_latex  \
# 4  \frac{{3\sqrt{ 2 } - 2\sqrt {3} }}{{3\sqrt {2}...
# 5  {( {\sqrt {7}  + \sqrt {3} } )^2}\cdot( {5 - \...
#
#                                            enunciado  \
# 4  -sqrt(6)/4 + (-2*sqrt(3) + 3*sqrt(2))/(2*sqrt(...
# 5             (-sqrt(21) + 5)*(sqrt(3) + sqrt(7))**2
#
#                                             solucion      texto curso  \
# 4  \frac{- 7 \sqrt{3} + 3 \sqrt{2}}{2 \left(2 \sq...  Calcular:   1BC
# 5                                                  8  Calcular:   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 4  Final 1ª Ev.     ex02e02           1           1       1      True     True
# 5  Final 1ª Ev.     ex02e02           1           1       1      True     True
# **Ejercicio: **ex02e03
#                                      enunciado_latex  \
# 6  Halla tres números naturales e impares consecu...
#
#                                  enunciado  \
# 6  6*x - (2*x - 1)*(2*x + 1)*(2*x + 3) + 9
#
#                                             solucion  \
# 6  6 x - \left(2 x - 1\right) \left(2 x + 1\right...
#
#                                         texto curso        titulo n_ejercicio  \
# 6  Resuelve mediante expresiones algebraicas:   1BC  Final 1ª Ev.     ex02e03
#
#    dificultad  n_columnas  puntos  enun_tex  sol_tex
# 6           1           1       1     False     True
# **Ejercicio: **ex02e04
#                                      enunciado_latex  \
# 7  \frac{{7 - x}}{{x + 4}} - \frac{3}{{x - 5}} = ...
# 8                \sqrt {x + 5}  - \sqrt {x - 1}  = 2
#
#                                            enunciado  \
# 7  Eq((-x + 7)/(x + 4) - 3/(x - 5), (26*x - 25)/(...
# 8                  Eq(-sqrt(x - 1) + sqrt(x + 5), 2)
#
#                                    solucion      texto curso        titulo  \
# 7  \left [ - \frac{23}{2}, \quad -1\right ]  Resuelve:   1BC  Final 1ª Ev.
# 8               \left [ \frac{5}{4}\right ]  Resuelve:   1BC  Final 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 7     ex02e04           1           1       1      True     True
# 8     ex02e04           1           1       1      True     True
# **Ejercicio: **ex02e05
#                                      enunciado_latex  \
# 9  \left\{\begin{matrix}{2^x} + {2^y} = 24\\{2^x}...
#
#                                    enunciado  \
# 9  [Eq(2**x + 2**y, 24), Eq(2**x*2**y, 128)]
#
#                                             solucion       texto curso  \
# 9  \left [ \left \{ x : 3, \quad y : 4\right \}, ...  Resolver :   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 9  Final 1ª Ev.     ex02e05           1           1       1      True     True
# **Ejercicio: **ex02e06
#                        enunciado_latex  \
# 11  2 \log x - \log (x + 6) = 3 \log 2
#
#                                           enunciado            solucion  \
# 11  Eq(2*log(x, 10) - log(x + 6, 10), 3*log(2, 10))  \left [ 12\right ]
#
#          texto curso        titulo n_ejercicio  dificultad  n_columnas  \
# 11  Resolver :   1BC  Final 1ª Ev.     ex02e06           1           1
#
#     puntos  enun_tex  sol_tex
# 11       1      True     True
# **Ejercicio: **ex02e07
#                                       enunciado_latex  \
# 12  \left\{\begin{matrix}2x - y + z = 6\\ 2x + 2y ...
# 13  \left\{\begin{matrix}x + 2y - 3z = 9\\ 4x - 2y...
#
#                                             enunciado  \
# 12  [Eq(2*x - y + z, 6), Eq(2*x + 2*y - 4*z, 2), E...
# 13  [Eq(x + 2*y - 3*z, 9), Eq(4*x - 2*y, 12), Eq(4...
#
#                                              solucion  \
# 12  \left[\begin{matrix}-1 & 2 & 1 & 6\\0 & 6 & -2...
# 13  \left[\begin{matrix}2 & 1 & -3 & 9\\0 & 5 & -3...
#
#                                                 texto curso        titulo  \
# 12  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
# 13  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 12     ex02e07           1           1       1      True     True
# 13     ex02e07           1           1       1      True     True
# **Ejercicio: **ex02e08
#                           enunciado_latex  \
# 14  {\binom{31}{5+2x}} = \binom{31}{2x-2}
#
#                                            enunciado          solucion  \
# 14  Eq(binomial(31, 2*x + 5), binomial(31, 2*x - 2))  \left\{7\right\}
#
#                                                 texto curso        titulo  \
# 14  Usando la definición y las propiedades de los ...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 14     ex02e08           1           1       1      True     True
# **Ejercicio: **ex02e09
#                                       enunciado_latex         enunciado  \
# 16  P(x)=4x^2+mx+9 \ no \ tenga\ ninguna \ ra \acu...  m*x + 4*x**2 + 9
#
#                                              solucion  \
# 16  \left [ 4, \quad m, \quad 9\right ]\to -12 < m...
#
#                                 texto curso        titulo n_ejercicio  \
# 16  Calcula el valor de $m$ para que:   1BC  Final 1ª Ev.     ex02e09
#
#     dificultad  n_columnas  puntos  enun_tex  sol_tex
# 16           1           1       1      True     True
# **Ejercicio: **ex02e10
#                                       enunciado_latex  \
# 20        \frac{{{x^3} - 5{x^2} + 2x + 8}}{x^2+1} < 0
# 19  \frac{{3x - 2}}{{x - 1}} - \frac{{3x + 2}}{{x ...
#
#                                             enunciado  \
# 20           (2*x + x**3 - 5*x**2 + 8)/(x**2 + 1) < 0
# 19  -(3*x + 2)/(x + 1) + (3*x - 2)/(x - 1) >= (2*x...
#
#                                              solucion      texto curso  \
# 20    \left(-\infty, -1\right) \cup \left(2, 4\right)  Resuelve:   1BC
# 19  \left(-\infty, -1\right) \cup \left(1, \infty\...  Resuelve:   1BC
#
#           titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 20  Final 1ª Ev.     ex02e10           1           1       1      True
# 19  Final 1ª Ev.     ex02e10           1           1       1      True
#
#     sol_tex
# 20     True
# 19     True
# **Ejercicio: **ex02e11
#                                       enunciado_latex  \
# 21  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
#
#                                             enunciado  \
# 21  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
#
#                      solucion  \
# 21  \frac{x^{2} + 2 x}{x - 1}
#
#                                                 texto curso        titulo  \
# 21  Calcula expresando el resultado en forma de fr...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 21     ex02e11           1           1       1      True     True
# **Ejercicio: **ex02e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| -4 \leq x \wedge x...
#
#                                            enunciado  \
# 0  [Interval(-4, 0), Union(Interval.open(-oo, -1)...
#
#                                             solucion  \
# 0  C=\left[-1, 5\right] \ \ A \cup  B = \left(-\i...
#
#                                                texto curso        titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Final 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 0     ex02e01           1           1       1      True     True
# **Ejercicio: **ex02e02
#                                      enunciado_latex  \
# 4  \frac{{3\sqrt{ 2 } - 2\sqrt {3} }}{{3\sqrt {2}...
# 5  {( {\sqrt {7}  + \sqrt {3} } )^2}\cdot( {5 - \...
#
#                                            enunciado  \
# 4  -sqrt(6)/4 + (-2*sqrt(3) + 3*sqrt(2))/(2*sqrt(...
# 5             (-sqrt(21) + 5)*(sqrt(3) + sqrt(7))**2
#
#                                             solucion      texto curso  \
# 4  \frac{- 7 \sqrt{3} + 3 \sqrt{2}}{2 \left(2 \sq...  Calcular:   1BC
# 5                                                  8  Calcular:   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 4  Final 1ª Ev.     ex02e02           1           1       1      True     True
# 5  Final 1ª Ev.     ex02e02           1           1       1      True     True
# **Ejercicio: **ex02e03
#                                      enunciado_latex  \
# 6  Halla tres números naturales e impares consecu...
#
#                                  enunciado  \
# 6  6*x - (2*x - 1)*(2*x + 1)*(2*x + 3) + 9
#
#                                             solucion  \
# 6  6 x - \left(2 x - 1\right) \left(2 x + 1\right...
#
#                                         texto curso        titulo n_ejercicio  \
# 6  Resuelve mediante expresiones algebraicas:   1BC  Final 1ª Ev.     ex02e03
#
#    dificultad  n_columnas  puntos  enun_tex  sol_tex
# 6           1           1       1     False     True
# **Ejercicio: **ex02e04
#                                      enunciado_latex  \
# 7  \frac{{7 - x}}{{x + 4}} - \frac{3}{{x - 5}} = ...
# 8                \sqrt {x + 5}  - \sqrt {x - 1}  = 2
#
#                                            enunciado  \
# 7  Eq((-x + 7)/(x + 4) - 3/(x - 5), (26*x - 25)/(...
# 8                  Eq(-sqrt(x - 1) + sqrt(x + 5), 2)
#
#                                    solucion      texto curso        titulo  \
# 7  \left [ - \frac{23}{2}, \quad -1\right ]  Resuelve:   1BC  Final 1ª Ev.
# 8               \left [ \frac{5}{4}\right ]  Resuelve:   1BC  Final 1ª Ev.
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 7     ex02e04           1           1       1      True     True
# 8     ex02e04           1           1       1      True     True
# **Ejercicio: **ex02e05
#                                      enunciado_latex  \
# 9  \left\{\begin{matrix}{2^x} + {2^y} = 24\\{2^x}...
#
#                                    enunciado  \
# 9  [Eq(2**x + 2**y, 24), Eq(2**x*2**y, 128)]
#
#                                             solucion       texto curso  \
# 9  \left [ \left \{ x : 3, \quad y : 4\right \}, ...  Resolver :   1BC
#
#          titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 9  Final 1ª Ev.     ex02e05           1           1       1      True     True
# **Ejercicio: **ex02e06
#                        enunciado_latex  \
# 11  2 \log x - \log (x + 6) = 3 \log 2
#
#                                           enunciado            solucion  \
# 11  Eq(2*log(x, 10) - log(x + 6, 10), 3*log(2, 10))  \left [ 12\right ]
#
#          texto curso        titulo n_ejercicio  dificultad  n_columnas  \
# 11  Resolver :   1BC  Final 1ª Ev.     ex02e06           1           1
#
#     puntos  enun_tex  sol_tex
# 11       1      True     True
# **Ejercicio: **ex02e07
#                                       enunciado_latex  \
# 12  \left\{\begin{matrix}2x - y + z = 6\\ 2x + 2y ...
# 13  \left\{\begin{matrix}x + 2y - 3z = 9\\ 4x - 2y...
#
#                                             enunciado  \
# 12  [Eq(2*x - y + z, 6), Eq(2*x + 2*y - 4*z, 2), E...
# 13  [Eq(x + 2*y - 3*z, 9), Eq(4*x - 2*y, 12), Eq(4...
#
#                                              solucion  \
# 12  \left[\begin{matrix}-1 & 2 & 1 & 6\\0 & 6 & -2...
# 13  \left[\begin{matrix}2 & 1 & -3 & 9\\0 & 5 & -3...
#
#                                                 texto curso        titulo  \
# 12  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
# 13  Discute el tipo de sistema y resuelve si es po...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 12     ex02e07           1           1       1      True     True
# 13     ex02e07           1           1       1      True     True
# **Ejercicio: **ex02e08
#                           enunciado_latex  \
# 14  {\binom{31}{5+2x}} = \binom{31}{2x-2}
#
#                                            enunciado          solucion  \
# 14  Eq(binomial(31, 2*x + 5), binomial(31, 2*x - 2))  \left\{7\right\}
#
#                                                 texto curso        titulo  \
# 14  Usando la definición y las propiedades de los ...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 14     ex02e08           1           1       1      True     True
# **Ejercicio: **ex02e09
#                                       enunciado_latex         enunciado  \
# 16  P(x)=4x^2+mx+9 \ no \ tenga\ ninguna \ ra \acu...  m*x + 4*x**2 + 9
#
#                                              solucion  \
# 16  \left [ 4, \quad m, \quad 9\right ]\to -12 < m...
#
#                                 texto curso        titulo n_ejercicio  \
# 16  Calcula el valor de $m$ para que:   1BC  Final 1ª Ev.     ex02e09
#
#     dificultad  n_columnas  puntos  enun_tex  sol_tex
# 16           1           1       1      True     True
# **Ejercicio: **ex02e10
#                                       enunciado_latex  \
# 20        \frac{{{x^3} - 5{x^2} + 2x + 8}}{x^2+1} < 0
# 19  \frac{{3x - 2}}{{x - 1}} - \frac{{3x + 2}}{{x ...
#
#                                             enunciado  \
# 20           (2*x + x**3 - 5*x**2 + 8)/(x**2 + 1) < 0
# 19  -(3*x + 2)/(x + 1) + (3*x - 2)/(x - 1) >= (2*x...
#
#                                              solucion      texto curso  \
# 20    \left(-\infty, -1\right) \cup \left(2, 4\right)  Resuelve:   1BC
# 19  \left(-\infty, -1\right) \cup \left(1, \infty\...  Resuelve:   1BC
#
#           titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex  \
# 20  Final 1ª Ev.     ex02e10           1           1       1      True
# 19  Final 1ª Ev.     ex02e10           1           1       1      True
#
#     sol_tex
# 20     True
# 19     True
# **Ejercicio: **ex02e11
#                                       enunciado_latex  \
# 21  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
#
#                                             enunciado  \
# 21  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
#
#                      solucion  \
# 21  \frac{x^{2} + 2 x}{x - 1}
#
#                                                 texto curso        titulo  \
# 21  Calcula expresando el resultado en forma de fr...   1BC  Final 1ª Ev.
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex  sol_tex
# 21     ex02e11           1           1       1      True     True
