# %%
import pandas as pd
import numpy as np
from docparts import escribir_ejercicios, escribir_fin, escribir_preambulo, generar_tex, exportar_pdf
from IPython.display import Markdown as md
from IPython.display import display
import string
import random

# %%
df = pd.read_csv('ejercicios_parcial1b.csv', index_col=False)

# %%
df
# Out:
#                                       enunciado_latex  \
# 0   A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
# 1                  {\binom{23}{x}} = \binom{23}{3x-1}
# 2               {\binom{39}{5+2x}} = \binom{39}{2x-2}
# 3                   {\binom{15}{x}} = \binom{15}{x+1}
# 4                                 {\binom{x}{2}} = 21
# 5                                 {\binom{x}{2}} = 28
# 6                             {\binom{x}{x - 2}} = 10
# 7                             {\binom{x}{x - 2}} = 28
# 8   {\binom{11}{3}} = {\binom{12}{3}}-{\binom{11}{x}}
# 9   {\binom{33}{x}} = {\binom{33}{x+y}}-{\binom{34...
# 10  {\binom{20}{7}} - {\binom{19}{x}}-{\binom{19}{...
# 11  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
# 12  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
# 13  P(x)=\left(2 x - \frac{3}{x}\right)^{8} \  \ y...
# 14  P(x)=\left(3 x^{2} + \frac{1}{x}\right)^{7} \ ...
# 15   P(x)=\left(3 x^{2} - \frac{3}{x}\right)^{10} \,
# 16  P(x)=\left(3 x^{2} - \frac{1}{3 x}\right)^{10}...
# 17                P(x)=\left(x^{2} + x\right)^{4} \,
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
# 19  \frac{\sqrt{3}}{\sqrt{3}-\sqrt{2}}-\frac{\sqrt...
# 20  El \ resto \ de \ dividir \ P(x)=x^{27}-kx+3k-...
# 21  El \ resto \ de \ dividir \ P(x)=x^{27}-kx+3k-...
# 22  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
# 23  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
# 24  El \ resto \ de \ dividir \ P(x)=x^{25}-kx+3k-...
# 25  P(x)=x^2+mx-16 \ tenga\ dos \ ra\acute \imath ...
# 26  P(x)=\frac{x^2}{9}+mx+\frac{9}{25} \ tenga\ do...
# 27  P(x)=\frac{x^2}{25}-mx+\frac{4}{9} \ tenga\ do...
# 28  P(x)=4x^2-mx+9 \ tenga\ una \ ra \acute \imath...
# 29  P(x)=\frac{x^2}{16}-mx+\frac{9}{4} \ tenga\ un...
# 30  P(x)=\frac{x^2}{4}-mx+\frac{1}{16} \ tenga\ un...
# 31  P(x)=4x^2+mx+9 \ no \ tenga\ ninguna \ ra \acu...
# 32  P(x)=9x^2-mx+\frac{1}{4} \ no \ tenga\ ninguna...
# 33  P(x)=16x^2-mx+\frac{9}{4} \ no \ tenga\ ningun...
# 34   A(x)= x^5+x^4-7x^3+x^2+10x-6\  y \\  B(x)= x^...
# 35   A(x)= x^{5} - 6 x^{3} + 2 x^{2} + 9 x - 6\  y...
# 36   A(x)= x^{5} - 2 x^{4} - 5 x^{3} + 10 x^{2} + ...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
#
#                                             enunciado  \
# 0   [Interval.Ropen(6, 8), Union(Interval.open(-oo...
# 1          Eq(binomial(23, x), binomial(23, 3*x - 1))
# 2    Eq(binomial(39, 2*x + 5), binomial(39, 2*x - 2))
# 3            Eq(binomial(15, x), binomial(15, x + 1))
# 4                              Eq(binomial(x, 2), 21)
# 5                              Eq(binomial(x, 2), 28)
# 6                          Eq(binomial(x, x - 2), 10)
# 7                          Eq(binomial(x, x - 2), 28)
# 8                                       Eq(-x + 3, 1)
# 9                            [Eq(y, 1), Eq(x + y, 5)]
# 10                                       Eq(x + 1, 7)
# 11                          ((2*x - 3/x)**8, x**(-6))
# 12                          ((3*x**2 + 1/x)**7, x**5)
# 13                          ((2*x - 3/x)**8, x**(-8))
# 14                          ((3*x**2 + 1/x)**7, x**8)
# 15              ((3*x**2 - 3/x)**10, -14880348*x**10)
# 16             ((3*x**2 - 1/(3*x))**10, -61236*x**10)
# 17                            ((x**2 + x)**4, 6*x**6)
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
# 19  -sqrt(3)/(sqrt(2) + sqrt(3)) + sqrt(3)/(-sqrt(...
# 20  (Poly((3*k - k*x + x**27) - 4, 3*k - k*x + x**...
# 21  (Poly((3*k - k*x + x**27) - 4, 3*k - k*x + x**...
# 22  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...
# 23  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...
# 24  (Poly((3*k - k*x + x**25) - 4, 3*k - k*x + x**...
# 25                                    m*x + x**2 - 16
# 26                                m*x + x**2/9 + 9/25
# 27                               -m*x + x**2/25 + 4/9
# 28                                  -m*x + 4*x**2 + 9
# 29                               -m*x + x**2/16 + 9/4
# 30                               -m*x + x**2/4 + 1/16
# 31                                   m*x + 4*x**2 + 9
# 32                                -m*x + 9*x**2 + 1/4
# 33                               -m*x + 16*x**2 + 9/4
# 34  (x**5 + x**4 - 7*x**3 + x**2 + 10*x - 6, x**5 ...
# 35  (x**5 - 6*x**3 + 2*x**2 + 9*x - 6, x**5 + 3*x*...
# 36  (x**5 - 2*x**4 - 5*x**3 + 10*x**2 + 4*x - 8, x...
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
#
#                                              solucion  \
# 0   C=\left(-\infty, -14\right] \cup \left[10, \in...
# 1                                    \left\{6\right\}
# 2                                    \left\{9\right\}
# 3                                    \left\{7\right\}
# 4                                    \left\{7\right\}
# 5                                    \left\{8\right\}
# 6                                    \left\{5\right\}
# 7                                    \left\{8\right\}
# 8                                   \left [ 2\right ]
# 9                \left \{ x : 4, \quad y : 1\right \}
# 10                                  \left [ 6\right ]
# 11                                             -34992
# 12                                               2835
# 13                                               6561
# 14                                               5103
# 15                                  - 14880348 x^{10}
# 16                                     - 61236 x^{10}
# 17                                            6 x^{6}
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...
# 19                            2 \sqrt{6}\to2 \sqrt{6}
# 20                                                  4
# 21                                                  4
# 22                                                  4
# 23                                                  3
# 24                                                  3
# 25  \left [ 1, \quad m, \quad -16\right ]\to \left...
# 26  \left [ \frac{1}{9}, \quad m, \quad \frac{9}{2...
# 27  \left [ \frac{1}{25}, \quad - m, \quad \frac{4...
# 28  \left [ 4, \quad - m, \quad 9\right ]\to \left...
# 29  \left [ \frac{1}{16}, \quad - m, \quad \frac{9...
# 30  \left [ \frac{1}{4}, \quad - m, \quad \frac{1}...
# 31  \left [ 4, \quad m, \quad 9\right ]\to -12 < m...
# 32  \left [ 9, \quad - m, \quad \frac{1}{4}\right ...
# 33  \left [ 16, \quad - m, \quad \frac{9}{4}\right...
# 34  Descomposici \acute on:(\left(x - 1\right)^{2}...
# 35  Descomposici \acute on:(\left(x - 1\right)^{2}...
# 36  Descomposici \acute on:(\left(x - 2\right)^{2}...
# 37                          \frac{x^{2} + 2 x}{x - 1}
# 38                \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 39                               \frac{6}{x^{2} - 12}
#
#                                                 texto curso     titulo  \
# 0   Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
# 1   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 2   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 3   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 4   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 5   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 6   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 7   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 8   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 9   Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 10  Usando la definición y las propiedades de los ...   1BC  Parcial 1
# 11  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
# 12  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
# 13  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
# 14  Calcula, sin hacer todo el desarrollo, el coef...   1BC  Parcial 1
# 15  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
# 16  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
# 17  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
# 18                                           Efectúa:   1BC  Parcial 1
# 19                                           Efectúa:   1BC  Parcial 1
# 20                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 21                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 22                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 23                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 24                  Calcula el valor de $k$ para que:   1BC  Parcial 1
# 25                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 26                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 27                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 28                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 29                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 30                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 31                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 32                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 33                  Calcula el valor de $m$ para que:   1BC  Parcial 1
# 34    Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
# 35    Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
# 36    Halla el m.c.d. y el m.c.m. de los polinomios:    1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0      ex01e01           1           3       2      True
# 1      ex01e02           1           3       1      True
# 2      ex01e02           1           3       1      True
# 3      ex01e02           1           3       1      True
# 4      ex01e02           1           3       1      True
# 5      ex01e02           1           3       1      True
# 6      ex01e02           1           3       1      True
# 7      ex01e02           1           3       1      True
# 8      ex01e02           1           3       1      True
# 9      ex01e02           1           3       1      True
# 10     ex01e02           1           3       1      True
# 11     ex01e03           1           3       2      True
# 12     ex01e03           1           3       2      True
# 13     ex01e03           1           3       2      True
# 14     ex01e03           1           3       2      True
# 15     ex01e04           1           3       2      True
# 16     ex01e04           1           3       2      True
# 17     ex01e04           1           3       2      True
# 18     ex01e05           1           3       1      True
# 19     ex01e05           1           3       1      True
# 20     ex01e06           1           3       1      True
# 21     ex01e06           1           3       1      True
# 22     ex01e06           1           3       1      True
# 23     ex01e06           1           3       1      True
# 24     ex01e06           1           3       1      True
# 25     ex01e07           1           3       1      True
# 26     ex01e07           1           3       1      True
# 27     ex01e07           1           3       1      True
# 28     ex01e07           1           3       1      True
# 29     ex01e07           1           3       1      True
# 30     ex01e07           1           3       1      True
# 31     ex01e07           1           3       1      True
# 32     ex01e07           1           3       1      True
# 33     ex01e07           1           3       1      True
# 34     ex01e08           1           3       3      True
# 35     ex01e08           1           3       3      True
# 36     ex01e08           1           3       3      True
# 37     ex01e09           1           3       1      True
# 38     ex01e09           1           3       1      True
# 39     ex01e09           1           3       1      True

# %%
df.pivot_table(index = ['n_ejercicio'], columns=['texto','puntos'])
# Out:
#                                    dificultad  \
# texto       Calcula el valor de $k$ para que:
# puntos                                      1
# n_ejercicio
# ex01e01                                   NaN
# ex01e02                                   NaN
# ex01e03                                   NaN
# ex01e04                                   NaN
# ex01e05                                   NaN
# ex01e06                                   1.0
# ex01e07                                   NaN
# ex01e08                                   NaN
# ex01e09                                   NaN
#
#                                                \
# texto       Calcula el valor de $m$ para que:
# puntos                                      1
# n_ejercicio
# ex01e01                                   NaN
# ex01e02                                   NaN
# ex01e03                                   NaN
# ex01e04                                   NaN
# ex01e05                                   NaN
# ex01e06                                   NaN
# ex01e07                                   1.0
# ex01e08                                   NaN
# ex01e09                                   NaN
#
#                                                                                           \
# texto       Calcula expresando el resultado en forma de fracción algebraica irreducible:
# puntos                                                                                 1
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                    NaN
# ex01e03                                                    NaN
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    1.0
#
#                                                                                            \
# texto       Calcula, sin hacer todo el desarrollo, el coeficiente del término asociado a:
# puntos                                                                                  2
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                    NaN
# ex01e03                                                    1.0
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
#                                                                                                                                                                                                                                                                                                            \
# texto       Dados los siguientes conjuntos A, B y C, represéntalos en la recta real. A continuación, calcula $A \cup  B$ , $A \cap B$ y $A \cap B \cap C$ , \ny expresa los resultados en forma de Intervalos. \nIndica además, si existe, el supremo y el ínfimo de cada uno.de los conjuntos resultado.
# puntos                                                                                                                                                                                                                                                                                                  2
# n_ejercicio
# ex01e01                                                    1.0
# ex01e02                                                    NaN
# ex01e03                                                    NaN
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
#                       \
# texto       Efectúa:
# puntos             1
# n_ejercicio
# ex01e01          NaN
# ex01e02          NaN
# ex01e03          NaN
# ex01e04          NaN
# ex01e05          1.0
# ex01e06          NaN
# ex01e07          NaN
# ex01e08          NaN
# ex01e09          NaN
#
#                                                                                                                  \
# texto       Encontrar, sin hacer todo el desarrollo, el término central del desarrollo del siguiente polinomio:
# puntos                                                                                                        2
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                    NaN
# ex01e03                                                    NaN
# ex01e04                                                    1.0
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
#                                                              \
# texto       Halla el m.c.d. y el m.c.m. de los polinomios:
# puntos                                                    3
# n_ejercicio
# ex01e01                                                 NaN
# ex01e02                                                 NaN
# ex01e03                                                 NaN
# ex01e04                                                 NaN
# ex01e05                                                 NaN
# ex01e06                                                 NaN
# ex01e07                                                 NaN
# ex01e08                                                 1.0
# ex01e09                                                 NaN
#
#                                                                                                            \
# texto       Usando la definición y las propiedades de los números combinatorios, resolver las ecuaciones:
# puntos                                                                                                  1
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                    1.0
# ex01e03                                                    NaN
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
#                                      enun_tex  \
# texto       Calcula el valor de $k$ para que:
# puntos                                      1
# n_ejercicio
# ex01e01                                   NaN
# ex01e02                                   NaN
# ex01e03                                   NaN
# ex01e04                                   NaN
# ex01e05                                   NaN
# ex01e06                                  True
# ex01e07                                   NaN
# ex01e08                                   NaN
# ex01e09                                   NaN
#
#                                                          ...                                               \
# texto                                                    ...
# puntos                                                   ...
# n_ejercicio                                              ...
# ex01e01                                                  ...
# ex01e02                                                  ...
# ex01e03                                                  ...
# ex01e04                                                  ...
# ex01e05                                                  ...
# ex01e06                                                  ...
# ex01e07                                                  ...
# ex01e08                                                  ...
# ex01e09                                                  ...
#
#                                                                                                            \
# texto       Usando la definición y las propiedades de los números combinatorios, resolver las ecuaciones:
# puntos                                                                                                  1
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                   True
# ex01e03                                                    NaN
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
#                                    n_columnas  \
# texto       Calcula el valor de $k$ para que:
# puntos                                      1
# n_ejercicio
# ex01e01                                   NaN
# ex01e02                                   NaN
# ex01e03                                   NaN
# ex01e04                                   NaN
# ex01e05                                   NaN
# ex01e06                                   3.0
# ex01e07                                   NaN
# ex01e08                                   NaN
# ex01e09                                   NaN
#
#                                                \
# texto       Calcula el valor de $m$ para que:
# puntos                                      1
# n_ejercicio
# ex01e01                                   NaN
# ex01e02                                   NaN
# ex01e03                                   NaN
# ex01e04                                   NaN
# ex01e05                                   NaN
# ex01e06                                   NaN
# ex01e07                                   3.0
# ex01e08                                   NaN
# ex01e09                                   NaN
#
#                                                                                           \
# texto       Calcula expresando el resultado en forma de fracción algebraica irreducible:
# puntos                                                                                 1
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                    NaN
# ex01e03                                                    NaN
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    3.0
#
#                                                                                            \
# texto       Calcula, sin hacer todo el desarrollo, el coeficiente del término asociado a:
# puntos                                                                                  2
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                    NaN
# ex01e03                                                    3.0
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
#                                                                                                                                                                                                                                                                                                            \
# texto       Dados los siguientes conjuntos A, B y C, represéntalos en la recta real. A continuación, calcula $A \cup  B$ , $A \cap B$ y $A \cap B \cap C$ , \ny expresa los resultados en forma de Intervalos. \nIndica además, si existe, el supremo y el ínfimo de cada uno.de los conjuntos resultado.
# puntos                                                                                                                                                                                                                                                                                                  2
# n_ejercicio
# ex01e01                                                    3.0
# ex01e02                                                    NaN
# ex01e03                                                    NaN
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
#                       \
# texto       Efectúa:
# puntos             1
# n_ejercicio
# ex01e01          NaN
# ex01e02          NaN
# ex01e03          NaN
# ex01e04          NaN
# ex01e05          3.0
# ex01e06          NaN
# ex01e07          NaN
# ex01e08          NaN
# ex01e09          NaN
#
#                                                                                                                  \
# texto       Encontrar, sin hacer todo el desarrollo, el término central del desarrollo del siguiente polinomio:
# puntos                                                                                                        2
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                    NaN
# ex01e03                                                    NaN
# ex01e04                                                    3.0
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
#                                                              \
# texto       Halla el m.c.d. y el m.c.m. de los polinomios:
# puntos                                                    3
# n_ejercicio
# ex01e01                                                 NaN
# ex01e02                                                 NaN
# ex01e03                                                 NaN
# ex01e04                                                 NaN
# ex01e05                                                 NaN
# ex01e06                                                 NaN
# ex01e07                                                 NaN
# ex01e08                                                 3.0
# ex01e09                                                 NaN
#
#
# texto       Usando la definición y las propiedades de los números combinatorios, resolver las ecuaciones:
# puntos                                                                                                  1
# n_ejercicio
# ex01e01                                                    NaN
# ex01e02                                                    3.0
# ex01e03                                                    NaN
# ex01e04                                                    NaN
# ex01e05                                                    NaN
# ex01e06                                                    NaN
# ex01e07                                                    NaN
# ex01e08                                                    NaN
# ex01e09                                                    NaN
#
# [9 rows x 27 columns]

# %%
# Generador de prueb: Cambia los parámetros 

fichero = 'parcial1b'
titulo = 'Parcial 1ª evaluación'
tipo = 'ejerc'  # Todo lo que sea diferente a 'ejercicios' lo generará

n_pdf = list(string.ascii_uppercase)[:6] # Pruebas diferentes a generar

if tipo != 'ejercicios' :
 
    #Construcción de lista de ejercicios
    numero = 2 # Número de ejercicios por defecto de cada ejercicio
    
    lista1 = np.unique(df.n_ejercicio.tolist())
    lista2 =[]
    for i in range(lista1.size) : lista2.append(numero)
    lista = list(zip(lista1,lista2))
    
    # Si queremos poner nuestra propia lista: lista =[('texto_nejercicio',nº de ejercicios)], si no comentar la linea siguiente
    # lista = [('ex01e01', 1),('ex01e02', 1),('ex01e03', 1),('ex01e05', 2),('ex01e06', 1),('ex01e08', 1)]
    lista = [('ex01e01', 1),('ex01e02', 1),('ex01e04', 1),('ex01e05', 1),('ex01e07', 1),('ex01e09', 3)]
    
    for s in n_pdf:
        random.shuffle(lista)
        df_ejercicios = pd.concat(df.loc[np.random.choice(df[df.n_ejercicio==s[0]].index, s[1], replace=False)] for s in lista)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = False)
        exportar_pdf(df_ejercicios,fichero, titulo, tipo, letra = s, soluciones = True)

else :
    exportar_pdf(df, fichero, titulo, tipo)
# Out:
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#                       enunciado_latex  \
# 1  {\binom{23}{x}} = \binom{23}{3x-1}
#
#                                     enunciado          solucion  \
# 1  Eq(binomial(23, x), binomial(23, 3*x - 1))  \left\{6\right\}
#
#                                                texto curso     titulo  \
# 1  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 1     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                         enunciado_latex                enunciado solucion  \
# 17  P(x)=\left(x^{2} + x\right)^{4} \,   ((x**2 + x)**4, 6*x**6)  6 x^{6}
#
#                                                 texto curso     titulo  \
# 17  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 17     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
#
#                                             enunciado  \
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
#
#                                              solucion     texto curso  \
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 18  Parcial 1     ex01e05           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex            enunciado  \
# 32  P(x)=9x^2-mx+\frac{1}{4} \ no \ tenga\ ninguna...  -m*x + 9*x**2 + 1/4
#
#                                              solucion  \
# 32  \left [ 9, \quad - m, \quad \frac{1}{4}\right ...
#
#                                 texto curso     titulo n_ejercicio  \
# 32  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 32           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
#
#                                             enunciado  \
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
#
#                                solucion  \
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 37            \frac{x^{2} + 2 x}{x - 1}
# 39                 \frac{6}{x^{2} - 12}
#
#                                                 texto curso     titulo  \
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 38     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#                       enunciado_latex  \
# 1  {\binom{23}{x}} = \binom{23}{3x-1}
#
#                                     enunciado          solucion  \
# 1  Eq(binomial(23, x), binomial(23, 3*x - 1))  \left\{6\right\}
#
#                                                texto curso     titulo  \
# 1  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 1     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                         enunciado_latex                enunciado solucion  \
# 17  P(x)=\left(x^{2} + x\right)^{4} \,   ((x**2 + x)**4, 6*x**6)  6 x^{6}
#
#                                                 texto curso     titulo  \
# 17  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 17     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
#
#                                             enunciado  \
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
#
#                                              solucion     texto curso  \
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 18  Parcial 1     ex01e05           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex            enunciado  \
# 32  P(x)=9x^2-mx+\frac{1}{4} \ no \ tenga\ ninguna...  -m*x + 9*x**2 + 1/4
#
#                                              solucion  \
# 32  \left [ 9, \quad - m, \quad \frac{1}{4}\right ...
#
#                                 texto curso     titulo n_ejercicio  \
# 32  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 32           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
#
#                                             enunciado  \
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
#
#                                solucion  \
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 37            \frac{x^{2} + 2 x}{x - 1}
# 39                 \frac{6}{x^{2} - 12}
#
#                                                 texto curso     titulo  \
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 38     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#        enunciado_latex               enunciado          solucion  \
# 5  {\binom{x}{2}} = 28  Eq(binomial(x, 2), 28)  \left\{8\right\}
#
#                                                texto curso     titulo  \
# 5  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 5     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                                       enunciado_latex  \
# 16  P(x)=\left(3 x^{2} - \frac{1}{3 x}\right)^{10}...
#
#                                  enunciado        solucion  \
# 16  ((3*x**2 - 1/(3*x))**10, -61236*x**10)  - 61236 x^{10}
#
#                                                 texto curso     titulo  \
# 16  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 16     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
#
#                                             enunciado  \
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
#
#                                              solucion     texto curso  \
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 18  Parcial 1     ex01e05           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex             enunciado  \
# 33  P(x)=16x^2-mx+\frac{9}{4} \ no \ tenga\ ningun...  -m*x + 16*x**2 + 9/4
#
#                                              solucion  \
# 33  \left [ 16, \quad - m, \quad \frac{9}{4}\right...
#
#                                 texto curso     titulo n_ejercicio  \
# 33  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 33           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
#
#                                             enunciado  \
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
#
#                                solucion  \
# 37            \frac{x^{2} + 2 x}{x - 1}
# 39                 \frac{6}{x^{2} - 12}
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
#
#                                                 texto curso     titulo  \
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 37     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# 38     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#        enunciado_latex               enunciado          solucion  \
# 5  {\binom{x}{2}} = 28  Eq(binomial(x, 2), 28)  \left\{8\right\}
#
#                                                texto curso     titulo  \
# 5  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 5     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                                       enunciado_latex  \
# 16  P(x)=\left(3 x^{2} - \frac{1}{3 x}\right)^{10}...
#
#                                  enunciado        solucion  \
# 16  ((3*x**2 - 1/(3*x))**10, -61236*x**10)  - 61236 x^{10}
#
#                                                 texto curso     titulo  \
# 16  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 16     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
#
#                                             enunciado  \
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
#
#                                              solucion     texto curso  \
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 18  Parcial 1     ex01e05           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex             enunciado  \
# 33  P(x)=16x^2-mx+\frac{9}{4} \ no \ tenga\ ningun...  -m*x + 16*x**2 + 9/4
#
#                                              solucion  \
# 33  \left [ 16, \quad - m, \quad \frac{9}{4}\right...
#
#                                 texto curso     titulo n_ejercicio  \
# 33  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 33           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
#
#                                             enunciado  \
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
#
#                                solucion  \
# 37            \frac{x^{2} + 2 x}{x - 1}
# 39                 \frac{6}{x^{2} - 12}
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
#
#                                                 texto curso     titulo  \
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 37     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# 38     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#                                       enunciado_latex     enunciado  \
# 10  {\binom{20}{7}} - {\binom{19}{x}}-{\binom{19}{...  Eq(x + 1, 7)
#
#              solucion                                              texto  \
# 10  \left [ 6\right ]  Usando la definición y las propiedades de los ...
#
#    curso     titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 10   1BC  Parcial 1     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                                       enunciado_latex  \
# 16  P(x)=\left(3 x^{2} - \frac{1}{3 x}\right)^{10}...
#
#                                  enunciado        solucion  \
# 16  ((3*x**2 - 1/(3*x))**10, -61236*x**10)  - 61236 x^{10}
#
#                                                 texto curso     titulo  \
# 16  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 16     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 19  \frac{\sqrt{3}}{\sqrt{3}-\sqrt{2}}-\frac{\sqrt...
#
#                                             enunciado  \
# 19  -sqrt(3)/(sqrt(2) + sqrt(3)) + sqrt(3)/(-sqrt(...
#
#                    solucion     texto curso     titulo n_ejercicio  \
# 19  2 \sqrt{6}\to2 \sqrt{6}  Efectúa:   1BC  Parcial 1     ex01e05
#
#     dificultad  n_columnas  puntos  enun_tex
# 19           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex             enunciado  \
# 30  P(x)=\frac{x^2}{4}-mx+\frac{1}{16} \ tenga\ un...  -m*x + x**2/4 + 1/16
#
#                                              solucion  \
# 30  \left [ \frac{1}{4}, \quad - m, \quad \frac{1}...
#
#                                 texto curso     titulo n_ejercicio  \
# 30  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 30           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
#
#                                             enunciado  \
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
#
#                                solucion  \
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 39                 \frac{6}{x^{2} - 12}
# 37            \frac{x^{2} + 2 x}{x - 1}
#
#                                                 texto curso     titulo  \
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 38     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#                                       enunciado_latex     enunciado  \
# 10  {\binom{20}{7}} - {\binom{19}{x}}-{\binom{19}{...  Eq(x + 1, 7)
#
#              solucion                                              texto  \
# 10  \left [ 6\right ]  Usando la definición y las propiedades de los ...
#
#    curso     titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 10   1BC  Parcial 1     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                                       enunciado_latex  \
# 16  P(x)=\left(3 x^{2} - \frac{1}{3 x}\right)^{10}...
#
#                                  enunciado        solucion  \
# 16  ((3*x**2 - 1/(3*x))**10, -61236*x**10)  - 61236 x^{10}
#
#                                                 texto curso     titulo  \
# 16  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 16     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 19  \frac{\sqrt{3}}{\sqrt{3}-\sqrt{2}}-\frac{\sqrt...
#
#                                             enunciado  \
# 19  -sqrt(3)/(sqrt(2) + sqrt(3)) + sqrt(3)/(-sqrt(...
#
#                    solucion     texto curso     titulo n_ejercicio  \
# 19  2 \sqrt{6}\to2 \sqrt{6}  Efectúa:   1BC  Parcial 1     ex01e05
#
#     dificultad  n_columnas  puntos  enun_tex
# 19           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex             enunciado  \
# 30  P(x)=\frac{x^2}{4}-mx+\frac{1}{16} \ tenga\ un...  -m*x + x**2/4 + 1/16
#
#                                              solucion  \
# 30  \left [ \frac{1}{4}, \quad - m, \quad \frac{1}...
#
#                                 texto curso     titulo n_ejercicio  \
# 30  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 30           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
#
#                                             enunciado  \
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
#
#                                solucion  \
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 39                 \frac{6}{x^{2} - 12}
# 37            \frac{x^{2} + 2 x}{x - 1}
#
#                                                 texto curso     titulo  \
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 38     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#                       enunciado_latex  \
# 1  {\binom{23}{x}} = \binom{23}{3x-1}
#
#                                     enunciado          solucion  \
# 1  Eq(binomial(23, x), binomial(23, 3*x - 1))  \left\{6\right\}
#
#                                                texto curso     titulo  \
# 1  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 1     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                         enunciado_latex                enunciado solucion  \
# 17  P(x)=\left(x^{2} + x\right)^{4} \,   ((x**2 + x)**4, 6*x**6)  6 x^{6}
#
#                                                 texto curso     titulo  \
# 17  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 17     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
#
#                                             enunciado  \
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
#
#                                              solucion     texto curso  \
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 18  Parcial 1     ex01e05           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex             enunciado  \
# 29  P(x)=\frac{x^2}{16}-mx+\frac{9}{4} \ tenga\ un...  -m*x + x**2/16 + 9/4
#
#                                              solucion  \
# 29  \left [ \frac{1}{16}, \quad - m, \quad \frac{9...
#
#                                 texto curso     titulo n_ejercicio  \
# 29  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 29           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
#
#                                             enunciado  \
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
#
#                                solucion  \
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 37            \frac{x^{2} + 2 x}{x - 1}
# 39                 \frac{6}{x^{2} - 12}
#
#                                                 texto curso     titulo  \
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 38     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#                       enunciado_latex  \
# 1  {\binom{23}{x}} = \binom{23}{3x-1}
#
#                                     enunciado          solucion  \
# 1  Eq(binomial(23, x), binomial(23, 3*x - 1))  \left\{6\right\}
#
#                                                texto curso     titulo  \
# 1  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 1     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                         enunciado_latex                enunciado solucion  \
# 17  P(x)=\left(x^{2} + x\right)^{4} \,   ((x**2 + x)**4, 6*x**6)  6 x^{6}
#
#                                                 texto curso     titulo  \
# 17  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 17     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
#
#                                             enunciado  \
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
#
#                                              solucion     texto curso  \
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 18  Parcial 1     ex01e05           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex             enunciado  \
# 29  P(x)=\frac{x^2}{16}-mx+\frac{9}{4} \ tenga\ un...  -m*x + x**2/16 + 9/4
#
#                                              solucion  \
# 29  \left [ \frac{1}{16}, \quad - m, \quad \frac{9...
#
#                                 texto curso     titulo n_ejercicio  \
# 29  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 29           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
#
#                                             enunciado  \
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
#
#                                solucion  \
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 37            \frac{x^{2} + 2 x}{x - 1}
# 39                 \frac{6}{x^{2} - 12}
#
#                                                 texto curso     titulo  \
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 38     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#        enunciado_latex               enunciado          solucion  \
# 5  {\binom{x}{2}} = 28  Eq(binomial(x, 2), 28)  \left\{8\right\}
#
#                                                texto curso     titulo  \
# 5  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 5     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                                      enunciado_latex  \
# 15  P(x)=\left(3 x^{2} - \frac{3}{x}\right)^{10} \,
#
#                                 enunciado           solucion  \
# 15  ((3*x**2 - 3/x)**10, -14880348*x**10)  - 14880348 x^{10}
#
#                                                 texto curso     titulo  \
# 15  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 15     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 19  \frac{\sqrt{3}}{\sqrt{3}-\sqrt{2}}-\frac{\sqrt...
#
#                                             enunciado  \
# 19  -sqrt(3)/(sqrt(2) + sqrt(3)) + sqrt(3)/(-sqrt(...
#
#                    solucion     texto curso     titulo n_ejercicio  \
# 19  2 \sqrt{6}\to2 \sqrt{6}  Efectúa:   1BC  Parcial 1     ex01e05
#
#     dificultad  n_columnas  puntos  enun_tex
# 19           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex             enunciado  \
# 29  P(x)=\frac{x^2}{16}-mx+\frac{9}{4} \ tenga\ un...  -m*x + x**2/16 + 9/4
#
#                                              solucion  \
# 29  \left [ \frac{1}{16}, \quad - m, \quad \frac{9...
#
#                                 texto curso     titulo n_ejercicio  \
# 29  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 29           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
#
#                                             enunciado  \
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
#
#                                solucion  \
# 39                 \frac{6}{x^{2} - 12}
# 37            \frac{x^{2} + 2 x}{x - 1}
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
#
#                                                 texto curso     titulo  \
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 39     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# 38     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#        enunciado_latex               enunciado          solucion  \
# 5  {\binom{x}{2}} = 28  Eq(binomial(x, 2), 28)  \left\{8\right\}
#
#                                                texto curso     titulo  \
# 5  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 5     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                                      enunciado_latex  \
# 15  P(x)=\left(3 x^{2} - \frac{3}{x}\right)^{10} \,
#
#                                 enunciado           solucion  \
# 15  ((3*x**2 - 3/x)**10, -14880348*x**10)  - 14880348 x^{10}
#
#                                                 texto curso     titulo  \
# 15  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 15     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 19  \frac{\sqrt{3}}{\sqrt{3}-\sqrt{2}}-\frac{\sqrt...
#
#                                             enunciado  \
# 19  -sqrt(3)/(sqrt(2) + sqrt(3)) + sqrt(3)/(-sqrt(...
#
#                    solucion     texto curso     titulo n_ejercicio  \
# 19  2 \sqrt{6}\to2 \sqrt{6}  Efectúa:   1BC  Parcial 1     ex01e05
#
#     dificultad  n_columnas  puntos  enun_tex
# 19           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex             enunciado  \
# 29  P(x)=\frac{x^2}{16}-mx+\frac{9}{4} \ tenga\ un...  -m*x + x**2/16 + 9/4
#
#                                              solucion  \
# 29  \left [ \frac{1}{16}, \quad - m, \quad \frac{9...
#
#                                 texto curso     titulo n_ejercicio  \
# 29  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 29           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
#
#                                             enunciado  \
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
#
#                                solucion  \
# 39                 \frac{6}{x^{2} - 12}
# 37            \frac{x^{2} + 2 x}{x - 1}
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
#
#                                                 texto curso     titulo  \
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 39     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# 38     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#        enunciado_latex               enunciado          solucion  \
# 5  {\binom{x}{2}} = 28  Eq(binomial(x, 2), 28)  \left\{8\right\}
#
#                                                texto curso     titulo  \
# 5  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 5     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                                      enunciado_latex  \
# 15  P(x)=\left(3 x^{2} - \frac{3}{x}\right)^{10} \,
#
#                                 enunciado           solucion  \
# 15  ((3*x**2 - 3/x)**10, -14880348*x**10)  - 14880348 x^{10}
#
#                                                 texto curso     titulo  \
# 15  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 15     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
#
#                                             enunciado  \
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
#
#                                              solucion     texto curso  \
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 18  Parcial 1     ex01e05           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex          enunciado  \
# 28  P(x)=4x^2-mx+9 \ tenga\ una \ ra \acute \imath...  -m*x + 4*x**2 + 9
#
#                                              solucion  \
# 28  \left [ 4, \quad - m, \quad 9\right ]\to \left...
#
#                                 texto curso     titulo n_ejercicio  \
# 28  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 28           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
#
#                                             enunciado  \
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
#
#                                solucion  \
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 39                 \frac{6}{x^{2} - 12}
# 37            \frac{x^{2} + 2 x}{x - 1}
#
#                                                 texto curso     titulo  \
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 38     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
# **Ejercicio: **ex01e01
#                                      enunciado_latex  \
# 0  A=\left\{ x \in \mathbb{R}| 6 \leq x \wedge x ...
#
#                                            enunciado  \
# 0  [Interval.Ropen(6, 8), Union(Interval.open(-oo...
#
#                                             solucion  \
# 0  C=\left(-\infty, -14\right] \cup \left[10, \in...
#
#                                                texto curso     titulo  \
# 0  Dados los siguientes conjuntos A, B y C, repre...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 0     ex01e01           1           1       2      True
# **Ejercicio: **ex01e02
#        enunciado_latex               enunciado          solucion  \
# 5  {\binom{x}{2}} = 28  Eq(binomial(x, 2), 28)  \left\{8\right\}
#
#                                                texto curso     titulo  \
# 5  Usando la definición y las propiedades de los ...   1BC  Parcial 1
#
#   n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 5     ex01e02           1           1       1      True
# **Ejercicio: **ex01e04
#                                      enunciado_latex  \
# 15  P(x)=\left(3 x^{2} - \frac{3}{x}\right)^{10} \,
#
#                                 enunciado           solucion  \
# 15  ((3*x**2 - 3/x)**10, -14880348*x**10)  - 14880348 x^{10}
#
#                                                 texto curso     titulo  \
# 15  Encontrar, sin hacer todo el desarrollo, el té...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 15     ex01e04           1           1       2      True
# **Ejercicio: **ex01e05
#                                       enunciado_latex  \
# 18  \frac{{2 - \sqrt {3} }}{{1 - \sqrt {3} }}-\fra...
#
#                                             enunciado  \
# 18  (-sqrt(3) + 2)/(-sqrt(3) + 1) - sqrt(3)/6 + 3/...
#
#                                              solucion     texto curso  \
# 18  \frac{14 \sqrt{3} + 39}{6}\to\frac{7 \sqrt{3}}...  Efectúa:   1BC
#
#        titulo n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 18  Parcial 1     ex01e05           1           1       1      True
# **Ejercicio: **ex01e07
#                                       enunciado_latex          enunciado  \
# 28  P(x)=4x^2-mx+9 \ tenga\ una \ ra \acute \imath...  -m*x + 4*x**2 + 9
#
#                                              solucion  \
# 28  \left [ 4, \quad - m, \quad 9\right ]\to \left...
#
#                                 texto curso     titulo n_ejercicio  \
# 28  Calcula el valor de $m$ para que:   1BC  Parcial 1     ex01e07
#
#     dificultad  n_columnas  puntos  enun_tex
# 28           1           1       1      True
# **Ejercicio: **ex01e09
#                                       enunciado_latex  \
# 38  \frac{1+{ \frac{1}{x}}}{{1 + \frac{1}{{1 + \fr...
# 39  \frac{{\frac{1}{{x - 3}} - \frac{1}{{x + 3}}}}...
# 37  \frac{{x^3}-x^2 -4x + 4}{{x^2} - 3x + 2}:\frac...
#
#                                             enunciado  \
# 38                        (1 + 1/x)/(1 + 1/(1 + 1/x))
# 39        (-1/(x + 3) + 1/(x - 3))/(1 - 3/(x**2 - 9))
# 37  ((-4*x + x**3 - x**2 + 4)/(x**2 - 3*x + 2))/((...
#
#                                solucion  \
# 38  \frac{x^{2} + 2 x + 1}{2 x^{2} + x}
# 39                 \frac{6}{x^{2} - 12}
# 37            \frac{x^{2} + 2 x}{x - 1}
#
#                                                 texto curso     titulo  \
# 38  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 39  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
# 37  Calcula expresando el resultado en forma de fr...   1BC  Parcial 1
#
#    n_ejercicio  dificultad  n_columnas  puntos  enun_tex
# 38     ex01e09           1           1       1      True
# 39     ex01e09           1           1       1      True
# 37     ex01e09           1           1       1      True
