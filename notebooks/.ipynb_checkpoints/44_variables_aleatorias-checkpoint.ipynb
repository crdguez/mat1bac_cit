# %%
from sympy import init_session
from sympy import div, QQ
from sympy.parsing.latex import parse_latex
from sympy.parsing.sympy_parser import parse_expr
from IPython.display import Markdown as md
from IPython.display import display
import pandas as pd

import numpy as np

import scipy as sc
from tabulate import tabulate
from scipy.stats import cumfreq, relfreq, stats
from sympy.stats import P, E, variance, Die, Normal, Binomial


init_session()

a, b, c, d = symbols('a b c d', real = True)
from docparts import añadir_ejercicios, doc_ejer, escribir_preambulo, escribir_ejercicios, escribir_fin

df_ejercicios = pd.DataFrame()

fichero = 'var_ale'
titulo = '44 - Variables aleatorias'
curso = '1BC'


x,y = symbols('x, y', real=True)

# %matplotlib inline
# Out:
# IPython console for SymPy 1.2 (Python 3.6.5-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at http://docs.sympy.org/1.2/

# %% [markdown]
# La probabilidad de que un jugador de baloncesto enceste una canasta de 3 puntos es 0,6. Si tira 6
# veces, calcula la probabilidad:
# i) de que enceste 3
# ii) de que enceste al menos 1
# iii) de que enceste mas de 3

# %%
df_ejercicios
# Out:
#                                       enunciado_latex  \
# 0                    Realiza una tabla de frecuencias
# 1   Realiza un diagrama de barras y un polígono de...
# 2           Calcular los parámetros de centralización
# 3                 Calcular los parámetros de posición
# 4               Calcular los parámetros de dispersión
# 5                    Realiza una tabla de frecuencias
# 6   Realiza un diagrama de barras y un polígono de...
# 7           Calcular los parámetros de centralización
# 8                 Calcular los parámetros de posición
# 9               Calcular los parámetros de dispersión
# 10                   Realiza una tabla de frecuencias
# 11  Realiza un diagrama de barras y un polígono de...
# 12          Calcular los parámetros de centralización
# 13                Calcular los parámetros de posición
# 14              Calcular los parámetros de dispersión
# 15                   Realiza una tabla de frecuencias
# 16  Realiza un diagrama de barras y un polígono de...
# 17          Calcular los parámetros de centralización
# 18                Calcular los parámetros de posición
# 19              Calcular los parámetros de dispersión
# 20                   Realiza una tabla de frecuencias
# 21  Realiza un diagrama de barras y un polígono de...
# 22          Calcular los parámetros de centralización
# 23                Calcular los parámetros de posición
# 24              Calcular los parámetros de dispersión
# 25                   Realiza una tabla de frecuencias
# 26  Realiza un diagrama de barras y un polígono de...
# 27          Calcular los parámetros de centralización
# 28                Calcular los parámetros de posición
# 29              Calcular los parámetros de dispersión
#
#                                             enunciado  \
# 0                    Realiza una tabla de frecuencias
# 1   Realiza un diagrama de barras y un polígono de...
# 2           Calcular los parámetros de centralización
# 3                 Calcular los parámetros de posición
# 4               Calcular los parámetros de dispersión
# 5                    Realiza una tabla de frecuencias
# 6   Realiza un diagrama de barras y un polígono de...
# 7           Calcular los parámetros de centralización
# 8                 Calcular los parámetros de posición
# 9               Calcular los parámetros de dispersión
# 10                   Realiza una tabla de frecuencias
# 11  Realiza un diagrama de barras y un polígono de...
# 12          Calcular los parámetros de centralización
# 13                Calcular los parámetros de posición
# 14              Calcular los parámetros de dispersión
# 15                   Realiza una tabla de frecuencias
# 16  Realiza un diagrama de barras y un polígono de...
# 17          Calcular los parámetros de centralización
# 18                Calcular los parámetros de posición
# 19              Calcular los parámetros de dispersión
# 20                   Realiza una tabla de frecuencias
# 21  Realiza un diagrama de barras y un polígono de...
# 22          Calcular los parámetros de centralización
# 23                Calcular los parámetros de posición
# 24              Calcular los parámetros de dispersión
# 25                   Realiza una tabla de frecuencias
# 26  Realiza un diagrama de barras y un polígono de...
# 27          Calcular los parámetros de centralización
# 28                Calcular los parámetros de posición
# 29              Calcular los parámetros de dispersión
#
#                                              solucion  \
# 0   \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 1   \\ \includegraphics[width=1\columnwidth]{p089e01}
# 2   {'media': 5.294117647058823, 'mediana': 5.5, '...
# 3                              {'Q1': 4.0, 'Q3': 7.0}
# 4   {'rango': 10, 'varianza': 6.031141868512111, '...
# 5   \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 6   \\ \includegraphics[width=1\columnwidth]{p089e02}
# 7   {'media': 13.833333333333334, 'mediana': 14.0,...
# 8                           {'Q1': 11.75, 'Q3': 16.0}
# 9   {'rango': 8, 'varianza': 6.222222222222221, 'd...
# 10  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 11  \\ \includegraphics[width=1\columnwidth]{p089e03}
# 12  {'media': 168.5, 'mediana': 168.0, 'moda': ([1...
# 13                        {'Q1': 164.5, 'Q3': 172.75}
# 14  {'rango': 27, 'varianza': 34.31666666666667, '...
# 15  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 16  \\ \includegraphics[width=1\columnwidth]{p089e...
# 17  {'media': 168.66666666666666, 'mediana': 167.5...
# 18                        {'Q1': 163.75, 'Q3': 172.5}
# 19  {'rango': 25.0, 'varianza': 34.47222222222222,...
# 20  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 21   \\ \includegraphics[width=1\columnwidth]{p90e05}
# 22  {'media': 38.166666666666664, 'mediana': 35.0,...
# 23                           {'Q1': 15.0, 'Q3': 55.0}
# 24  {'rango': 70.0, 'varianza': 558.3055555555554,...
# 25  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 26   \\ \includegraphics[width=1\columnwidth]{p90e05}
# 27  {'media': 38.166666666666664, 'mediana': 35.0,...
# 28                           {'Q1': 15.0, 'Q3': 55.0}
# 29  {'rango': 70.0, 'varianza': 558.3055555555554,...
#
#                                                 texto curso  \
# 0   Las calificaciones de un grupo de 34 alumnos h...   1BC
# 1   Las calificaciones de un grupo de 34 alumnos h...   1BC
# 2   Las calificaciones de un grupo de 34 alumnos h...   1BC
# 3   Las calificaciones de un grupo de 34 alumnos h...   1BC
# 4   Las calificaciones de un grupo de 34 alumnos h...   1BC
# 5   Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 6   Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 7   Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 8   Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 9   Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 10  La altura en cm de 30 alumnos de un curso son:...   1BC
# 11  La altura en cm de 30 alumnos de un curso son:...   1BC
# 12  La altura en cm de 30 alumnos de un curso son:...   1BC
# 13  La altura en cm de 30 alumnos de un curso son:...   1BC
# 14  La altura en cm de 30 alumnos de un curso son:...   1BC
# 15  La altura en cm de 30 alumnos de un curso son:...   1BC
# 16  La altura en cm de 30 alumnos de un curso son:...   1BC
# 17  La altura en cm de 30 alumnos de un curso son:...   1BC
# 18  La altura en cm de 30 alumnos de un curso son:...   1BC
# 19  La altura en cm de 30 alumnos de un curso son:...   1BC
# 20  La realización de una prueba de habilidad moto...   1BC
# 21  La realización de una prueba de habilidad moto...   1BC
# 22  La realización de una prueba de habilidad moto...   1BC
# 23  La realización de una prueba de habilidad moto...   1BC
# 24  La realización de una prueba de habilidad moto...   1BC
# 25  La realización de una prueba de habilidad moto...   1BC
# 26  La realización de una prueba de habilidad moto...   1BC
# 27  La realización de una prueba de habilidad moto...   1BC
# 28  La realización de una prueba de habilidad moto...   1BC
# 29  La realización de una prueba de habilidad moto...   1BC
#
#                              titulo n_ejercicio dificultad n_columnas puntos  \
# 0   41 - Estadística Unidimensional     p089e01          1          1      1
# 1   41 - Estadística Unidimensional     p089e01          1          1      1
# 2   41 - Estadística Unidimensional     p089e01          1          1      1
# 3   41 - Estadística Unidimensional     p089e01          1          1      1
# 4   41 - Estadística Unidimensional     p089e01          1          1      1
# 5   41 - Estadística Unidimensional     p089e02          1          1      1
# 6   41 - Estadística Unidimensional     p089e02          1          1      1
# 7   41 - Estadística Unidimensional     p089e02          1          1      1
# 8   41 - Estadística Unidimensional     p089e02          1          1      1
# 9   41 - Estadística Unidimensional     p089e02          1          1      1
# 10  41 - Estadística Unidimensional     p089e03          1          1      1
# 11  41 - Estadística Unidimensional     p089e03          1          1      1
# 12  41 - Estadística Unidimensional     p089e03          1          1      1
# 13  41 - Estadística Unidimensional     p089e03          1          1      1
# 14  41 - Estadística Unidimensional     p089e03          1          1      1
# 15  41 - Estadística Unidimensional    p089e03b          1          1      1
# 16  41 - Estadística Unidimensional    p089e03b          1          1      1
# 17  41 - Estadística Unidimensional    p089e03b          1          1      1
# 18  41 - Estadística Unidimensional    p089e03b          1          1      1
# 19  41 - Estadística Unidimensional    p089e03b          1          1      1
# 20  41 - Estadística Unidimensional      p90e05          1          1      1
# 21  41 - Estadística Unidimensional      p90e05          1          1      1
# 22  41 - Estadística Unidimensional      p90e05          1          1      1
# 23  41 - Estadística Unidimensional      p90e05          1          1      1
# 24  41 - Estadística Unidimensional      p90e05          1          1      1
# 25  41 - Estadística Unidimensional      p90e05          1          1      1
# 26  41 - Estadística Unidimensional      p90e05          1          1      1
# 27  41 - Estadística Unidimensional      p90e05          1          1      1
# 28  41 - Estadística Unidimensional      p90e05          1          1      1
# 29  41 - Estadística Unidimensional      p90e05          1          1      1
#
#     enun_tex  sol_tex
# 0      False    False
# 1      False    False
# 2      False    False
# 3      False    False
# 4      False    False
# 5      False    False
# 6      False    False
# 7      False    False
# 8      False    False
# 9      False    False
# 10     False    False
# 11     False    False
# 12     False    False
# 13     False    False
# 14     False    False
# 15     False    False
# 16     False    False
# 17     False    False
# 18     False    False
# 19     False    False
# 20     False    False
# 21     False    False
# 22     False    False
# 23     False    False
# 24     False    False
# 25     False    False
# 26     False    False
# 27     False    False
# 28     False    False
# 29     False    False

# %%
df_ejercicios.to_csv('ejercicios44.csv', index = False)

# %%
df_ejercicios = pd.read_csv('ejercicios44.csv', index_col= None)

# %%
escribir_preambulo(fichero, titulo, 'ejercicios')
for s in df_ejercicios.groupby('n_ejercicio').count().index : 
    display(md("**Ejercicio: **" + s ))
    display(df_ejercicios[df_ejercicios.n_ejercicio == s])
    escribir_ejercicios(df_ejercicios[df_ejercicios.n_ejercicio == s],fichero)

escribir_fin(fichero)
# Out:
# **Ejercicio: **autoevaluacion1
#                                       enunciado_latex  \
# 20                   Realiza una tabla de frecuencias
# 21  Realiza un diagrama de barras y un polígono de...
# 22          Calcular los parámetros de centralización
# 23  Calcular los parámetros de posición P70, Q1, Q...
# 24              Calcular los parámetros de dispersión
#
#                                             enunciado  \
# 20                   Realiza una tabla de frecuencias
# 21  Realiza un diagrama de barras y un polígono de...
# 22          Calcular los parámetros de centralización
# 23  Calcular los parámetros de posición P70, Q1, Q...
# 24              Calcular los parámetros de dispersión
#
#                                              solucion  \
# 20  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 21  \\ \includegraphics[width=1\columnwidth]{autoe...
# 22  {'media': 3.95, 'mediana': 4.0, 'moda': ModeRe...
# 23     {'P70': 5.0, 'Q1': 2.75, 'Q3': 5.0, 'D4': 3.0}
# 24  {'rango': 7, 'varianza': 3.747500000000001, 'd...
#
#                                                 texto curso  \
# 20  Se realiza una encuesta a un grupo de 20 perso...   1BC
# 21  Se realiza una encuesta a un grupo de 20 perso...   1BC
# 22  Se realiza una encuesta a un grupo de 20 perso...   1BC
# 23  Se realiza una encuesta a un grupo de 20 perso...   1BC
# 24  Se realiza una encuesta a un grupo de 20 perso...   1BC
#
#                              titulo      n_ejercicio  dificultad  n_columnas  \
# 20  41 - Estadística Unidimensional  autoevaluacion1           1           1
# 21  41 - Estadística Unidimensional  autoevaluacion1           1           1
# 22  41 - Estadística Unidimensional  autoevaluacion1           1           1
# 23  41 - Estadística Unidimensional  autoevaluacion1           1           1
# 24  41 - Estadística Unidimensional  autoevaluacion1           1           1
#
#     puntos  enun_tex  sol_tex
# 20       1     False    False
# 21       1     False    False
# 22       1     False    False
# 23       1     False    False
# 24       1     False    False
# **Ejercicio: **p089e01
#                                      enunciado_latex  \
# 0                   Realiza una tabla de frecuencias
# 1  Realiza un diagrama de barras y un polígono de...
# 2          Calcular los parámetros de centralización
# 3  Calcular los parámetros de posición P70, Q1, Q...
# 4              Calcular los parámetros de dispersión
#
#                                            enunciado  \
# 0                   Realiza una tabla de frecuencias
# 1  Realiza un diagrama de barras y un polígono de...
# 2          Calcular los parámetros de centralización
# 3  Calcular los parámetros de posición P70, Q1, Q...
# 4              Calcular los parámetros de dispersión
#
#                                             solucion  \
# 0  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 1  \\ \includegraphics[width=1\columnwidth]{p089e01}
# 2  {'media': 5.294117647058823, 'mediana': 5.5, '...
# 3      {'P70': 7.0, 'Q1': 4.0, 'Q3': 7.0, 'D4': 5.0}
# 4  {'rango': 10, 'varianza': 6.031141868512111, '...
#
#                                                texto curso  \
# 0  Las calificaciones de un grupo de 34 alumnos h...   1BC
# 1  Las calificaciones de un grupo de 34 alumnos h...   1BC
# 2  Las calificaciones de un grupo de 34 alumnos h...   1BC
# 3  Las calificaciones de un grupo de 34 alumnos h...   1BC
# 4  Las calificaciones de un grupo de 34 alumnos h...   1BC
#
#                             titulo n_ejercicio  dificultad  n_columnas  \
# 0  41 - Estadística Unidimensional     p089e01           1           1
# 1  41 - Estadística Unidimensional     p089e01           1           1
# 2  41 - Estadística Unidimensional     p089e01           1           1
# 3  41 - Estadística Unidimensional     p089e01           1           1
# 4  41 - Estadística Unidimensional     p089e01           1           1
#
#    puntos  enun_tex  sol_tex
# 0       1     False    False
# 1       1     False    False
# 2       1     False    False
# 3       1     False    False
# 4       1     False    False
# **Ejercicio: **p089e02
#                                       enunciado_latex  \
# 15                   Realiza una tabla de frecuencias
# 16  Realiza un diagrama de barras y un polígono de...
# 17          Calcular los parámetros de centralización
# 18  Calcular los parámetros de posición P70, Q1, Q...
# 19              Calcular los parámetros de dispersión
#
#                                             enunciado  \
# 15                   Realiza una tabla de frecuencias
# 16  Realiza un diagrama de barras y un polígono de...
# 17          Calcular los parámetros de centralización
# 18  Calcular los parámetros de posición P70, Q1, Q...
# 19              Calcular los parámetros de dispersión
#
#                                              solucion  \
# 15  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 16  \\ \includegraphics[width=1\columnwidth]{p089e02}
# 17  {'media': 9.366666666666667, 'mediana': 10.0, ...
# 18   {'P70': 12.0, 'Q1': 5.25, 'Q3': 12.0, 'D4': 8.0}
# 19  {'rango': 19, 'varianza': 24.232222222222227, ...
#
#                                                 texto curso  \
# 15  En un grupo de personas de 1º de Bachillerato ...   1BC
# 16  En un grupo de personas de 1º de Bachillerato ...   1BC
# 17  En un grupo de personas de 1º de Bachillerato ...   1BC
# 18  En un grupo de personas de 1º de Bachillerato ...   1BC
# 19  En un grupo de personas de 1º de Bachillerato ...   1BC
#
#                              titulo n_ejercicio  dificultad  n_columnas  \
# 15  41 - Estadística Unidimensional     p089e02           1           1
# 16  41 - Estadística Unidimensional     p089e02           1           1
# 17  41 - Estadística Unidimensional     p089e02           1           1
# 18  41 - Estadística Unidimensional     p089e02           1           1
# 19  41 - Estadística Unidimensional     p089e02           1           1
#
#     puntos  enun_tex  sol_tex
# 15       1     False    False
# 16       1     False    False
# 17       1     False    False
# 18       1     False    False
# 19       1     False    False
# **Ejercicio: **p089e03
#                                      enunciado_latex  \
# 5                   Realiza una tabla de frecuencias
# 6  Realiza un diagrama de barras y un polígono de...
# 7          Calcular los parámetros de centralización
# 8  Calcular los parámetros de posición P70, Q1, Q...
# 9              Calcular los parámetros de dispersión
#
#                                            enunciado  \
# 5                   Realiza una tabla de frecuencias
# 6  Realiza un diagrama de barras y un polígono de...
# 7          Calcular los parámetros de centralización
# 8  Calcular los parámetros de posición P70, Q1, Q...
# 9              Calcular los parámetros de dispersión
#
#                                             solucion  \
# 5  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 6  \\ \includegraphics[width=1\columnwidth]{p089e03}
# 7  {'media': 13.833333333333334, 'mediana': 14.0,...
# 8  {'P70': 16.0, 'Q1': 11.75, 'Q3': 16.0, 'D4': 1...
# 9  {'rango': 8, 'varianza': 6.222222222222221, 'd...
#
#                                                texto curso  \
# 5  Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 6  Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 7  Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 8  Estos datos reflejan el tiempo, en minutos, qu...   1BC
# 9  Estos datos reflejan el tiempo, en minutos, qu...   1BC
#
#                             titulo n_ejercicio  dificultad  n_columnas  \
# 5  41 - Estadística Unidimensional     p089e03           1           1
# 6  41 - Estadística Unidimensional     p089e03           1           1
# 7  41 - Estadística Unidimensional     p089e03           1           1
# 8  41 - Estadística Unidimensional     p089e03           1           1
# 9  41 - Estadística Unidimensional     p089e03           1           1
#
#    puntos  enun_tex  sol_tex
# 5       1     False    False
# 6       1     False    False
# 7       1     False    False
# 8       1     False    False
# 9       1     False    False
# **Ejercicio: **p089e04
#                                       enunciado_latex  \
# 10                   Realiza una tabla de frecuencias
# 11  Realiza un diagrama de barras y un polígono de...
# 12          Calcular los parámetros de centralización
# 13  Calcular los parámetros de posición P70, Q1, Q...
# 14              Calcular los parámetros de dispersión
#
#                                             enunciado  \
# 10                   Realiza una tabla de frecuencias
# 11  Realiza un diagrama de barras y un polígono de...
# 12          Calcular los parámetros de centralización
# 13  Calcular los parámetros de posición P70, Q1, Q...
# 14              Calcular los parámetros de dispersión
#
#                                              solucion  \
# 10  \begin{tabular}{rrrrrrr}\n\hline\n   x\_i &   ...
# 11  \\ \includegraphics[width=1\columnwidth]{p089e04}
# 12  {'media': 168.5, 'mediana': 168.0, 'moda': Mod...
# 13  {'P70': 172.0, 'Q1': 164.5, 'Q3': 172.75, 'D4'...
# 14  {'rango': 27, 'varianza': 34.31666666666667, '...
#
#                                                 texto curso  \
# 10  La altura en cm de 30 alumnos de un curso son:...   1BC
# 11  La altura en cm de 30 alumnos de un curso son:...   1BC
# 12  La altura en cm de 30 alumnos de un curso son:...   1BC
# 13  La altura en cm de 30 alumnos de un curso son:...   1BC
# 14  La altura en cm de 30 alumnos de un curso son:...   1BC
#
#                              titulo n_ejercicio  dificultad  n_columnas  \
# 10  41 - Estadística Unidimensional     p089e04           1           1
# 11  41 - Estadística Unidimensional     p089e04           1           1
# 12  41 - Estadística Unidimensional     p089e04           1           1
# 13  41 - Estadística Unidimensional     p089e04           1           1
# 14  41 - Estadística Unidimensional     p089e04           1           1
#
#     puntos  enun_tex  sol_tex
# 10       1     False    False
# 11       1     False    False
# 12       1     False    False
# 13       1     False    False
# 14       1     False    False
