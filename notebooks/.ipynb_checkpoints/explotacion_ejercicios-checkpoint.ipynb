# %%
import pandas as pd
import numpy as np
from docparts import escribir_ejercicios, escribir_fin, escribir_preambulo

# %%
fichero = 'ejercicios'
n_ficheros = 3

df = pd.concat([pd.read_csv(fichero + str(n + 1)+ '.csv', index_col=False) for n in range(n_ficheros)])
df = df.reset_index()

# %%
np.random.choice(df.n_ejercicio, 10)
# Out:
# array(['p6e13', 'p6e15', 'p9e3', 'p9e3', 'p6e28', 'p9e7-13', 'p6e27',
#        'p9e3', 'p6e13', 'p6e15'], dtype=object)

# %%
ejercicios = df.loc[np.random.choice(df.index, 10)].sort_values('n_ejercicio')

# %%
ejercicios
# Out:
#      index                                    enunciado_latex  \
# 33      25                                \sqrt{a^5\cdot b^3}
# 37      29                        \sqrt {\sqrt {\sqrt {2} } }
# 34      26      \sqrt{a}  \cdot \sqrt[5]{a} \cdot \sqrt[6]{a}
# 55      47  \sqrt [3] {5}  \cdot \sqrt [4] {3}   \cdot \sq...
# 72      64                          \sqrt [3] {\sqrt[4] {a} }
# 80      72                   \frac{{abc}}{{\sqrt {ab{c^3}} }}
# 84      76                    \frac{1}{{\sqrt {\sqrt {2 }} }}
# 7        7                 \left|{2 x + 1}\right| - 0.5\geq 0
# 107     21                  ( {\frac{2}{5} + \frac{3}{x}} )^8
# 115     29            ( {\frac{{{x^2}}}{2} - \frac{3}{x}} )^8
#
#                        enunciado  \
# 33               sqrt(a**5*b**3)
# 37                      2**(1/8)
# 34   a**(1/6)*(a**(1/5)*sqrt(a))
# 55   sqrt(2)*(3**(1/4)*5**(1/3))
# 72                     a**(1/12)
# 80      (a*(b*c))/sqrt(a*b*c**3)
# 84                  1/(2**(1/4))
# ...

# %%
escribir_preambulo('autoevalucion.txt','Autoevaluacion')
